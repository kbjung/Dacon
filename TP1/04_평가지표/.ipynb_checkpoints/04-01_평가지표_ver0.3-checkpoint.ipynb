# %%
import pandas as pd
from tqdm import tqdm

# %%
# 과학적 표기법(Scientific notation)
# pd.set_option('display.float_format', '{:.2e}'.format)

# %%
# 판다스 라이브러리에서 과학적 표기 사용 안하기
pd.options.display.float_format = '{:.5f}'.format

# %% [markdown]
# # 실제 종가 파일

# %%
end = pd.read_csv('20211101_05_end.csv')
end
# Out:
#           Day  005930  000660  035420  035720  207940  005935  051910  006400  \
# 0  2021-11-01   69900  106500  408500  125500  874000   65200  832000  723000
# 1  2021-11-02   71500  107500  410000  128000  874000   66200  831000  731000
# 2  2021-11-03   70400  105500  402500  124500  874000   66200  784000  732000
# 3  2021-11-04   70600  106000  411500  130000  865000   66600  790000  751000
# 4  2021-11-05   70200  107000  410500  128500  864000   66300  786000  755000
#
#    005380  ...  078020  102710  314130  035890  032620  220630  064260  \
# 0  208000  ...    9030   28950   36600    1845    8050    4930    8970
# 1  210000  ...    9060   29150   38000    1875    8090    4965    9050
# 2  208500  ...    9040   29000   38650    1830    7900    4980    9080
# 3  214000  ...    9020   28750   39750    1815    7870    4975    8100
# 4  215000  ...    8940   28650   38400    1800    7670    5010    8480
#
#    287410  110790  099320
# 0    7480   41600   50300
# 1    7430   41650   49950
# 2    7110   42000   48850
# 3    6990   42100   47350
# 4    6780   41850   45550
#
# [5 rows x 371 columns]

# %% [markdown]
# # 예측 파일(제출 파일)

# %%
pred = pd.read_csv('prac_4w_pred_1w.csv')

# %%
pred
# Out:
#        005930       000660       035420       035720       207940      005935  \
# 0 69085.21840  96213.00000 379968.31250 113255.00000 840493.07230 64061.00000
# 1 70704.00000  98906.00000 408343.26659 127755.00000 881500.00000 64600.00000
# 2 69913.00000  97968.87059 405420.00000 126000.00000 868120.00000 64809.72802
# 3 70359.00000 106590.00000 408670.00000 125605.00000 875957.27264 65429.00000
# 4 70190.00000 104070.00000 402500.00000 125250.00000 873259.59017 66133.32031
#
#         051910       006400       005380       068270  ...     078020  \
# 0 807290.00000 669904.80000 204040.00000 216802.80358  ... 8758.97266
# 1 831000.00000 731855.50000 211173.15084 220069.09375  ... 9156.84961
# 2 831370.00000 711362.40000 226172.12500 217824.03406  ... 8959.52344
# 3 835480.00000 722741.90000 208675.00000 208866.37500  ... 9003.10645
# 4 803775.12500 739384.90000 209810.88553 203623.65625  ... 9023.87383
#
#        102710      314130     035890     032620     220630     064260  \
# 0 28794.67600 35650.00000 1804.80000 7263.47852 4267.91699 5806.46340
# 1 29529.10200 36898.67576 1901.73621 7677.60000 4504.76654 7512.00000
# 2 28763.67800 36807.48800 1868.16428 7664.09957 4779.19580 6230.00000
# 3 29026.02700 37770.90019 1849.27441 7902.56201 4882.04883 8912.89818
# 4 28532.63300 38162.53125 1829.88925 7903.77148 4968.85000 8645.04629
#
#       287410      110790      099320
# 0 7140.00000 41900.00000 63136.49219
# 1 7155.00000 42730.50000 55144.32031
# 2 7213.60000 42047.00000 52778.70312
# 3 7220.00000 42300.00000 50436.65625
# 4 7110.00000 41422.51562 47655.93860
#
# [5 rows x 370 columns]

# %% [markdown]
# # 예측 셋 중 public 평가 셋 만 가져오기

# %%
pred1 = pred.loc[:4]
pred1
# Out:
#        005930       000660       035420       035720       207940      005935  \
# 0 69085.21840  96213.00000 379968.31250 113255.00000 840493.07230 64061.00000
# 1 70704.00000  98906.00000 408343.26659 127755.00000 881500.00000 64600.00000
# 2 69913.00000  97968.87059 405420.00000 126000.00000 868120.00000 64809.72802
# 3 70359.00000 106590.00000 408670.00000 125605.00000 875957.27264 65429.00000
# 4 70190.00000 104070.00000 402500.00000 125250.00000 873259.59017 66133.32031
#
#         051910       006400       005380       068270  ...     078020  \
# 0 807290.00000 669904.80000 204040.00000 216802.80358  ... 8758.97266
# 1 831000.00000 731855.50000 211173.15084 220069.09375  ... 9156.84961
# 2 831370.00000 711362.40000 226172.12500 217824.03406  ... 8959.52344
# 3 835480.00000 722741.90000 208675.00000 208866.37500  ... 9003.10645
# 4 803775.12500 739384.90000 209810.88553 203623.65625  ... 9023.87383
#
#        102710      314130     035890     032620     220630     064260  \
# 0 28794.67600 35650.00000 1804.80000 7263.47852 4267.91699 5806.46340
# 1 29529.10200 36898.67576 1901.73621 7677.60000 4504.76654 7512.00000
# 2 28763.67800 36807.48800 1868.16428 7664.09957 4779.19580 6230.00000
# 3 29026.02700 37770.90019 1849.27441 7902.56201 4882.04883 8912.89818
# 4 28532.63300 38162.53125 1829.88925 7903.77148 4968.85000 8645.04629
#
#       287410      110790      099320
# 0 7140.00000 41900.00000 63136.49219
# 1 7155.00000 42730.50000 55144.32031
# 2 7213.60000 42047.00000 52778.70312
# 3 7220.00000 42300.00000 50436.65625
# 4 7110.00000 41422.51562 47655.93860
#
# [5 rows x 370 columns]

# %% [markdown]
# # 평가지표 함수화

# %%
def evaluation_index(prediction_set, real_set):
    eval_set = pd.DataFrame(['MSE','RMSE','R2','NMAE','NMAE*100'], columns=['평가지표'])
    for code in tqdm(end.columns.values[1:]):
        one_eval_list = []
        real = real_set[code]
        pred = prediction_set[code]

        # MSE
        mse = ( (real - pred) ** 2 ).sum() / len(pred)
            
        # RMSE
        rmse = mse ** (1/2)
        
        # MAE
        mae = ( abs( real - pred ) ).sum() / len(pred)
        
        # R2
        real_mean = real.mean()
        upper = ( (real - pred) ** 2 ).sum()
        lower = ( (real - real_mean) ** 2 ).sum()
        if lower == 0:
            fraction = 0
        else:
            fraction = upper / lower
        r2 = 1 - fraction
        
        #NMAE(Normalized Mean Absolute Error)-정규화 평균 절대 오차 척도
        nmae = ( abs( real - pred ) / real ).sum() / len(pred)  
        
        # 평가지표 셋 만들기
        one_eval_list.append(mse)
        one_eval_list.append(rmse)
        one_eval_list.append(r2)
        one_eval_list.append(nmae)
        one_eval_list.append(nmae*100)
        eval_set[code] = one_eval_list

    # 평가지표 셋에서 전체 종목 평균 구하기
    eval_set['평가지표_평균'] = eval_set.mean(axis=1)

    # 평가지표 평균 출력
    print(eval_set[['평가지표', '평가지표_평균']])

    return eval_set

# %%
result = evaluation_index(pred1, end)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 370/370 [00:01<00:00, 323.92it/s]
#        평가지표         평가지표_평균
# 0       MSE 123996342.39327
# 1      RMSE      4940.10749
# 2        R2       -19.37594
# 3      NMAE         0.04272
# 4  NMAE*100         4.27195

# %%
result
# Out:
#        평가지표       005930         000660          035420         035720  \
# 0       MSE 318567.00998 49066023.04378 179467451.43689 36425715.00000
# 1      RMSE    564.41741     7004.71434     13396.54625     6035.37199
# 2        R2     -0.08504      -97.13205       -16.52612       -7.97185
# 3      NMAE      0.00665        0.05617         0.02150        0.03413
# 4  NMAE*100      0.66526        5.61740         2.15012        3.41263
#
#            207940        005935           051910          006400  \
# 0 283868087.48652 1437840.06189 1047777293.75312 857618848.13400
# 1     16848.38531    1199.09969      32369.38822     29285.13015
# 2       -12.04541      -5.41893         -1.15486        -4.58928
# 3         0.01541       0.01655          0.03406         0.03222
# 4         1.54062       1.65472          3.40609         3.22221
#
#           005380  ...      102710        314130     035890       032620  \
# 0 76928883.78677  ... 62731.57530 1896698.60293 1171.09599 180009.64161
# 1     8770.91123  ...   250.46272    1377.20681   34.22128    424.27543
# 2       -8.33603  ...    -0.96036      -0.81920   -0.75840     -7.09979
# 3        0.03168  ...     0.00804       0.03172    0.01848      0.04263
# 4        3.16804  ...     0.80434       3.17166    1.84784      4.26316
#
#         220630        064260      287410       110790         099320  \
# 0 140164.86246 4236790.31509 72751.59200 296486.42817 44230725.52723
# 1    374.38598    2058.34650   269.72503    544.50567     6650.61843
# 2   -209.45775     -27.56058    -0.03611     -6.92744      -13.32342
# 3      0.05884       0.19126     0.03572      0.00985        0.11021
# 4      5.88423      19.12644     3.57229      0.98476       11.02069
#
#           평가지표_평균
# 0 123996342.39327
# 1      4940.10749
# 2       -19.37594
# 3         0.04272
# 4         4.27195
#
# [5 rows x 372 columns]
