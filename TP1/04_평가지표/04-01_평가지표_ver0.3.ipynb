# %%
import pandas as pd
from tqdm import tqdm

# %%
# 과학적 표기법(Scientific notation)
# pd.set_option('display.float_format', '{:.2e}'.format)

# %%
# 판다스 라이브러리에서 과학적 표기 사용 안하기
pd.options.display.float_format = '{:.5f}'.format

# %% [markdown]
# # 실제 종가 파일

# %%
end = pd.read_csv('20211101_05_end.csv')
end
# Out:
#           Day  005930  000660  035420  035720  207940  005935  051910  006400  \
# 0  2021-11-01   69900  106500  408500  125500  874000   65200  832000  723000
# 1  2021-11-02   71500  107500  410000  128000  874000   66200  831000  731000
# 2  2021-11-03   70400  105500  402500  124500  874000   66200  784000  732000
# 3  2021-11-04   70600  106000  411500  130000  865000   66600  790000  751000
# 4  2021-11-05   70200  107000  410500  128500  864000   66300  786000  755000
#
#    005380  ...  078020  102710  314130  035890  032620  220630  064260  \
# 0  208000  ...    9030   28950   36600    1845    8050    4930    8970
# 1  210000  ...    9060   29150   38000    1875    8090    4965    9050
# 2  208500  ...    9040   29000   38650    1830    7900    4980    9080
# 3  214000  ...    9020   28750   39750    1815    7870    4975    8100
# 4  215000  ...    8940   28650   38400    1800    7670    5010    8480
#
#    287410  110790  099320
# 0    7480   41600   50300
# 1    7430   41650   49950
# 2    7110   42000   48850
# 3    6990   42100   47350
# 4    6780   41850   45550
#
# [5 rows x 371 columns]

# %% [markdown]
# # 예측 파일(제출 파일)

# %%
pred = pd.read_csv('prac_4w_pred_1w-catboost-onebyone.csv')

# %%
pred
# Out:
#          Date      005930       000660       035420       035720       207940  \
# 0  2021-11-01 71147.98418  94154.50840 392319.71004 118734.07034 836926.93712
# 1  2021-11-02 70460.88586 101495.50613 409844.80103 126598.20195 879038.61567
# 2  2021-11-03 70276.46819 104422.85168 409863.86143 126459.30285 881576.22467
# 3  2021-11-04 70386.72432 105828.16210 408646.44088 125725.22200 877316.07488
# 4  2021-11-05 70173.33020 101733.82248 406385.59626 126382.31355 875510.81195
#
#        005935       051910       006400       005380  ...     078020  \
# 0 65221.01907 781007.39946 686554.47181 206703.91265  ... 8784.19017
# 1 64740.31019 827922.08640 733131.84206 209687.74784  ... 9090.36006
# 2 65028.22068 832228.69960 729832.84972 209101.75337  ... 9065.37813
# 3 65052.41325 833963.68804 734564.63875 208359.14287  ... 9042.10892
# 4 64653.33096 826921.90428 730540.75842 208223.57723  ... 9024.22579
#
#        102710      314130     035890     032620     220630     064260  \
# 0 28125.49757 35742.93836 1858.57736 7268.28433 4422.64495 5883.70562
# 1 29367.00534 37272.77610 1898.01359 7878.06812 4756.75780 7570.66897
# 2 29137.27822 37528.30726 1858.93652 7891.40622 4834.76840 8043.04498
# 3 29061.48600 37434.21110 1852.29508 7905.76010 4871.32973 7946.28447
# 4 28980.91374 37168.04342 1854.37558 7730.78947 4802.71484 7956.04180
#
#       287410      110790      099320
# 0 6644.23109 41144.12850 58196.27470
# 1 7189.58154 42573.99026 50295.28758
# 2 7300.19999 42325.44416 50114.60520
# 3 7258.54720 42065.86815 50606.36707
# 4 7180.70789 42226.12480 50573.20664
#
# [5 rows x 371 columns]

# %% [markdown]
# # 예측 셋 중 public 평가 셋 만 가져오기

# %%
pred1 = pred.loc[:4]
pred1
# Out:
#          Date      005930       000660       035420       035720       207940  \
# 0  2021-11-01 71147.98418  94154.50840 392319.71004 118734.07034 836926.93712
# 1  2021-11-02 70460.88586 101495.50613 409844.80103 126598.20195 879038.61567
# 2  2021-11-03 70276.46819 104422.85168 409863.86143 126459.30285 881576.22467
# 3  2021-11-04 70386.72432 105828.16210 408646.44088 125725.22200 877316.07488
# 4  2021-11-05 70173.33020 101733.82248 406385.59626 126382.31355 875510.81195
#
#        005935       051910       006400       005380  ...     078020  \
# 0 65221.01907 781007.39946 686554.47181 206703.91265  ... 8784.19017
# 1 64740.31019 827922.08640 733131.84206 209687.74784  ... 9090.36006
# 2 65028.22068 832228.69960 729832.84972 209101.75337  ... 9065.37813
# 3 65052.41325 833963.68804 734564.63875 208359.14287  ... 9042.10892
# 4 64653.33096 826921.90428 730540.75842 208223.57723  ... 9024.22579
#
#        102710      314130     035890     032620     220630     064260  \
# 0 28125.49757 35742.93836 1858.57736 7268.28433 4422.64495 5883.70562
# 1 29367.00534 37272.77610 1898.01359 7878.06812 4756.75780 7570.66897
# 2 29137.27822 37528.30726 1858.93652 7891.40622 4834.76840 8043.04498
# 3 29061.48600 37434.21110 1852.29508 7905.76010 4871.32973 7946.28447
# 4 28980.91374 37168.04342 1854.37558 7730.78947 4802.71484 7956.04180
#
#       287410      110790      099320
# 0 6644.23109 41144.12850 58196.27470
# 1 7189.58154 42573.99026 50295.28758
# 2 7300.19999 42325.44416 50114.60520
# 3 7258.54720 42065.86815 50606.36707
# 4 7180.70789 42226.12480 50573.20664
#
# [5 rows x 371 columns]

# %% [markdown]
# # 평가지표 함수화

# %%
def evaluation_index(prediction_set, real_set):
    eval_set = pd.DataFrame(['MSE','RMSE','R2','NMAE','NMAE*100'], columns=['평가지표'])
    for code in tqdm(end.columns.values[1:]):
        one_eval_list = []
        real = real_set[code]
        pred = prediction_set[code]

        # MSE
        mse = ( (real - pred) ** 2 ).sum() / len(pred)
            
        # RMSE
        rmse = mse ** (1/2)
        
        # MAE
        mae = ( abs( real - pred ) ).sum() / len(pred)
        
        # R2
        real_mean = real.mean()
        upper = ( (real - pred) ** 2 ).sum()
        lower = ( (real - real_mean) ** 2 ).sum()
        if lower == 0:
            fraction = 0
        else:
            fraction = upper / lower
        r2 = 1 - fraction
        
        #NMAE(Normalized Mean Absolute Error)-정규화 평균 절대 오차 척도
        nmae = ( abs( real - pred ) / real ).sum() / len(pred)  
        
        # 평가지표 셋 만들기
        one_eval_list.append(mse)
        one_eval_list.append(rmse)
        one_eval_list.append(r2)
        one_eval_list.append(nmae)
        one_eval_list.append(nmae*100)
        eval_set[code] = one_eval_list

    # 평가지표 셋에서 전체 종목 평균 구하기
    eval_set['평가지표_평균'] = eval_set.mean(axis=1)

    # 평가지표 평균 출력
    print(eval_set[['평가지표', '평가지표_평균']])

    return eval_set

# %%
result = evaluation_index(pred1, end)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 370/370 [00:00<00:00, 393.26it/s]
#        평가지표        평가지표_평균
# 0       MSE 88827286.88518
# 1      RMSE     4424.32825
# 2        R2      -16.29416
# 3      NMAE        0.04099
# 4  NMAE*100        4.09893

# %%
result
# Out:
#        평가지표          005930         000660           035420         035720  \
# 0       MSE 130834598.22759 19637714.86734 2068714387.87442 32233338.48085
# 1      RMSE     11438.29525     4431.44614      45483.12201     5677.44119
# 2        R2      -444.62193      -38.27543       -201.02289       -6.93925
# 3      NMAE         0.15508        0.03660          0.11118        0.04090
# 4  NMAE*100        15.50827        3.66008         11.11805        4.08986
#
#             207940         005935           051910           006400  \
# 0 1695526163.58394 58536420.37060 1054713617.61799 4474919420.65323
# 1      41176.76728     7650.90977      32476.35475      66894.83852
# 2        -76.91940     -260.32331         -1.16912        -28.16397
# 3          0.04538        0.10840          0.03226          0.08739
# 4          4.53772       10.84005          3.22567          8.73857
#
#            005380  ...         102710         314130          035890  \
# 0 927186412.20659  ... 11979825.16177 38552800.97826 102853478.38877
# 1     30449.73583  ...     3461.18840     6209.09019     10141.67039
# 2      -111.52262  ...     -373.36954      -35.97756   -154433.65224
# 3         0.14324  ...        0.11655        0.15896         5.48362
# 4        14.32394  ...       11.65520       15.89618       548.36214
#
#           032620          220630         064260         287410  \
# 0 31459736.35245 162179574.16971 95751599.98007 39495490.46796
# 1     5608.89796     12734.97445     9785.27465     6284.54378
# 2    -1414.57489   -243511.87413     -644.46999     -561.48562
# 3        0.68505         2.54105        1.09877        0.87040
# 4       68.50514       254.10520      109.87714       87.03995
#
#            110790         099320         평가지표_평균
# 0 111635780.45619 26184426.40997 347501137.09837
# 1     10565.78348     5117.07205     13665.43575
# 2     -2983.91392       -7.47941    -26873.13613
# 3         0.24569        0.10128         0.53778
# 4        24.56905       10.12794        53.77794
#
# [5 rows x 372 columns]
