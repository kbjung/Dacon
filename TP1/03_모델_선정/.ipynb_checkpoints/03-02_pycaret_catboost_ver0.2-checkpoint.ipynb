# %%
import FinanceDataReader as fdr
from tqdm import tqdm
import pandas as pd

# %% [markdown]
# # 상장 시장별 예측(Catboost이용)

# %% [markdown]
# ## 모든 종목 예측

# %% [markdown]
# * 종가와 상관계수 높은 특성 : KOSDAQ(0.87), KOSPI(0.79), DOW(0.58), NASDAQ(0.50), S&P500(0.56)
# * 예측 순서(종가와 상관계수 높은 특성 먼저 예측)
#     * weekday, weeknumdm로 KOSDAQ 예측(종가와 상관계수 0.87)
#     * weekday, weeknum, KOSDAQ으로 NASDAQ 예측(KOSDAQ과 상관계수 0.68)
#     * weekday, weeknum, KOSDAQ, NASDAQ으로 S&P500 예측(NASDAQ과 상관계수 0.93)
#     * weekday, weeknum, KOSDAQ, NASDAQ, S&P500으로 DOW 예측(S&P500과 상관계수 0.95)
#     * weekday, weeknum, KOSDAQ, NASDAQ, S&P500, DOW로 KOSPI 예측
#     * weekday, weeknum, KOSDAQ, NASDAQ, S&P500, DOW, KOSPI로 다른 종가 예측
# * 바로 전날 데이터 이용해 예측

# %%
# 제출 점수 :
# 자체 결정계수 점수 : 53.77794

# %%
from pycaret.regression import *

# %% [markdown]
# # 데이터 불러오기(첫번째 주)
# * 훈련 : 10.04 ~ 10.29
# * 예측 : 11.01 ~ 11.05

# %%
start_date = '2021-10-04'
end_date = '2021-11-04'

# %% [markdown]
# ### train set

# %%
data1 = pd.read_csv('../data/20210104-20211126_stock_index.csv')
stock_list = pd.read_csv('../data/stock_list.csv')

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    235 non-null    object
#  1   kosdaq  235 non-null    float64
#  2   nasdaq  235 non-null    float64
#  3   dow     235 non-null    float64
#  4   sp500   235 non-null    float64
#  5   kospi   235 non-null    float64
# dtypes: float64(5), object(1)
# memory usage: 11.1+ KB

# %%
data1['Date'] = pd.to_datetime(data1['Date'])
data1['weeknum'] = data1['Date'].dt.weekofyear
data1['weekday'] = data1['Date'].dt.weekday
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     235 non-null    datetime64[ns]
#  1   kosdaq   235 non-null    float64
#  2   nasdaq   235 non-null    float64
#  3   dow      235 non-null    float64
#  4   sp500    235 non-null    float64
#  5   kospi    235 non-null    float64
#  6   weeknum  235 non-null    int64
#  7   weekday  235 non-null    int64
# dtypes: datetime64[ns](1), float64(5), int64(2)
# memory usage: 14.8 KB

# %%
data1.head()
# Out:
#         Date  kosdaq   nasdaq       dow    sp500    kospi  weeknum  weekday
# 0 2021-01-04  977.62  12698.4  30223.89  3700.65  2944.45        1        0
# 1 2021-01-05  985.76  12819.0  30391.60  3726.86  2990.57        1        1
# 2 2021-01-06  981.39  12740.8  30829.40  3748.14  2968.21        1        2
# 3 2021-01-07  988.86  13067.5  31041.13  3803.79  3031.68        1        3
# 4 2021-01-08  987.79  13202.0  31097.97  3824.68  3152.18        1        4

# %%
data1.columns
# Out:
# Index(['Date', 'kosdaq', 'nasdaq', 'dow', 'sp500', 'kospi', 'weeknum',
#        'weekday'],
#       dtype='object')

# %%
data1 = data1[['Date', 'weeknum', 'weekday', 'kosdaq', 'nasdaq', 'dow', 'sp500', 'kospi']]

# %%
data1.head()
# Out:
#         Date  weeknum  weekday  kosdaq   nasdaq       dow    sp500    kospi
# 0 2021-01-04        1        0  977.62  12698.4  30223.89  3700.65  2944.45
# 1 2021-01-05        1        1  985.76  12819.0  30391.60  3726.86  2990.57
# 2 2021-01-06        1        2  981.39  12740.8  30829.40  3748.14  2968.21
# 3 2021-01-07        1        3  988.86  13067.5  31041.13  3803.79  3031.68
# 4 2021-01-08        1        4  987.79  13202.0  31097.97  3824.68  3152.18

# %%
train1 = data1[(data1['Date'] >= start_date) & (data1['Date'] <= end_date)]
train1.head()
# Out:
#           Date  weeknum  weekday   kosdaq   nasdaq       dow    sp500  \
# 195 2021-10-04       40        0  969.285  14255.5  34003.58  4300.46
# 196 2021-10-05       40        1  955.370  14433.8  34315.99  4345.72
# 197 2021-10-06       40        2  922.360  14501.9  34417.98  4363.55
# 198 2021-10-07       40        3  953.430  14654.0  34754.15  4399.76
# 199 2021-10-08       40        4  953.110  14579.5  34746.71  4391.36
#
#         kospi
# 195  2990.675
# 196  2962.170
# 197  2908.310
# 198  2959.460
# 199  2956.300

# %%
train1.tail()
# Out:
#           Date  weeknum  weekday   kosdaq   nasdaq       dow    sp500    kospi
# 214 2021-10-29       43        4   992.33  15498.4  35819.59  4605.38  2970.68
# 215 2021-11-01       44        0   998.57  15595.9  35913.68  4613.67  2978.94
# 216 2021-11-02       44        1  1009.44  15649.6  36053.09  4630.65  3013.49
# 217 2021-11-03       44        2  1005.00  15811.6  36157.02  4660.57  2975.71
# 218 2021-11-04       44        3  1001.43  15940.3  36124.66  4680.06  2983.22

# %%
train1 = train1.reset_index()
train1 = train1.drop('index', axis=1)
train1.head()
# Out:
#         Date  weeknum  weekday   kosdaq   nasdaq       dow    sp500     kospi
# 0 2021-10-04       40        0  969.285  14255.5  34003.58  4300.46  2990.675
# 1 2021-10-05       40        1  955.370  14433.8  34315.99  4345.72  2962.170
# 2 2021-10-06       40        2  922.360  14501.9  34417.98  4363.55  2908.310
# 3 2021-10-07       40        3  953.430  14654.0  34754.15  4399.76  2959.460
# 4 2021-10-08       40        4  953.110  14579.5  34746.71  4391.36  2956.300

# %%
train1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     24 non-null     datetime64[ns]
#  1   weeknum  24 non-null     int64
#  2   weekday  24 non-null     int64
#  3   kosdaq   24 non-null     float64
#  4   nasdaq   24 non-null     float64
#  5   dow      24 non-null     float64
#  6   sp500    24 non-null     float64
#  7   kospi    24 non-null     float64
# dtypes: datetime64[ns](1), float64(5), int64(2)
# memory usage: 1.6 KB

# %%
# 종목 코드 6자리로 맞추기
stock_list['종목코드'] = stock_list['종목코드'].astype(str).str.zfill(6)

# %%
stock_list.head()
# Out:
#         종목명    종목코드   상장시장
# 0      삼성전자  005930  KOSPI
# 1    SK하이닉스  000660  KOSPI
# 2     NAVER  035420  KOSPI
# 3       카카오  035720  KOSPI
# 4  삼성바이오로직스  207940  KOSPI

# %% [markdown]
# ### test set

# %%
test1 = data1[(data1['Date'] >= '2021-11-01') & (data1['Date'] <= '2021-11-05')].reset_index()
test1 = test1.drop('index', axis=1)
test1.head()
# Out:
#         Date  weeknum  weekday   kosdaq   nasdaq       dow    sp500    kospi
# 0 2021-11-01       44        0   998.57  15595.9  35913.68  4613.67  2978.94
# 1 2021-11-02       44        1  1009.44  15649.6  36053.09  4630.65  3013.49
# 2 2021-11-03       44        2  1005.00  15811.6  36157.02  4660.57  2975.71
# 3 2021-11-04       44        3  1001.43  15940.3  36124.66  4680.06  2983.22
# 4 2021-11-05       44        4  1001.35  15971.6  36329.07  4697.53  2969.27

# %%
test1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     5 non-null      datetime64[ns]
#  1   weeknum  5 non-null      int64
#  2   weekday  5 non-null      int64
#  3   kosdaq   5 non-null      float64
#  4   nasdaq   5 non-null      float64
#  5   dow      5 non-null      float64
#  6   sp500    5 non-null      float64
#  7   kospi    5 non-null      float64
# dtypes: datetime64[ns](1), float64(5), int64(2)
# memory usage: 448.0 bytes

# %%
test1 = test1[['Date','weeknum','weekday']]
test1
# Out:
#         Date  weeknum  weekday
# 0 2021-11-01       44        0
# 1 2021-11-02       44        1
# 2 2021-11-03       44        2
# 3 2021-11-04       44        3
# 4 2021-11-05       44        4

# %% [markdown]
# ## 3가지 날짜 특성으로 5가지 외부 특성 순서대로 예측하기

# %%
start_date = '2021-10-04'
end_date = '2021-11-04'

features = ['Date', 'weeknum', 'weekday', 'kosdaq', 'nasdaq', 'sp500', 'dow', 'kospi']
days1 = ['2021-10-04', '2021-10-05', '2021-10-06', '2021-10-07', '2021-10-08']
days2 = ['2021-10-29', '2021-11-01', '2021-11-02', '2021-11-03', '2021-11-04', '2021-11-05']
pred_test1 = pd.DataFrame()
for d in tqdm(range(5)):
    train_start_day = d
    train_end_day = d
    test_day = d+1
    temp_train = train1[(train1['Date'] >= days1[train_start_day]) & (train1['Date'] <= days2[train_end_day])]
    temp_test = test1[test1['Date'] == days2[test_day]]
    
    for i in range(5):      
        ex = setup(temp_train, target = features[i+3], ignore_features = features[i+4:], fold=4,
                      fold_shuffle=True, silent=True, use_gpu=True)
        model = create_model('catboost')
        final_model = finalize_model(model)
        pred = predict_model(final_model, temp_test)
        
        temp_test[features[i+3]] = pred['Label']
    
    pred_test1 = pd.concat([pred_test1, temp_test])
# Out:
# <style  type="text/css" >
# #T_ad637_row4_col0,#T_ad637_row4_col1,#T_ad637_row4_col2,#T_ad637_row4_col3,#T_ad637_row4_col4,#T_ad637_row4_col5{
#             background:  yellow;
#         }</style><table id="T_ad637_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ad637_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ad637_row0_col0" class="data row0 col0" >21.4816</td>
#                         <td id="T_ad637_row0_col1" class="data row0 col1" >615.0072</td>
#                         <td id="T_ad637_row0_col2" class="data row0 col2" >24.7993</td>
#                         <td id="T_ad637_row0_col3" class="data row0 col3" >0.2045</td>
#                         <td id="T_ad637_row0_col4" class="data row0 col4" >0.0082</td>
#                         <td id="T_ad637_row0_col5" class="data row0 col5" >0.0071</td>
#             </tr>
#             <tr>
#                         <th id="T_ad637_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_ad637_row1_col0" class="data row1 col0" >18.3648</td>
#                         <td id="T_ad637_row1_col1" class="data row1 col1" >965.3607</td>
#                         <td id="T_ad637_row1_col2" class="data row1 col2" >31.0703</td>
#                         <td id="T_ad637_row1_col3" class="data row1 col3" >0.4642</td>
#                         <td id="T_ad637_row1_col4" class="data row1 col4" >0.0106</td>
#                         <td id="T_ad637_row1_col5" class="data row1 col5" >0.0063</td>
#             </tr>
#             <tr>
#                         <th id="T_ad637_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_ad637_row2_col0" class="data row2 col0" >8.0191</td>
#                         <td id="T_ad637_row2_col1" class="data row2 col1" >129.4418</td>
#                         <td id="T_ad637_row2_col2" class="data row2 col2" >11.3772</td>
#                         <td id="T_ad637_row2_col3" class="data row2 col3" >0.6294</td>
#                         <td id="T_ad637_row2_col4" class="data row2 col4" >0.0038</td>
#                         <td id="T_ad637_row2_col5" class="data row2 col5" >0.0027</td>
#             </tr>
#             <tr>
#                         <th id="T_ad637_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_ad637_row3_col0" class="data row3 col0" >16.9876</td>
#                         <td id="T_ad637_row3_col1" class="data row3 col1" >430.9811</td>
#                         <td id="T_ad637_row3_col2" class="data row3 col2" >20.7601</td>
#                         <td id="T_ad637_row3_col3" class="data row3 col3" >-0.1723</td>
#                         <td id="T_ad637_row3_col4" class="data row3 col4" >0.0069</td>
#                         <td id="T_ad637_row3_col5" class="data row3 col5" >0.0057</td>
#             </tr>
#             <tr>
#                         <th id="T_ad637_level0_row4" class="row_heading level0 row4" >Mean</th>
#                         <td id="T_ad637_row4_col0" class="data row4 col0" >16.2133</td>
#                         <td id="T_ad637_row4_col1" class="data row4 col1" >535.1977</td>
#                         <td id="T_ad637_row4_col2" class="data row4 col2" >22.0017</td>
#                         <td id="T_ad637_row4_col3" class="data row4 col3" >0.2815</td>
#                         <td id="T_ad637_row4_col4" class="data row4 col4" >0.0074</td>
#                         <td id="T_ad637_row4_col5" class="data row4 col5" >0.0054</td>
#             </tr>
#             <tr>
#                         <th id="T_ad637_level0_row5" class="row_heading level0 row5" >SD</th>
#                         <td id="T_ad637_row5_col0" class="data row5 col0" >5.0032</td>
#                         <td id="T_ad637_row5_col1" class="data row5 col1" >302.8650</td>
#                         <td id="T_ad637_row5_col2" class="data row5 col2" >7.1499</td>
#                         <td id="T_ad637_row5_col3" class="data row5 col3" >0.3026</td>
#                         <td id="T_ad637_row5_col4" class="data row5 col4" >0.0024</td>
#                         <td id="T_ad637_row5_col5" class="data row5 col5" >0.0017</td>
#             </tr>
#     </tbody></table>
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [04:02<00:00, 48.41s/it]

# %%
pred_test1
# Out:
#         Date  weeknum  weekday       kosdaq        nasdaq        sp500  \
# 0 2021-11-01       44        0   969.212896  14506.027898  4374.346336
# 1 2021-11-02       44        1   996.130465  15253.017991  4566.198763
# 2 2021-11-03       44        2  1003.685315  15507.310373  4593.508834
# 3 2021-11-04       44        3   995.710558  15486.116757  4606.498971
# 4 2021-11-05       44        4   993.271141  15495.872560  4622.599512
#
#             dow        kospi
# 0  34540.700050  2972.818283
# 1  35697.133860  3013.898914
# 2  35736.631211  3003.717113
# 3  35910.840208  2984.410936
# 4  35846.924735  2977.474141

# %%
# pred_test1.to_csv('prac_4w_pred_1w_test1_cat.csv', index=False)

# %% [markdown]
# ## 훈련, 테스트 셋 준비

# %% [markdown]
# ### 데이터 불러오기

# %%
all_data = pd.read_csv('../data/2021-01-04_2021-11-26_all_data.csv')
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86950 entries, 0 to 86949
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    86950 non-null  object
#  1   kosdaq  86950 non-null  float64
#  2   nasdaq  86950 non-null  float64
#  3   dow     86950 non-null  float64
#  4   sp500   86950 non-null  float64
#  5   kospi   86950 non-null  float64
#  6   code    86950 non-null  int64
#  7   market  86950 non-null  object
#  8   close   82872 non-null  float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 6.0+ MB

# %%
all_data['code'] = all_data['code'].astype(str).str.zfill(6)
all_data.head()
# Out:
#          Date  kosdaq   nasdaq       dow    sp500    kospi    code market  \
# 0  2021-01-04  977.62  12698.4  30223.89  3700.65  2944.45  005930  KOSPI
# 1  2021-01-05  985.76  12819.0  30391.60  3726.86  2990.57  005930  KOSPI
# 2  2021-01-06  981.39  12740.8  30829.40  3748.14  2968.21  005930  KOSPI
# 3  2021-01-07  988.86  13067.5  31041.13  3803.79  3031.68  005930  KOSPI
# 4  2021-01-08  987.79  13202.0  31097.97  3824.68  3152.18  005930  KOSPI
#
#      close
# 0  83000.0
# 1  83900.0
# 2  82200.0
# 3  82900.0
# 4  88800.0

# %% [markdown]
# ### 훈련 셋 준비

# %% [markdown]
# #### KOPSI 종목 데이터만 추출

# %%
kospi_train = all_data[all_data['market'] == 'KOSPI']
kospi_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43475 entries, 0 to 43474
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    43475 non-null  object
#  1   kosdaq  43475 non-null  float64
#  2   nasdaq  43475 non-null  float64
#  3   dow     43475 non-null  float64
#  4   sp500   43475 non-null  float64
#  5   kospi   43475 non-null  float64
#  6   code    43475 non-null  object
#  7   market  43475 non-null  object
#  8   close   41440 non-null  float64
# dtypes: float64(6), object(3)
# memory usage: 3.3+ MB

# %%
kospi_train.head()
# Out:
#          Date  kosdaq   nasdaq       dow    sp500    kospi    code market  \
# 0  2021-01-04  977.62  12698.4  30223.89  3700.65  2944.45  005930  KOSPI
# 1  2021-01-05  985.76  12819.0  30391.60  3726.86  2990.57  005930  KOSPI
# 2  2021-01-06  981.39  12740.8  30829.40  3748.14  2968.21  005930  KOSPI
# 3  2021-01-07  988.86  13067.5  31041.13  3803.79  3031.68  005930  KOSPI
# 4  2021-01-08  987.79  13202.0  31097.97  3824.68  3152.18  005930  KOSPI
#
#      close
# 0  83000.0
# 1  83900.0
# 2  82200.0
# 3  82900.0
# 4  88800.0

# %% [markdown]
# #### KOSDAQ 종목 데이터만 추출

# %%
kosdaq_train = all_data[all_data['market'] == 'KOSDAQ']
kosdaq_train = kosdaq_train.reset_index()
kosdaq_train = kosdaq_train.drop('index', axis=1)
kosdaq_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43475 entries, 0 to 43474
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    43475 non-null  object
#  1   kosdaq  43475 non-null  float64
#  2   nasdaq  43475 non-null  float64
#  3   dow     43475 non-null  float64
#  4   sp500   43475 non-null  float64
#  5   kospi   43475 non-null  float64
#  6   code    43475 non-null  object
#  7   market  43475 non-null  object
#  8   close   41432 non-null  float64
# dtypes: float64(6), object(3)
# memory usage: 3.0+ MB

# %%
kosdaq_train.head()
# Out:
#          Date  kosdaq   nasdaq       dow    sp500    kospi    code  market  \
# 0  2021-01-04  977.62  12698.4  30223.89  3700.65  2944.45  091990  KOSDAQ
# 1  2021-01-05  985.76  12819.0  30391.60  3726.86  2990.57  091990  KOSDAQ
# 2  2021-01-06  981.39  12740.8  30829.40  3748.14  2968.21  091990  KOSDAQ
# 3  2021-01-07  988.86  13067.5  31041.13  3803.79  3031.68  091990  KOSDAQ
# 4  2021-01-08  987.79  13202.0  31097.97  3824.68  3152.18  091990  KOSDAQ
#
#       close
# 0  151300.0
# 1  152300.0
# 2  150300.0
# 3  154700.0
# 4  162900.0

# %% [markdown]
# ### 테스트 셋 준비

# %%
test = pd.DataFrame()
test_start_date = '2021-11-01'
test_end_date = '2021-11-05'
Business_days = pd.DataFrame(pd.date_range(start=test_start_date, end=test_end_date, freq='B'), columns=['Date'])
for code, market in tqdm(stock_list[['종목코드', '상장시장']].values):
    temp_code = [code] * 5
    temp_market = [market] * 5
    
    pred_test1['code'] = temp_code
    pred_test1['market'] = temp_market
    
    test = pd.concat([test, pred_test1])
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 370/370 [00:00<00:00, 883.31it/s]

# %%
# 5일 * 370종목 = 1850
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1850 entries, 0 to 4
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     1850 non-null   datetime64[ns]
#  1   weeknum  1850 non-null   int64
#  2   weekday  1850 non-null   int64
#  3   kosdaq   1850 non-null   float64
#  4   nasdaq   1850 non-null   float64
#  5   sp500    1850 non-null   float64
#  6   dow      1850 non-null   float64
#  7   kospi    1850 non-null   float64
#  8   code     1850 non-null   object
#  9   market   1850 non-null   object
# dtypes: datetime64[ns](1), float64(5), int64(2), object(2)
# memory usage: 159.0+ KB

# %%
test.head()
# Out:
#         Date  weeknum  weekday       kosdaq        nasdaq        sp500  \
# 0 2021-11-01       44        0   969.212896  14506.027898  4374.346336
# 1 2021-11-02       44        1   996.130465  15253.017991  4566.198763
# 2 2021-11-03       44        2  1003.685315  15507.310373  4593.508834
# 3 2021-11-04       44        3   995.710558  15486.116757  4606.498971
# 4 2021-11-05       44        4   993.271141  15495.872560  4622.599512
#
#             dow        kospi    code market
# 0  34540.700050  2972.818283  005930  KOSPI
# 1  35697.133860  3013.898914  005930  KOSPI
# 2  35736.631211  3003.717113  005930  KOSPI
# 3  35910.840208  2984.410936  005930  KOSPI
# 4  35846.924735  2977.474141  005930  KOSPI

# %% [markdown]
# #### KOSPI 종목 데이터만 추출

# %%
kospi_test = test[test['market'] == 'KOSPI']
kospi_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 925 entries, 0 to 4
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     925 non-null    datetime64[ns]
#  1   weeknum  925 non-null    int64
#  2   weekday  925 non-null    int64
#  3   kosdaq   925 non-null    float64
#  4   nasdaq   925 non-null    float64
#  5   sp500    925 non-null    float64
#  6   dow      925 non-null    float64
#  7   kospi    925 non-null    float64
#  8   code     925 non-null    object
#  9   market   925 non-null    object
# dtypes: datetime64[ns](1), float64(5), int64(2), object(2)
# memory usage: 79.5+ KB

# %%
kospi_test.head()
# Out:
#         Date  weeknum  weekday       kosdaq        nasdaq        sp500  \
# 0 2021-11-01       44        0   969.212896  14506.027898  4374.346336
# 1 2021-11-02       44        1   996.130465  15253.017991  4566.198763
# 2 2021-11-03       44        2  1003.685315  15507.310373  4593.508834
# 3 2021-11-04       44        3   995.710558  15486.116757  4606.498971
# 4 2021-11-05       44        4   993.271141  15495.872560  4622.599512
#
#             dow        kospi    code market
# 0  34540.700050  2972.818283  005930  KOSPI
# 1  35697.133860  3013.898914  005930  KOSPI
# 2  35736.631211  3003.717113  005930  KOSPI
# 3  35910.840208  2984.410936  005930  KOSPI
# 4  35846.924735  2977.474141  005930  KOSPI

# %% [markdown]
# #### KOSDAQ 종목 데이터만 추출

# %%
kosdaq_test = test[test['market'] == 'KOSDAQ'].reset_index()
kosdaq_test = kosdaq_test.drop('index', axis=1)
kosdaq_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 925 entries, 0 to 924
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     925 non-null    datetime64[ns]
#  1   weeknum  925 non-null    int64
#  2   weekday  925 non-null    int64
#  3   kosdaq   925 non-null    float64
#  4   nasdaq   925 non-null    float64
#  5   sp500    925 non-null    float64
#  6   dow      925 non-null    float64
#  7   kospi    925 non-null    float64
#  8   code     925 non-null    object
#  9   market   925 non-null    object
# dtypes: datetime64[ns](1), float64(5), int64(2), object(2)
# memory usage: 72.4+ KB

# %%
kosdaq_test.head()
# Out:
#         Date  weeknum  weekday       kosdaq        nasdaq        sp500  \
# 0 2021-11-01       44        0   969.212896  14506.027898  4374.346336
# 1 2021-11-02       44        1   996.130465  15253.017991  4566.198763
# 2 2021-11-03       44        2  1003.685315  15507.310373  4593.508834
# 3 2021-11-04       44        3   995.710558  15486.116757  4606.498971
# 4 2021-11-05       44        4   993.271141  15495.872560  4622.599512
#
#             dow        kospi    code  market
# 0  34540.700050  2972.818283  091990  KOSDAQ
# 1  35697.133860  3013.898914  091990  KOSDAQ
# 2  35736.631211  3003.717113  091990  KOSDAQ
# 3  35910.840208  2984.410936  091990  KOSDAQ
# 4  35846.924735  2977.474141  091990  KOSDAQ

# %% [markdown]
# ## 상장 시장 별 종가 예측하기

# %% [markdown]
# ### KOSPI

# %%
days1 = ['2021-10-04', '2021-10-05', '2021-10-06', '2021-10-07', '2021-10-08']
days2 = ['2021-10-29', '2021-11-01', '2021-11-02', '2021-11-03', '2021-11-04', '2021-11-05']

kospi_stock_list = stock_list[stock_list['상장시장'] == 'KOSPI']

temp_pred_test = pd.DataFrame()
for d in range(5):
    train_start_day = d
    train_end_day = d
    test_day = d+1
    temp_train = kospi_train[ (kospi_train['Date'] >= days1[train_start_day]) &
                              (kospi_train['Date'] <= days2[train_end_day]) ]
    
    temp_test = kospi_test[kospi_test['Date'] == days2[test_day]]

    ex = setup(temp_train, target = 'close', silent=True, fold=4, fold_shuffle=True, use_gpu=True)
    cat = create_model('catboost')
    pred = predict_model(cat, temp_test)
    temp_test['close'] = pred['Label']
    temp_pred_test = pd.concat([temp_pred_test, temp_test])

kospi_pred = temp_pred_test[['Date','code', 'close']]
# Out:
# <style  type="text/css" >
# #T_fc258_row4_col0,#T_fc258_row4_col1,#T_fc258_row4_col2,#T_fc258_row4_col3,#T_fc258_row4_col4,#T_fc258_row4_col5{
#             background:  yellow;
#         }</style><table id="T_fc258_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fc258_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_fc258_row0_col0" class="data row0 col0" >24003.0930</td>
#                         <td id="T_fc258_row0_col1" class="data row0 col1" >1122596537.3063</td>
#                         <td id="T_fc258_row0_col2" class="data row0 col2" >33505.1718</td>
#                         <td id="T_fc258_row0_col3" class="data row0 col3" >0.9730</td>
#                         <td id="T_fc258_row0_col4" class="data row0 col4" >0.6277</td>
#                         <td id="T_fc258_row0_col5" class="data row0 col5" >0.7573</td>
#             </tr>
#             <tr>
#                         <th id="T_fc258_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_fc258_row1_col0" class="data row1 col0" >22603.4687</td>
#                         <td id="T_fc258_row1_col1" class="data row1 col1" >948029908.9137</td>
#                         <td id="T_fc258_row1_col2" class="data row1 col2" >30790.0943</td>
#                         <td id="T_fc258_row1_col3" class="data row1 col3" >0.9656</td>
#                         <td id="T_fc258_row1_col4" class="data row1 col4" >0.6076</td>
#                         <td id="T_fc258_row1_col5" class="data row1 col5" >0.6969</td>
#             </tr>
#             <tr>
#                         <th id="T_fc258_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_fc258_row2_col0" class="data row2 col0" >26580.7507</td>
#                         <td id="T_fc258_row2_col1" class="data row2 col1" >1362945144.4824</td>
#                         <td id="T_fc258_row2_col2" class="data row2 col2" >36918.0870</td>
#                         <td id="T_fc258_row2_col3" class="data row2 col3" >0.9622</td>
#                         <td id="T_fc258_row2_col4" class="data row2 col4" >0.6469</td>
#                         <td id="T_fc258_row2_col5" class="data row2 col5" >0.7930</td>
#             </tr>
#             <tr>
#                         <th id="T_fc258_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_fc258_row3_col0" class="data row3 col0" >23644.7950</td>
#                         <td id="T_fc258_row3_col1" class="data row3 col1" >999264121.0547</td>
#                         <td id="T_fc258_row3_col2" class="data row3 col2" >31611.1392</td>
#                         <td id="T_fc258_row3_col3" class="data row3 col3" >0.9619</td>
#                         <td id="T_fc258_row3_col4" class="data row3 col4" >0.7334</td>
#                         <td id="T_fc258_row3_col5" class="data row3 col5" >1.0636</td>
#             </tr>
#             <tr>
#                         <th id="T_fc258_level0_row4" class="row_heading level0 row4" >Mean</th>
#                         <td id="T_fc258_row4_col0" class="data row4 col0" >24208.0268</td>
#                         <td id="T_fc258_row4_col1" class="data row4 col1" >1108208927.9393</td>
#                         <td id="T_fc258_row4_col2" class="data row4 col2" >33206.1231</td>
#                         <td id="T_fc258_row4_col3" class="data row4 col3" >0.9657</td>
#                         <td id="T_fc258_row4_col4" class="data row4 col4" >0.6539</td>
#                         <td id="T_fc258_row4_col5" class="data row4 col5" >0.8277</td>
#             </tr>
#             <tr>
#                         <th id="T_fc258_level0_row5" class="row_heading level0 row5" >SD</th>
#                         <td id="T_fc258_row5_col0" class="data row5 col0" >1463.1860</td>
#                         <td id="T_fc258_row5_col1" class="data row5 col1" >160174773.6108</td>
#                         <td id="T_fc258_row5_col2" class="data row5 col2" >2358.4568</td>
#                         <td id="T_fc258_row5_col3" class="data row5 col3" >0.0045</td>
#                         <td id="T_fc258_row5_col4" class="data row5 col4" >0.0480</td>
#                         <td id="T_fc258_row5_col5" class="data row5 col5" >0.1405</td>
#             </tr>
#     </tbody></table>

# %%
kospi_pred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 925 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    925 non-null    datetime64[ns]
#  1   code    925 non-null    object
#  2   close   925 non-null    float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 28.9+ KB

# %% [markdown]
# ### KOSDAQ

# %%
days1 = ['2021-10-04', '2021-10-05', '2021-10-06', '2021-10-07', '2021-10-08']
days2 = ['2021-10-29', '2021-11-01', '2021-11-02', '2021-11-03', '2021-11-04', '2021-11-05']

kosdaq_stock_list = stock_list[stock_list['상장시장'] == 'KOSDAQ']

temp_pred_test = pd.DataFrame()
for d in range(5):
    train_start_day = d
    train_end_day = d
    test_day = d+1
    temp_train = kosdaq_train[ (kosdaq_train['Date'] >= days1[train_start_day]) &
                              (kosdaq_train['Date'] <= days2[train_end_day]) ]
    
    temp_test = kosdaq_test[kosdaq_test['Date'] == days2[test_day]]

    ex = setup(temp_train, target = 'close', silent=True, fold=4, fold_shuffle=True, use_gpu=True)
    cat = create_model('catboost')
    pred = predict_model(cat, temp_test)
    temp_test['close'] = pred['Label']
    temp_pred_test = pd.concat([temp_pred_test, temp_test])

kosdaq_pred = temp_pred_test[['Date','code', 'close']]
# Out:
# <style  type="text/css" >
# #T_f0a07_row4_col0,#T_f0a07_row4_col1,#T_f0a07_row4_col2,#T_f0a07_row4_col3,#T_f0a07_row4_col4,#T_f0a07_row4_col5{
#             background:  yellow;
#         }</style><table id="T_f0a07_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f0a07_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f0a07_row0_col0" class="data row0 col0" >9594.7304</td>
#                         <td id="T_f0a07_row0_col1" class="data row0 col1" >210807510.7110</td>
#                         <td id="T_f0a07_row0_col2" class="data row0 col2" >14519.2118</td>
#                         <td id="T_f0a07_row0_col3" class="data row0 col3" >0.9469</td>
#                         <td id="T_f0a07_row0_col4" class="data row0 col4" >0.4401</td>
#                         <td id="T_f0a07_row0_col5" class="data row0 col5" >0.4251</td>
#             </tr>
#             <tr>
#                         <th id="T_f0a07_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f0a07_row1_col0" class="data row1 col0" >10469.6829</td>
#                         <td id="T_f0a07_row1_col1" class="data row1 col1" >235771319.8107</td>
#                         <td id="T_f0a07_row1_col2" class="data row1 col2" >15354.8468</td>
#                         <td id="T_f0a07_row1_col3" class="data row1 col3" >0.9353</td>
#                         <td id="T_f0a07_row1_col4" class="data row1 col4" >0.5065</td>
#                         <td id="T_f0a07_row1_col5" class="data row1 col5" >0.5196</td>
#             </tr>
#             <tr>
#                         <th id="T_f0a07_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_f0a07_row2_col0" class="data row2 col0" >8945.5504</td>
#                         <td id="T_f0a07_row2_col1" class="data row2 col1" >133996591.8728</td>
#                         <td id="T_f0a07_row2_col2" class="data row2 col2" >11575.6897</td>
#                         <td id="T_f0a07_row2_col3" class="data row2 col3" >0.9576</td>
#                         <td id="T_f0a07_row2_col4" class="data row2 col4" >0.4854</td>
#                         <td id="T_f0a07_row2_col5" class="data row2 col5" >0.4995</td>
#             </tr>
#             <tr>
#                         <th id="T_f0a07_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_f0a07_row3_col0" class="data row3 col0" >9536.9990</td>
#                         <td id="T_f0a07_row3_col1" class="data row3 col1" >193088342.6089</td>
#                         <td id="T_f0a07_row3_col2" class="data row3 col2" >13895.6231</td>
#                         <td id="T_f0a07_row3_col3" class="data row3 col3" >0.9431</td>
#                         <td id="T_f0a07_row3_col4" class="data row3 col4" >0.4713</td>
#                         <td id="T_f0a07_row3_col5" class="data row3 col5" >0.4706</td>
#             </tr>
#             <tr>
#                         <th id="T_f0a07_level0_row4" class="row_heading level0 row4" >Mean</th>
#                         <td id="T_f0a07_row4_col0" class="data row4 col0" >9636.7407</td>
#                         <td id="T_f0a07_row4_col1" class="data row4 col1" >193415941.2508</td>
#                         <td id="T_f0a07_row4_col2" class="data row4 col2" >13836.3429</td>
#                         <td id="T_f0a07_row4_col3" class="data row4 col3" >0.9457</td>
#                         <td id="T_f0a07_row4_col4" class="data row4 col4" >0.4758</td>
#                         <td id="T_f0a07_row4_col5" class="data row4 col5" >0.4787</td>
#             </tr>
#             <tr>
#                         <th id="T_f0a07_level0_row5" class="row_heading level0 row5" >SD</th>
#                         <td id="T_f0a07_row5_col0" class="data row5 col0" >543.8865</td>
#                         <td id="T_f0a07_row5_col1" class="data row5 col1" >37507369.8845</td>
#                         <td id="T_f0a07_row5_col2" class="data row5 col2" >1404.1217</td>
#                         <td id="T_f0a07_row5_col3" class="data row5 col3" >0.0080</td>
#                         <td id="T_f0a07_row5_col4" class="data row5 col4" >0.0241</td>
#                         <td id="T_f0a07_row5_col5" class="data row5 col5" >0.0355</td>
#             </tr>
#     </tbody></table>

# %%
kosdaq_pred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 925 entries, 0 to 924
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    925 non-null    datetime64[ns]
#  1   code    925 non-null    object
#  2   close   925 non-null    float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 28.9+ KB

# %% [markdown]
# ### KOSPI, KOSDAQ 예측값 합치기

# %%
all_data = pd.concat([kospi_pred,kosdaq_pred])
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1850 entries, 0 to 924
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1850 non-null   datetime64[ns]
#  1   code    1850 non-null   object
#  2   close   1850 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 57.8+ KB

# %%
all_data = all_data.sort_values('Date')
all_data = all_data.reset_index().drop('index', axis=1)
all_data
# Out:
#            Date    code          close
# 0    2021-11-01  005930   59024.119220
# 1    2021-11-01  215200   75285.819229
# 2    2021-11-01  112040   93995.504732
# 3    2021-11-01  067630   24002.295991
# 4    2021-11-01  218410   25544.179190
# ...         ...     ...            ...
# 1845 2021-11-05  064350   46749.643188
# 1846 2021-11-05  004170  241524.943399
# 1847 2021-11-05  298050  683153.565087
# 1848 2021-11-05  153130   99477.192071
# 1849 2021-11-05  099320   41679.531559
#
# [1850 rows x 3 columns]

# %%
all_data['code'] = all_data['code'].astype(int)
all_data = all_data.sort_values(['code','Date'])
all_data
# Out:
#            Date    code         close
# 329  2021-11-01      60  33879.194865
# 595  2021-11-02      60  33750.773853
# 777  2021-11-03      60  43889.078001
# 1332 2021-11-04      60  41348.023605
# 1807 2021-11-05      60  31360.235247
# ...         ...     ...           ...
# 11   2021-11-01  950130  16477.537396
# 542  2021-11-02  950130  19719.678121
# 1096 2021-11-03  950130  23634.813986
# 1279 2021-11-04  950130  17047.446498
# 1490 2021-11-05  950130  19911.318794
#
# [1850 rows x 3 columns]

# %%
all_data = all_data.reset_index().drop('index', axis=1)
all_data
# Out:
#            Date    code         close
# 0    2021-11-01      60  33879.194865
# 1    2021-11-02      60  33750.773853
# 2    2021-11-03      60  43889.078001
# 3    2021-11-04      60  41348.023605
# 4    2021-11-05      60  31360.235247
# ...         ...     ...           ...
# 1845 2021-11-01  950130  16477.537396
# 1846 2021-11-02  950130  19719.678121
# 1847 2021-11-03  950130  23634.813986
# 1848 2021-11-04  950130  17047.446498
# 1849 2021-11-05  950130  19911.318794
#
# [1850 rows x 3 columns]

# %%
all_data['code'] = all_data['code'].astype(str).str.zfill(6)
all_data.head()
# Out:
#         Date    code         close
# 0 2021-11-01  000060  33879.194865
# 1 2021-11-02  000060  33750.773853
# 2 2021-11-03  000060  43889.078001
# 3 2021-11-04  000060  41348.023605
# 4 2021-11-05  000060  31360.235247

# %%
all_data_pivot = all_data.pivot_table(index=['Date'], columns =['code'], values=['close'])

# %%
all_data_pivot
# Out:
#                    close                                             \
# code              000060        000080        000100         000120
# Date
# 2021-11-01  33879.194865  35886.182408  62770.685640  140540.792275
# 2021-11-02  33750.773853  36395.650783  61488.415662  136085.006018
# 2021-11-03  43889.078001  48132.985225  73507.788569  148908.645305
# 2021-11-04  41348.023605  43848.526307  69275.391445  142169.167650
# 2021-11-05  31360.235247  32484.981538  62234.421660  137571.510267
#
#                                                                      \
# code               000150        000240        000250        000270
# Date
# 2021-11-01   95346.984625  29261.693390  45152.532758  77160.032384
# 2021-11-02   95862.827693  28712.198589  46702.227509  78492.520197
# 2021-11-03  106666.790643  42473.959209  47102.460469  91619.835816
# 2021-11-04  100564.826068  31127.755873  46470.104781  81361.125261
# 2021-11-05  101957.371336  32370.902650  46849.663762  79122.845175
#
#                                           ...                              \
# code               000660         000670  ...        330860        336260
# Date                                      ...
# 2021-11-01  102793.989628  611726.650010  ...  46455.430904  43055.131506
# 2021-11-02  110090.041385  703696.566765  ...  47984.563507  52338.233353
# 2021-11-03  115055.396751  678125.915021  ...  50076.703036  44127.704524
# 2021-11-04  114672.239653  662962.982156  ...  47150.302742  58034.225908
# 2021-11-05  106692.425768  666732.980809  ...  48676.268032  52035.214020
#
#                                                                     \
# code              336370        347860        348150        348210
# Date
# 2021-11-01  75417.303160  31692.496441  30191.540393  49104.064770
# 2021-11-02  86791.857535  33940.836849  31029.658596  52010.982925
# 2021-11-03  81348.622370  36284.188304  32645.838179  54830.933253
# 2021-11-04  87056.477211  33212.745024  29753.985988  50617.409705
# 2021-11-05  90320.743635  34512.115454  30886.561166  49373.669249
#
#
# code               352820         357780        363280        950130
# Date
# 2021-11-01  266591.854254  257177.183421  29730.174735  16477.537396
# 2021-11-02  321347.449953  249839.430573  37304.071672  19719.678121
# 2021-11-03  302528.058420  242332.106912  34604.476952  23634.813986
# 2021-11-04  277610.087293  256940.518607  42486.568406  17047.446498
# 2021-11-05  313808.646618  252345.030351  33732.641337  19911.318794
#
# [5 rows x 370 columns]

# %%
all_data_pivot.columns = all_data_pivot.columns.droplevel(0)
all_data_pivot
# Out:
# code              000060        000080        000100         000120  \
# Date
# 2021-11-01  33879.194865  35886.182408  62770.685640  140540.792275
# 2021-11-02  33750.773853  36395.650783  61488.415662  136085.006018
# 2021-11-03  43889.078001  48132.985225  73507.788569  148908.645305
# 2021-11-04  41348.023605  43848.526307  69275.391445  142169.167650
# 2021-11-05  31360.235247  32484.981538  62234.421660  137571.510267
#
# code               000150        000240        000250        000270  \
# Date
# 2021-11-01   95346.984625  29261.693390  45152.532758  77160.032384
# 2021-11-02   95862.827693  28712.198589  46702.227509  78492.520197
# 2021-11-03  106666.790643  42473.959209  47102.460469  91619.835816
# 2021-11-04  100564.826068  31127.755873  46470.104781  81361.125261
# 2021-11-05  101957.371336  32370.902650  46849.663762  79122.845175
#
# code               000660         000670  ...        330860        336260  \
# Date                                      ...
# 2021-11-01  102793.989628  611726.650010  ...  46455.430904  43055.131506
# 2021-11-02  110090.041385  703696.566765  ...  47984.563507  52338.233353
# 2021-11-03  115055.396751  678125.915021  ...  50076.703036  44127.704524
# 2021-11-04  114672.239653  662962.982156  ...  47150.302742  58034.225908
# 2021-11-05  106692.425768  666732.980809  ...  48676.268032  52035.214020
#
# code              336370        347860        348150        348210  \
# Date
# 2021-11-01  75417.303160  31692.496441  30191.540393  49104.064770
# 2021-11-02  86791.857535  33940.836849  31029.658596  52010.982925
# 2021-11-03  81348.622370  36284.188304  32645.838179  54830.933253
# 2021-11-04  87056.477211  33212.745024  29753.985988  50617.409705
# 2021-11-05  90320.743635  34512.115454  30886.561166  49373.669249
#
# code               352820         357780        363280        950130
# Date
# 2021-11-01  266591.854254  257177.183421  29730.174735  16477.537396
# 2021-11-02  321347.449953  249839.430573  37304.071672  19719.678121
# 2021-11-03  302528.058420  242332.106912  34604.476952  23634.813986
# 2021-11-04  277610.087293  256940.518607  42486.568406  17047.446498
# 2021-11-05  313808.646618  252345.030351  33732.641337  19911.318794
#
# [5 rows x 370 columns]

# %%
all_data_pivot.to_csv('prac_4w_pred_1w_cat.csv', index=False)

# %% [markdown]
# # 데이터 불러오기(두번째 주)
# * 훈련 : 11.01 ~ 11.26
# * 예측 : 11.29 ~ 12.03

# %%
start_date = '2021-11-01'
end_date = '2021-11-26'

# %% [markdown]
# ### train set2

# %%
code_data = fdr.DataReader(code, start = start_date, end = end_date)[['Close']].reset_index()
code_data = pd.merge(Business_days, code_data, how = 'outer')

# %%
data2 = pd.read_csv('../data/20210104-20211126_stock_index.csv')

# %%
data2.info()

# %%
data2['Date'] = pd.to_datetime(data2['Date'])
data2.info()

# %%
data2.tail()

# %%
data2['weeknum'] = data2['Date'].dt.weekofyear
data2['weekday'] = data2['Date'].dt.weekday
data2.head()

# %%
data2 = data2[['Date', 'weeknum', 'weekday', 'kosdaq', 'nasdaq', 'dow', 'sp500', 'kospi']]

# %%
data2.head()

# %%
train2 = data2[(data2['Date'] >= start_date) & (data2['Date'] <= end_date)]
train2.head()

# %%
train2.tail()

# %%
train2 = train2.reset_index()
train2 = train2.drop('index', axis=1)
train2.head()

# %%
train2.info()

# %%
# 종목 코드 6자리로 맞추기
stock_list['종목코드'] = stock_list['종목코드'].astype(str).str.zfill(6)

# %%
stock_list.head()

# %% [markdown]
# ### test set

# %%
Business_days = pd.DataFrame(pd.date_range(start='2021-11-29', end='2021-12-03', freq='B'), columns=['Date'])
test2 = Business_days
test2['weeknum'] = test2['Date'].dt.weekofyear
test2['weekday'] = test2['Date'].dt.weekday
test2.head()

# %%
test2.info()

# %% [markdown]
# ## 3가지 날짜 특성으로 5가지 외부 특성 순서대로 예측하기

# %%
features = ['Date', 'weeknum', 'weekday', 'kosdaq', 'nasdaq', 'sp500', 'dow', 'kospi']

for i in tqdm(range(4)):
    model = setup(train2, target = features[i+3], ignore_features = features[i+4:], fold=4, fold_shuffle=True,
                  silent=True, use_gpu=True)
    top1_model = compare_models(sort='MAPE', n_select=1, exclude=['knn','huber','llar','omp','par'])
    final_model = finalize_model(top1_model)
    pred = predict_model(final_model, test2)

    test2[features[i+3]] = pred['Label']

# %%
pred_test2 = test2
pred_test2

# %%
pred_test2.to_csv('prac_4w_pred_1w_test2.csv', index=False)

# %% [markdown]
# ## 8가지 특성으로 종가 예측하기

# %%
days1 = ['2021-10-29', '2021-11-01', '2021-11-02', '2021-11-03', '2021-11-04', '2021-11-05']
stock_pred_set1 = {}
Business_days = pd.DataFrame(pd.date_range(start_date,end_date,freq='B'), columns = ['Date'])

for code in tqdm(stock_list['종목코드'].values):
    code_data = fdr.DataReader(code, start = start_date, end = end_date)[['Close']].reset_index()
    code_data = pd.merge(Business_days, code_data, how = 'outer')
    train1['Close'] = code_data['Close']
    temp_pred_test = pd.DataFrame()
    for d in range(5):
        train_end_day = d
        test_day = d+1
        temp_train = train1[train1['Date'] <= days1[train_end_day]]
        temp_test = pred_test1[pred_test1['Date'] == days1[test_day]]

        model = setup(temp_train, target = 'Close', silent=True, fold=4, fold_shuffle=True, use_gpu=True)
        top1_model = compare_models(sort='MAPE', n_select=1, exclude=['knn','huber','llar','omp','par'])
        final_model = finalize_model(top1_model)
        pred = predict_model(final_model, temp_test)
        temp_test[code] = pred['Label']
        temp_pred_test = pd.concat([temp_pred_test, temp_test])
    
    stock_pred_set1[code] = temp_pred_test[code]

# %%
len(stock_pred_set1)

# %%
pred1 = pd.DataFrame(stock_pred_set1)
pred1.head()

# %% [markdown]
# # 제출 파일 만들기

# %%
sub = pd.read_csv('../data/sample_submission.csv')
sub

# %%
sub.info()

# %%
for code in tqdm(sub.columns.values[1:]):
    temp = list(stock_pred_dict1[code]) + list(stock_pred_dict2[code])
    sub[code] = temp

# %%
sub

# %%
sub.info()

# %%
sub.to_csv('sub05_pycaret04.csv', index=False)
