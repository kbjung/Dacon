# %%
import os
import FinanceDataReader as fdr
from tqdm import tqdm
import pandas as pd

# %% [markdown]
# # Pycaret 이용

# %% [markdown]
# ## 모든 종목 예측

# %% [markdown]
# * 종가와 상관계수 높은 특성 : KOSDAQ(0.87), KOSPI(0.79), DOW(0.58), NASDAQ(0.50), S&P500(0.56)
# * 예측 순서(종가와 상관계수 높은 특성 먼저 예측)
#     * weekday, weeknumdm로 KOSDAQ 예측(종가와 상관계수 0.87)
#     * weekday, weeknum, KOSDAQ으로 NASDAQ 예측(KOSDAQ과 상관계수 0.68)
#     * weekday, weeknum, KOSDAQ, NASDAQ으로 S&P500 예측(NASDAQ과 상관계수 0.93)
#     * weekday, weeknum, KOSDAQ, NASDAQ, S&P500으로 DOW 예측(S&P500과 상관계수 0.95)
#     * weekday, weeknum, KOSDAQ, NASDAQ, S&P500, DOW로 KOSPI 예측
#     * weekday, weeknum, KOSDAQ, NASDAQ, S&P500, DOW, KOSPI로 다른 종가 예측

# %%
# 제출 점수 :

# %%
from pycaret.regression import *

# %% [markdown]
# # 데이터 불러오기

# %% [markdown]
# ## 외부 데이터 가져오기

# %%
# 외부 데이터 가져오기
df = pd.read_csv('../data/20210104_20211119_data_interpolate.csv')
df.head()
# Out:
#          Date  exchange_rate    kospi  kosdaq  kospi100       dow   nasdaq  \
# 0  2021-01-04        1086.48  2944.45  977.62   3052.74  30223.89  12698.4
# 1  2021-01-05        1086.42  2990.57  985.76   3099.42  30391.60  12819.0
# 2  2021-01-06        1087.93  2968.21  981.39   3070.05  30829.40  12740.8
# 3  2021-01-07        1094.28  3031.68  988.86   3139.48  31041.13  13067.5
# 4  2021-01-08        1092.93  3152.18  987.79   3293.96  31097.97  13202.0
#
#      sp500  미국채10년-2년         BTC   Gold    Oil  US10Y    US2Y
# 0  3700.65     0.8009  36499000.0  37.10  32.38  0.918  0.1171
# 1  3726.86     0.8320  37962000.0  37.18  33.94  0.955  0.1230
# 2  3748.14     0.9002  40731000.0  36.60  34.11  1.039  0.1388
# 3  3803.79     0.9402  44575000.0  36.48  34.53  1.081  0.1408
# 4  3824.68     0.9821  47241000.0  35.26  35.43  1.119  0.1369

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230 entries, 0 to 229
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           230 non-null    object
#  1   exchange_rate  230 non-null    float64
#  2   kospi          230 non-null    float64
#  3   kosdaq         230 non-null    float64
#  4   kospi100       230 non-null    float64
#  5   dow            230 non-null    float64
#  6   nasdaq         230 non-null    float64
#  7   sp500          230 non-null    float64
#  8   미국채10년-2년      230 non-null    float64
#  9   BTC            230 non-null    float64
#  10  Gold           230 non-null    float64
#  11  Oil            230 non-null    float64
#  12  US10Y          230 non-null    float64
#  13  US2Y           230 non-null    float64
# dtypes: float64(13), object(1)
# memory usage: 25.3+ KB

# %%
df.columns
# Out:
# Index(['Date', 'exchange_rate', 'kospi', 'kosdaq', 'kospi100', 'dow', 'nasdaq',
#        'sp500', '미국채10년-2년', 'BTC', 'Gold', 'Oil', 'US10Y', 'US2Y'],
#       dtype='object')

# %% [markdown]
# ### 필요한 특성만 추출

# %%
df = df[['Date','kosdaq','nasdaq','sp500','dow','kospi']]
df.head()
# Out:
#          Date  kosdaq   nasdaq    sp500       dow    kospi
# 0  2021-01-04  977.62  12698.4  3700.65  30223.89  2944.45
# 1  2021-01-05  985.76  12819.0  3726.86  30391.60  2990.57
# 2  2021-01-06  981.39  12740.8  3748.14  30829.40  2968.21
# 3  2021-01-07  988.86  13067.5  3803.79  31041.13  3031.68
# 4  2021-01-08  987.79  13202.0  3824.68  31097.97  3152.18

# %%
# 요일 번호와 주 번호 지정하여 열로 추가하기
df['Date'] = pd.to_datetime(df['Date'])
df['weekday'] = df['Date'].apply(lambda x : x.weekday())
df['weeknum'] = df['Date'].apply(lambda x : x.strftime('%V'))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230 entries, 0 to 229
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     230 non-null    datetime64[ns]
#  1   kosdaq   230 non-null    float64
#  2   nasdaq   230 non-null    float64
#  3   sp500    230 non-null    float64
#  4   dow      230 non-null    float64
#  5   kospi    230 non-null    float64
#  6   weekday  230 non-null    int64
#  7   weeknum  230 non-null    object
# dtypes: datetime64[ns](1), float64(5), int64(1), object(1)
# memory usage: 14.5+ KB

# %%
df.columns
# Out:
# Index(['Date', 'kosdaq', 'nasdaq', 'sp500', 'dow', 'kospi', 'weekday',
#        'weeknum'],
#       dtype='object')

# %%
df = df[['Date', 'weekday', 'weeknum','kosdaq', 'nasdaq', 'sp500', 'dow', 'kospi']]
df.head()
# Out:
#         Date  weekday weeknum  kosdaq   nasdaq    sp500       dow    kospi
# 0 2021-01-04        0      01  977.62  12698.4  3700.65  30223.89  2944.45
# 1 2021-01-05        1      01  985.76  12819.0  3726.86  30391.60  2990.57
# 2 2021-01-06        2      01  981.39  12740.8  3748.14  30829.40  2968.21
# 3 2021-01-07        3      01  988.86  13067.5  3803.79  31041.13  3031.68
# 4 2021-01-08        4      01  987.79  13202.0  3824.68  31097.97  3152.18

# %% [markdown]
# ### 훈련, 테스트 셋 나누기

# %%
start_date = '2021-10-04'
end_date = '2021-10-29'

# %%
train = df[(df['Date'] <= end_date) & (df['Date'] >= start_date)]
test =  df[(df['Date'] <= '2021-11-05') & (df['Date'] >= '2021-11-01')]

# %%
train = train.reset_index()
train = train.drop('index',axis=1)

# %%
train.shape, test.shape
# Out:
# ((20, 8), (5, 8))

# %%
train.head()
# Out:
#         Date  weekday weeknum   kosdaq   nasdaq    sp500       dow     kospi
# 0 2021-10-04        0      40  969.285  14255.5  4300.46  34003.58  2990.675
# 1 2021-10-05        1      40  955.370  14433.8  4345.72  34315.99  2962.170
# 2 2021-10-06        2      40  922.360  14501.9  4363.55  34417.98  2908.310
# 3 2021-10-07        3      40  953.430  14654.0  4399.76  34754.15  2959.460
# 4 2021-10-08        4      40  953.110  14579.5  4391.36  34746.71  2956.300

# %%
train.tail()
# Out:
#          Date  weekday weeknum   kosdaq   nasdaq    sp500       dow    kospi
# 15 2021-10-25        0      43   994.31  15226.7  4566.48  35743.78  3020.54
# 16 2021-10-26        1      43  1011.76  15235.7  4574.79  35755.83  3049.08
# 17 2021-10-27        2      43  1008.95  15235.8  4551.68  35491.48  3025.49
# 18 2021-10-28        3      43  1000.13  15448.1  4596.42  35729.89  3009.55
# 19 2021-10-29        4      43   992.33  15498.4  4605.38  35819.59  2970.68

# %%
test.head()
# Out:
#           Date  weekday weeknum   kosdaq   nasdaq    sp500       dow    kospi
# 215 2021-11-01        0      44   998.57  15595.9  4613.67  35913.68  2978.94
# 216 2021-11-02        1      44  1009.44  15649.6  4630.65  36053.09  3013.49
# 217 2021-11-03        2      44  1005.00  15811.6  4660.57  36157.02  2975.71
# 218 2021-11-04        3      44  1001.43  15940.3  4680.06  36124.66  2983.22
# 219 2021-11-05        4      44  1001.35  15971.6  4697.53  36329.07  2969.27

# %%
test = test[['Date', 'weekday', 'weeknum']]
test
# Out:
#           Date  weekday weeknum
# 215 2021-11-01        0      44
# 216 2021-11-02        1      44
# 217 2021-11-03        2      44
# 218 2021-11-04        3      44
# 219 2021-11-05        4      44

# %% [markdown]
# ## 종목 정보 가져오기

# %%
# 종목 정보 가져오기
path = '../data'
list_name = 'Stock_List.csv'
stock_list = pd.read_csv(os.path.join(path,list_name))
stock_list.head()
# Out:
#         종목명    종목코드   상장시장
# 0      삼성전자    5930  KOSPI
# 1    SK하이닉스     660  KOSPI
# 2     NAVER   35420  KOSPI
# 3       카카오   35720  KOSPI
# 4  삼성바이오로직스  207940  KOSPI

# %%
stock_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 370 entries, 0 to 369
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   종목명     370 non-null    object
#  1   종목코드    370 non-null    int64
#  2   상장시장    370 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 8.8+ KB

# %%
# 종목 코드 6자리로 맞추기
stock_list['종목코드'] = stock_list["종목코드"].astype(str).str.zfill(6)
stock_list.head()
# Out:
#         종목명    종목코드   상장시장
# 0      삼성전자  005930  KOSPI
# 1    SK하이닉스  000660  KOSPI
# 2     NAVER  035420  KOSPI
# 3       카카오  035720  KOSPI
# 4  삼성바이오로직스  207940  KOSPI

# %% [markdown]
# # 종가 예측

# %% [markdown]
# * 1. kosdaq 예측
# * 2. nasdaq
# * 3. sp500
# * 4. dow
# * 5. kospi
# * 6. 종가

# %%
train.head()
# Out:
#         Date  weekday weeknum   kosdaq   nasdaq    sp500       dow     kospi
# 0 2021-10-04        0      40  969.285  14255.5  4300.46  34003.58  2990.675
# 1 2021-10-05        1      40  955.370  14433.8  4345.72  34315.99  2962.170
# 2 2021-10-06        2      40  922.360  14501.9  4363.55  34417.98  2908.310
# 3 2021-10-07        3      40  953.430  14654.0  4399.76  34754.15  2959.460
# 4 2021-10-08        4      40  953.110  14579.5  4391.36  34746.71  2956.300

# %%
train.to_csv('20211004_29_train.csv', index=False)

# %%
test
# Out:
#           Date  weekday weeknum
# 215 2021-11-01        0      44
# 216 2021-11-02        1      44
# 217 2021-11-03        2      44
# 218 2021-11-04        3      44
# 219 2021-11-05        4      44

# %% [markdown]
# ### 테스트셋의 5가지 특성 예측 하기

# %%
features = ['Date', 'weekday', 'weeknum','kosdaq', 'nasdaq', 'sp500', 'dow', 'kospi']
for i in range(5):
    model = setup(train, target = features[i+3], ignore_features = features[i+4:], fold=4, fold_shuffle=True, silent=True)
    tuned_model = tune_model(compare_models(sort='MAPE', n_select=1))
    final_model = finalize_model(tuned_model)
    end_features = features[:i+3]
    pred = predict_model(final_model, test)
    test[features[i+3]] = pred['Label']
# Out:
# <style  type="text/css" >
# #T_7fa98_row4_col0,#T_7fa98_row4_col1,#T_7fa98_row4_col2,#T_7fa98_row4_col3,#T_7fa98_row4_col4,#T_7fa98_row4_col5{
#             background:  yellow;
#         }</style><table id="T_7fa98_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7fa98_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_7fa98_row0_col0" class="data row0 col0" >6.5614</td>
#                         <td id="T_7fa98_row0_col1" class="data row0 col1" >59.1036</td>
#                         <td id="T_7fa98_row0_col2" class="data row0 col2" >7.6879</td>
#                         <td id="T_7fa98_row0_col3" class="data row0 col3" >0.9767</td>
#                         <td id="T_7fa98_row0_col4" class="data row0 col4" >0.0026</td>
#                         <td id="T_7fa98_row0_col5" class="data row0 col5" >0.0022</td>
#             </tr>
#             <tr>
#                         <th id="T_7fa98_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_7fa98_row1_col0" class="data row1 col0" >7.0384</td>
#                         <td id="T_7fa98_row1_col1" class="data row1 col1" >71.3379</td>
#                         <td id="T_7fa98_row1_col2" class="data row1 col2" >8.4462</td>
#                         <td id="T_7fa98_row1_col3" class="data row1 col3" >0.9518</td>
#                         <td id="T_7fa98_row1_col4" class="data row1 col4" >0.0028</td>
#                         <td id="T_7fa98_row1_col5" class="data row1 col5" >0.0023</td>
#             </tr>
#             <tr>
#                         <th id="T_7fa98_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_7fa98_row2_col0" class="data row2 col0" >9.4792</td>
#                         <td id="T_7fa98_row2_col1" class="data row2 col1" >190.4328</td>
#                         <td id="T_7fa98_row2_col2" class="data row2 col2" >13.7997</td>
#                         <td id="T_7fa98_row2_col3" class="data row2 col3" >0.6589</td>
#                         <td id="T_7fa98_row2_col4" class="data row2 col4" >0.0046</td>
#                         <td id="T_7fa98_row2_col5" class="data row2 col5" >0.0032</td>
#             </tr>
#             <tr>
#                         <th id="T_7fa98_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_7fa98_row3_col0" class="data row3 col0" >9.8656</td>
#                         <td id="T_7fa98_row3_col1" class="data row3 col1" >266.8352</td>
#                         <td id="T_7fa98_row3_col2" class="data row3 col2" >16.3351</td>
#                         <td id="T_7fa98_row3_col3" class="data row3 col3" >-2.8068</td>
#                         <td id="T_7fa98_row3_col4" class="data row3 col4" >0.0055</td>
#                         <td id="T_7fa98_row3_col5" class="data row3 col5" >0.0033</td>
#             </tr>
#             <tr>
#                         <th id="T_7fa98_level0_row4" class="row_heading level0 row4" >Mean</th>
#                         <td id="T_7fa98_row4_col0" class="data row4 col0" >8.2362</td>
#                         <td id="T_7fa98_row4_col1" class="data row4 col1" >146.9274</td>
#                         <td id="T_7fa98_row4_col2" class="data row4 col2" >11.5672</td>
#                         <td id="T_7fa98_row4_col3" class="data row4 col3" >-0.0549</td>
#                         <td id="T_7fa98_row4_col4" class="data row4 col4" >0.0039</td>
#                         <td id="T_7fa98_row4_col5" class="data row4 col5" >0.0027</td>
#             </tr>
#             <tr>
#                         <th id="T_7fa98_level0_row5" class="row_heading level0 row5" >SD</th>
#                         <td id="T_7fa98_row5_col0" class="data row5 col0" >1.4526</td>
#                         <td id="T_7fa98_row5_col1" class="data row5 col1" >86.1647</td>
#                         <td id="T_7fa98_row5_col2" class="data row5 col2" >3.6231</td>
#                         <td id="T_7fa98_row5_col3" class="data row5 col3" >1.5937</td>
#                         <td id="T_7fa98_row5_col4" class="data row5 col4" >0.0012</td>
#                         <td id="T_7fa98_row5_col5" class="data row5 col5" >0.0005</td>
#             </tr>
#     </tbody></table>

# %%
test
# Out:
#           Date  weekday weeknum      kosdaq        nasdaq        sp500  \
# 215 2021-11-01        0      44  972.099426  14971.576678  4483.729492
# 216 2021-11-02        1      44  972.519958  14975.816364  4484.821289
# 217 2021-11-03        2      44  971.229126  14958.857623  4480.517090
# 218 2021-11-04        3      44  973.408752  14980.056049  4485.989258
# 219 2021-11-05        4      44  973.426453  14980.056049  4486.321289
#
#               dow        kospi
# 215  35186.917969  2974.400879
# 216  35193.468750  2974.633301
# 217  35167.761719  2972.511230
# 218  35200.984375  2977.358887
# 219  35205.234375  2974.027344

# %%
test.to_csv('20211004_29_pred_1101_05_test.csv', index=False)

# %%
test = pd.read_csv('20211004_29_pred_1101_05_test.csv')
test
# Out:
#          Date  weekday  weeknum     kosdaq        nasdaq      sp500  \
# 0  2021-11-01        0       44  972.09940  14971.576678  4483.7295
# 1  2021-11-02        1       44  972.51996  14975.816364  4484.8213
# 2  2021-11-03        2       44  971.22910  14958.857623  4480.5170
# 3  2021-11-04        3       44  973.40875  14980.056049  4485.9893
# 4  2021-11-05        4       44  973.42645  14980.056049  4486.3213
#
#          dow      kospi
# 0  35186.918  2974.4010
# 1  35193.470  2974.6333
# 2  35167.760  2972.5112
# 3  35200.984  2977.3590
# 4  35205.234  2974.0273

# %%
train.head()
# Out:
#         Date  weekday weeknum   kosdaq   nasdaq    sp500       dow     kospi
# 0 2021-10-04        0      40  969.285  14255.5  4300.46  34003.58  2990.675
# 1 2021-10-05        1      40  955.370  14433.8  4345.72  34315.99  2962.170
# 2 2021-10-06        2      40  922.360  14501.9  4363.55  34417.98  2908.310
# 3 2021-10-07        3      40  953.430  14654.0  4399.76  34754.15  2959.460
# 4 2021-10-08        4      40  953.110  14579.5  4391.36  34746.71  2956.300

# %%
stock_list['종목코드'].values[0]
# Out:
# '005930'

# %%
code_data = fdr.DataReader('005930', start = start_date, end = end_date)[['Close']].reset_index()
train['Close'] = code_data['Close']
train
# Out:
#          Date  weekday weeknum    kosdaq   nasdaq    sp500       dow  \
# 0  2021-10-04        0      40   969.285  14255.5  4300.46  34003.58
# 1  2021-10-05        1      40   955.370  14433.8  4345.72  34315.99
# 2  2021-10-06        2      40   922.360  14501.9  4363.55  34417.98
# 3  2021-10-07        3      40   953.430  14654.0  4399.76  34754.15
# 4  2021-10-08        4      40   953.110  14579.5  4391.36  34746.71
# 5  2021-10-11        0      41   946.630  14486.2  4361.19  34496.85
# 6  2021-10-12        1      41   940.150  14465.9  4350.64  34378.08
# 7  2021-10-13        2      41   953.470  14571.6  4363.80  34378.60
# 8  2021-10-14        3      41   983.430  14823.4  4438.23  34911.70
# 9  2021-10-15        4      41   990.540  14897.3  4471.37  35295.48
# 10 2021-10-18        0      42   993.860  15021.8  4486.48  35259.01
# 11 2021-10-19        1      42  1005.350  15129.1  4519.63  35458.37
# 12 2021-10-20        2      42  1001.620  15121.7  4536.19  35609.93
# 13 2021-10-21        3      42   993.700  15215.7  4549.78  35601.96
# 14 2021-10-22        4      42   995.070  15090.2  4544.90  35677.68
# 15 2021-10-25        0      43   994.310  15226.7  4566.48  35743.78
# 16 2021-10-26        1      43  1011.760  15235.7  4574.79  35755.83
# 17 2021-10-27        2      43  1008.950  15235.8  4551.68  35491.48
# 18 2021-10-28        3      43  1000.130  15448.1  4596.42  35729.89
# 19 2021-10-29        4      43   992.330  15498.4  4605.38  35819.59
#
#        kospi    Close
# 0   2990.675  72200.0
# 1   2962.170  71300.0
# 2   2908.310  71600.0
# 3   2959.460  71500.0
# 4   2956.300  69000.0
# 5   2936.340  68800.0
# 6   2916.380  69400.0
# 7   2944.410  70100.0
# 8   2988.640  70200.0
# 9   3015.060  70600.0
# 10  3006.680  70300.0
# 11  3029.040  70200.0
# 12  3013.130  70400.0
# 13  3007.330  70200.0
# 14  3006.160  71100.0
# 15  3020.540  70100.0
# 16  3049.080  70700.0
# 17  3025.490  69800.0
# 18  3009.550      NaN
# 19  2970.680      NaN

# %%
Business_days = pd.DataFrame(pd.date_range(start_date,end_date,freq='B'), columns = ['Date'])
code_data = fdr.DataReader('005930', start = start_date, end = end_date)[['Close']].reset_index()
code_data = pd.merge(Business_days, code_data, how = 'outer')
train['Close'] = code_data['Close']
train
# Out:
#          Date  weekday weeknum    kosdaq   nasdaq    sp500       dow  \
# 0  2021-10-04        0      40   969.285  14255.5  4300.46  34003.58
# 1  2021-10-05        1      40   955.370  14433.8  4345.72  34315.99
# 2  2021-10-06        2      40   922.360  14501.9  4363.55  34417.98
# 3  2021-10-07        3      40   953.430  14654.0  4399.76  34754.15
# 4  2021-10-08        4      40   953.110  14579.5  4391.36  34746.71
# 5  2021-10-11        0      41   946.630  14486.2  4361.19  34496.85
# 6  2021-10-12        1      41   940.150  14465.9  4350.64  34378.08
# 7  2021-10-13        2      41   953.470  14571.6  4363.80  34378.60
# 8  2021-10-14        3      41   983.430  14823.4  4438.23  34911.70
# 9  2021-10-15        4      41   990.540  14897.3  4471.37  35295.48
# 10 2021-10-18        0      42   993.860  15021.8  4486.48  35259.01
# 11 2021-10-19        1      42  1005.350  15129.1  4519.63  35458.37
# 12 2021-10-20        2      42  1001.620  15121.7  4536.19  35609.93
# 13 2021-10-21        3      42   993.700  15215.7  4549.78  35601.96
# 14 2021-10-22        4      42   995.070  15090.2  4544.90  35677.68
# 15 2021-10-25        0      43   994.310  15226.7  4566.48  35743.78
# 16 2021-10-26        1      43  1011.760  15235.7  4574.79  35755.83
# 17 2021-10-27        2      43  1008.950  15235.8  4551.68  35491.48
# 18 2021-10-28        3      43  1000.130  15448.1  4596.42  35729.89
# 19 2021-10-29        4      43   992.330  15498.4  4605.38  35819.59
#
#        kospi    Close
# 0   2990.675      NaN
# 1   2962.170  72200.0
# 2   2908.310  71300.0
# 3   2959.460  71600.0
# 4   2956.300  71500.0
# 5   2936.340      NaN
# 6   2916.380  69000.0
# 7   2944.410  68800.0
# 8   2988.640  69400.0
# 9   3015.060  70100.0
# 10  3006.680  70200.0
# 11  3029.040  70600.0
# 12  3013.130  70300.0
# 13  3007.330  70200.0
# 14  3006.160  70400.0
# 15  3020.540  70200.0
# 16  3049.080  71100.0
# 17  3025.490  70100.0
# 18  3009.550  70700.0
# 19  2970.680  69800.0

# %%
train = df[(df['Date'] <= end_date) & (df['Date'] >= start_date)]
train = train.reset_index()
train = train.drop('index',axis=1)
train
# Out:
#          Date  weekday weeknum    kosdaq   nasdaq    sp500       dow     kospi
# 0  2021-10-04        0      40   969.285  14255.5  4300.46  34003.58  2990.675
# 1  2021-10-05        1      40   955.370  14433.8  4345.72  34315.99  2962.170
# 2  2021-10-06        2      40   922.360  14501.9  4363.55  34417.98  2908.310
# 3  2021-10-07        3      40   953.430  14654.0  4399.76  34754.15  2959.460
# 4  2021-10-08        4      40   953.110  14579.5  4391.36  34746.71  2956.300
# 5  2021-10-11        0      41   946.630  14486.2  4361.19  34496.85  2936.340
# 6  2021-10-12        1      41   940.150  14465.9  4350.64  34378.08  2916.380
# 7  2021-10-13        2      41   953.470  14571.6  4363.80  34378.60  2944.410
# 8  2021-10-14        3      41   983.430  14823.4  4438.23  34911.70  2988.640
# 9  2021-10-15        4      41   990.540  14897.3  4471.37  35295.48  3015.060
# 10 2021-10-18        0      42   993.860  15021.8  4486.48  35259.01  3006.680
# 11 2021-10-19        1      42  1005.350  15129.1  4519.63  35458.37  3029.040
# 12 2021-10-20        2      42  1001.620  15121.7  4536.19  35609.93  3013.130
# 13 2021-10-21        3      42   993.700  15215.7  4549.78  35601.96  3007.330
# 14 2021-10-22        4      42   995.070  15090.2  4544.90  35677.68  3006.160
# 15 2021-10-25        0      43   994.310  15226.7  4566.48  35743.78  3020.540
# 16 2021-10-26        1      43  1011.760  15235.7  4574.79  35755.83  3049.080
# 17 2021-10-27        2      43  1008.950  15235.8  4551.68  35491.48  3025.490
# 18 2021-10-28        3      43  1000.130  15448.1  4596.42  35729.89  3009.550
# 19 2021-10-29        4      43   992.330  15498.4  4605.38  35819.59  2970.680

# %% [markdown]
# ## 8가지 특성으로 종목별 종가 예측

# %%
stock_pred_dict = {}
Business_days = pd.DataFrame(pd.date_range(start_date,end_date,freq='B'), columns = ['Date'])
for code in tqdm(stock_list['종목코드'].values):
    code_data = fdr.DataReader(code, start = start_date, end = end_date)[['Close']].reset_index()
    code_data = pd.merge(Business_days, code_data, how = 'outer')
    train['Close'] = code_data['Close']

    model=setup(train, target = 'Close', silent=True, fold=4, fold_shuffle=True)
    tuned_model = tune_model(
        compare_models(sort='MAPE', n_select=1, 
    exclude=['knn','huber','llar','omp','par'])
    )
    tuned_model_ = finalize_model(tuned_model)
    pred = predict_model(tuned_model_, test)
    
    stock_pred_dict[code] = pred['Label']
# Out:
# <style  type="text/css" >
# #T_937d7_row3_col1,#T_937d7_row42_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_937d7_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_937d7_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_937d7_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_937d7_row0_col1" class="data row0 col1" >6102</td>
#             </tr>
#             <tr>
#                         <th id="T_937d7_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_937d7_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_937d7_row1_col1" class="data row1 col1" >Close</td>
#             </tr>
#             <tr>
#                         <th id="T_937d7_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_937d7_row2_col0" class="data row2 col0" >Original Data</td>
#                         <td id="T_937d7_row2_col1" class="data row2 col1" >(20, 9)</td>
#             </tr>
#             <tr>
#                         <th id="T_937d7_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_937d7_row3_col0" class="data row3 col0" >Missing Values</td>
#                         <td id="T_937d7_row3_col1" class="data row3 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_937d7_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_937d7_row4_col0" class="data row4 col0" >Numeric Features</td>
#                         <td id="T_937d7_row4_col1" class="data row4 col1" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_937d7_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_937d7_row5_col0" class="data row5 col0" >Categorical Features</td>
#                         <td id="T_937d7_row5_col1" class="data row5 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_937d7_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_937d7_row6_col0" class="data row6 col0" >Ordinal Features</td>
#                         <td id="T_937d7_row6_col1" class="data row6 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_937d7_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_937d7_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#                         <td id="T_937d7_row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_937d7_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_937d7_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#                         <td id="T_937d7_row8_col1" class="data row8 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_937d7_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_937d7_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#                         <td id="T_937d7_row9_col1" class="data row9 col1" >(12, 17)</td>
#             </tr>
#             <tr>
#                         <th id="T_937d7_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_937d7_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#                         <td id="T_937d7_row10_col1" class="data row10 col1" >(6, 17)</td>
#             </tr>
#             <tr>
#                         <th id="T_937d7_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_937d7_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#                         <td id="T_937d7_row11_col1" class="data row11 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_937d7_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_937d7_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#                         <td id="T_937d7_row12_col1" class="data row12 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_937d7_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_937d7_row13_col0" class="data row13 col0" >Fold Generator</td>
#                         <td id="T_937d7_row13_col1" class="data row13 col1" >KFold</td>
#             </tr>
#             <tr>
#                         <th id="T_937d7_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_937d7_row14_col0" class="data row14 col0" >Fold Number</td>
#                         <td id="T_937d7_row14_col1" class="data row14 col1" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_937d7_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_937d7_row15_col0" class="data row15 col0" >CPU Jobs</td>
#                         <td id="T_937d7_row15_col1" class="data row15 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_937d7_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_937d7_row16_col0" class="data row16 col0" >Use GPU</td>
#                         <td id="T_937d7_row16_col1" class="data row16 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_937d7_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_937d7_row17_col0" class="data row17 col0" >Log Experiment</td>
#                         <td id="T_937d7_row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_937d7_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_937d7_row18_col0" class="data row18 col0" >Experiment Name</td>
#                         <td id="T_937d7_row18_col1" class="data row18 col1" >reg-default-name</td>
#             </tr>
#             <tr>
#                         <th id="T_937d7_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_937d7_row19_col0" class="data row19 col0" >USI</td>
#                         <td id="T_937d7_row19_col1" class="data row19 col1" >337a</td>
#             </tr>
#             <tr>
#                         <th id="T_937d7_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_937d7_row20_col0" class="data row20 col0" >Imputation Type</td>
#                         <td id="T_937d7_row20_col1" class="data row20 col1" >simple</td>
#             </tr>
#             <tr>
#                         <th id="T_937d7_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_937d7_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#                         <td id="T_937d7_row21_col1" class="data row21 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_937d7_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_937d7_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#                         <td id="T_937d7_row22_col1" class="data row22 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_937d7_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_937d7_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#                         <td id="T_937d7_row23_col1" class="data row23 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_937d7_level0_row24" class="row_heading le
# IntProgress(value=0, description='Processing: ', max=74)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .            12:47:31
# Status     . . . . . . . . . . . . . . . . . .     Fitting 4 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  CatBoost Regressor
# <style  type="text/css" >
#     #T_2fee7_ th {
#           text-align: left;
#     }#T_2fee7_row0_col0,#T_2fee7_row0_col1,#T_2fee7_row0_col2,#T_2fee7_row0_col3,#T_2fee7_row0_col4,#T_2fee7_row0_col5,#T_2fee7_row0_col6,#T_2fee7_row0_col7,#T_2fee7_row1_col0,#T_2fee7_row1_col1,#T_2fee7_row1_col2,#T_2fee7_row1_col3,#T_2fee7_row1_col4,#T_2fee7_row1_col5,#T_2fee7_row1_col6,#T_2fee7_row1_col7,#T_2fee7_row2_col0,#T_2fee7_row2_col1,#T_2fee7_row2_col2,#T_2fee7_row2_col3,#T_2fee7_row2_col4,#T_2fee7_row2_col5,#T_2fee7_row2_col6,#T_2fee7_row2_col7,#T_2fee7_row3_col0,#T_2fee7_row3_col1,#T_2fee7_row3_col2,#T_2fee7_row3_col3,#T_2fee7_row3_col4,#T_2fee7_row3_col5,#T_2fee7_row3_col6,#T_2fee7_row3_col7,#T_2fee7_row4_col0,#T_2fee7_row4_col1,#T_2fee7_row4_col2,#T_2fee7_row4_col3,#T_2fee7_row4_col4,#T_2fee7_row4_col5,#T_2fee7_row4_col6,#T_2fee7_row4_col7,#T_2fee7_row5_col0,#T_2fee7_row5_col1,#T_2fee7_row5_col2,#T_2fee7_row5_col3,#T_2fee7_row5_col4,#T_2fee7_row5_col5,#T_2fee7_row5_col6,#T_2fee7_row5_col7,#T_2fee7_row6_col0,#T_2fee7_row6_col1,#T_2fee7_row6_col2,#T_2fee7_row6_col3,#T_2fee7_row6_col4,#T_2fee7_row6_col5,#T_2fee7_row6_col6,#T_2fee7_row6_col7,#T_2fee7_row7_col0,#T_2fee7_row7_col1,#T_2fee7_row7_col2,#T_2fee7_row7_col3,#T_2fee7_row7_col4,#T_2fee7_row7_col5,#T_2fee7_row7_col6,#T_2fee7_row7_col7,#T_2fee7_row8_col0,#T_2fee7_row8_col1,#T_2fee7_row8_col2,#T_2fee7_row8_col3,#T_2fee7_row8_col4,#T_2fee7_row8_col5,#T_2fee7_row8_col6,#T_2fee7_row8_col7,#T_2fee7_row9_col0,#T_2fee7_row9_col1,#T_2fee7_row9_col2,#T_2fee7_row9_col3,#T_2fee7_row9_col4,#T_2fee7_row9_col5,#T_2fee7_row9_col6,#T_2fee7_row9_col7,#T_2fee7_row10_col0,#T_2fee7_row10_col1,#T_2fee7_row10_col2,#T_2fee7_row10_col3,#T_2fee7_row10_col4,#T_2fee7_row10_col5,#T_2fee7_row10_col6,#T_2fee7_row10_col7,#T_2fee7_row11_col0,#T_2fee7_row11_col1,#T_2fee7_row11_col2,#T_2fee7_row11_col3,#T_2fee7_row11_col4,#T_2fee7_row11_col5,#T_2fee7_row11_col6,#T_2fee7_row11_col7{
#             text-align:  left;
#         }</style><table id="T_2fee7_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>        <th class="col_heading level0 col7" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2fee7_level0_row0" class="row_heading level0 row0" >et</th>
#                         <td id="T_2fee7_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#                         <td id="T_2fee7_row0_col1" class="data row0 col1" >537.2500</td>
#                         <td id="T_2fee7_row0_col2" class="data row0 col2" >462253.5417</td>
#                         <td id="T_2fee7_row0_col3" class="data row0 col3" >660.8258</td>
#                         <td id="T_2fee7_row0_col4" class="data row0 col4" >-0.4432</td>
#                         <td id="T_2fee7_row0_col5" class="data row0 col5" >0.0167</td>
#                         <td id="T_2fee7_row0_col6" class="data row0 col6" >0.0136</td>
#                         <td id="T_2fee7_row0_col7" class="data row0 col7" >0.1525</td>
#             </tr>
#             <tr>
#                         <th id="T_2fee7_level0_row1" class="row_heading level0 row1" >en</th>
#                         <td id="T_2fee7_row1_col0" class="data row1 col0" >Elastic Net</td>
#                         <td id="T_2fee7_row1_col1" class="data row1 col1" >552.9079</td>
#                         <td id="T_2fee7_row1_col2" class="data row1 col2" >434218.5127</td>
#                         <td id="T_2fee7_row1_col3" class="data row1 col3" >620.4142</td>
#                         <td id="T_2fee7_row1_col4" class="data row1 col4" >-0.7101</td>
#                         <td id="T_2fee7_row1_col5" class="data row1 col5" >0.0159</td>
#                         <td id="T_2fee7_row1_col6" class="data row1 col6" >0.0142</td>
#                         <td id="T_2fee7_row1_col7" class="data row1 col7" >0.0150</td>
#             </tr>
#             <tr>
#                         <th id="T_2fee7_level0_row2" class="row_heading level0 row2" >rf</th>
#                         <td id="T_2fee7_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#                         <td id="T_2fee7_row2_col1" class="data row2 col1" >582.7500</td>
#                         <td id="T_2fee7_row2_col2" class="data row2 col2" >493840.7917</td>
#                         <td id="T_2fee7_row2_col3" class="data row2 col3" >666.4469</td>
#                         <td id="T_2fee7_row2_col4" class="data row2 col4" >-0.1148</td>
#                         <td id="T_2fee7_row2_col5" class="data row2 col5" >0.0169</td>
#                         <td id="T_2fee7_row2_col6" class="data row2 col6" >0.0148</td>
#                         <td id="T_2fee7_row2_col7" class="data row2 col7" >0.1875</td>
#             </tr>
#             <tr>
#                         <th id="T_2fee7_level0_row3" class="row_heading level0 row3" >ada</th>
#                         <td id="T_2fee7_row3_col0" class="data row3 col0" >AdaBoost Regressor</td>
#                         <td id="T_2fee7_row3_col1" class="data row3 col1" >585.0694</td>
#                         <td id="T_2fee7_row3_col2" class="data row3 col2" >481500.2894</td>
#                         <td id="T_2fee7_row3_col3" class="data row3 col3" >687.0558</td>
#                         <td id="T_2fee7_row3_col4" class="data row3 col4" >-0.5741</td>
#                         <td id="T_2fee7_row3_col5" class="data row3 col5" >0.0174</td>
#                         <td id="T_2fee7_row3_col6" class="data row3 col6" >0.0148</td>
#                         <td id="T_2fee7_row3_col7" class="data row3 col7" >0.0675</td>
#             </tr>
#             <tr>
#                         <th id="T_2fee7_level0_row4" class="row_heading level0 row4" >xgboost</th>
#                         <td id="T_2fee7_row4_col0" class="data row4 col0" >Extreme Gradient Boosting</td>
#                         <td id="T_2fee7_row4_col1" class="data row4 col1" >590.3796</td>
#                         <td id="T_2fee7_row4_col2" class="data row4 col2" >478143.2629</td>
#                         <td id="T_2fee7_row4_col3" class="data row4 col3" >674.2679</td>
#                         <td id="T_2fee7_row4_col4" class="data row4 col4" >-0.9432</td>
#                         <td id="T_2fee7_row4_col5" class="data row4 col5" >0.0170</td>
#                         <td id="T_2fee7_row4_col6" class="data row4 col6" >0.0149</td>
#                         <td id="T_2fee7_row4_col7" class="data row4 col7" >0.1075</td>
#             </tr>
#             <tr>
#                         <th id="T_2fee7_level0_row5" class="row_heading level0 row5" >br</th>
#                         <td id="T_2fee7_row5_col0" class="data row5 col0" >Bayesian Ridge</td>
#                         <td id="T_2fee7_row5_col1" class="data row5 col1" >614.2472</td>
#                         <td id="T_2fee7_row5_col2" class="data row5 col2" >547685.6406</td>
#                         <td id="T_2fee7_row5_col3" class="data row5 col3" >694.8492</td>
#                         <td id="T_2fee7_row5_col4" class="data row5 col4" >-0.1777</td>
#                         <td id="T_2fee7_row5_col5" class="data row5 col5" >0.0176</td>
#                         <td id="T_2fee7_row5_col6" class="data row5 col6" >0.0156</td>
#                         <td id="T_2fee7_row5_col7" class="data row5 col7" >0.0125</td>
#             </tr>
#             <tr>
#                         <th id="T_2fee7_level0_row6" class="row_heading level0 row6" >ridge</th>
#                         <td id="T_2fee7_row6_col0" class="data row6 col0" >Ridge Regression</td>
#                         <td id="T_2fee7_row6_col1" class="data row6 col1" >660.5726</td>
#                         <td id="T_2fee7_row6_col2" class="data row6 col2" >649069.4648</td>

# %%
len(stock_pred_dict)
# Out:
# 3

# %%
stock_pred = pd.DataFrame(stock_pred_dict)
stock_pred

# %%
stock_pred.columns

# %%
stock_pred * 2

# %%
type(stock_pred['005930'])

# %%
final_stock_pred = pd.concat([stock_pred, stock_pred])
final_stock_pred

# %%
final_stock_pred = final_stock_pred.reset_index()
final_stock_pred

# %%
final_stock_pred = final_stock_pred.drop('index',axis=1)
final_stock_pred

# %%
final_stock_pred.columns

# %% [markdown]
# # 제출 파일 만들기

# %%
sample_name = 'sample_submission.csv'
sub = pd.read_csv(os.path.join(path,sample_name))
sub

# %%
for code in final_stock_pred.columns:
    sub[code] = final_stock_pred[code]

# %%
sub

# %%
sub.to_csv('sub01_cat01.csv', index=False)
