# %%
import FinanceDataReader as fdr
from tqdm import tqdm
import pandas as pd

# %% [markdown]
# # 상장 시장별 예측(Pycaret, Catboost이용)

# %% [markdown]
# ## 모든 종목 예측

# %% [markdown]
# * 종가와 상관계수 높은 특성 : KOSDAQ(0.87), KOSPI(0.79), DOW(0.58), NASDAQ(0.50), S&P500(0.56)
# * 예측 순서(종가와 상관계수 높은 특성 먼저 예측)
#     * weekday, weeknumdm로 KOSDAQ 예측(종가와 상관계수 0.87)
#     * weekday, weeknum, KOSDAQ으로 NASDAQ 예측(KOSDAQ과 상관계수 0.68)
#     * weekday, weeknum, KOSDAQ, NASDAQ으로 S&P500 예측(NASDAQ과 상관계수 0.93)
#     * weekday, weeknum, KOSDAQ, NASDAQ, S&P500으로 DOW 예측(S&P500과 상관계수 0.95)
#     * weekday, weeknum, KOSDAQ, NASDAQ, S&P500, DOW로 KOSPI 예측
#     * weekday, weeknum, KOSDAQ, NASDAQ, S&P500, DOW, KOSPI로 다른 종가 예측
# * 바로 전날 데이터 이용해 예측
# * 증감 비율로 예측

# %%
# 제출 점수 :
# 자체 결정계수 점수 : 3.22868

# %%
from pycaret.regression import *

# %% [markdown]
# # 데이터 불러오기(첫번째 주)
# * 훈련 : 10.04 ~ 10.29
# * 예측 : 11.01 ~ 11.05

# %% [markdown]
# ### 원 데이터 불러오기

# %%
data = pd.read_csv('../data/2021-01-04_2021-11-26_all_data2.csv')
stock_list = pd.read_csv('../data/stock_list.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86950 entries, 0 to 86949
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         86950 non-null  object
#  1   kosdaq       86950 non-null  float64
#  2   nasdaq       86950 non-null  float64
#  3   dow          86950 non-null  float64
#  4   sp500        86950 non-null  float64
#  5   kospi        86950 non-null  float64
#  6   code         86950 non-null  int64
#  7   market       86950 non-null  object
#  8   close        86950 non-null  float64
#  9   kospi_rate   86950 non-null  float64
#  10  nasdaq_rate  86950 non-null  float64
#  11  dow_rate     86950 non-null  float64
#  12  sp500_rate   86950 non-null  float64
#  13  kosdaq_rate  86950 non-null  float64
#  14  close_rate   86950 non-null  float64
# dtypes: float64(12), int64(1), object(2)
# memory usage: 10.0+ MB

# %%
data['code'] = data['code'].astype(str).str.zfill(6)
data.head()
# Out:
#          Date  kosdaq   nasdaq       dow    sp500    kospi    code market  \
# 0  2021-01-04  977.62  12698.4  30223.89  3700.65  2944.45  005930  KOSPI
# 1  2021-01-05  985.76  12819.0  30391.60  3726.86  2990.57  005930  KOSPI
# 2  2021-01-06  981.39  12740.8  30829.40  3748.14  2968.21  005930  KOSPI
# 3  2021-01-07  988.86  13067.5  31041.13  3803.79  3031.68  005930  KOSPI
# 4  2021-01-08  987.79  13202.0  31097.97  3824.68  3152.18  005930  KOSPI
#
#      close  kospi_rate  nasdaq_rate  dow_rate  sp500_rate  kosdaq_rate  \
# 0  83000.0    0.000000     0.000000  0.000000    0.000000     0.000000
# 1  83900.0    0.015663     0.009497  0.005549    0.007083     0.008326
# 2  82200.0   -0.007477    -0.006100  0.014405    0.005710    -0.004433
# 3  82900.0    0.021383     0.025642  0.006868    0.014847     0.007612
# 4  88800.0    0.039747     0.010293  0.001831    0.005492    -0.001082
#
#    close_rate
# 0    0.000000
# 1    0.010843
# 2   -0.020262
# 3    0.008516
# 4    0.071170

# %%
data.columns
# Out:
# Index(['Date', 'kosdaq', 'nasdaq', 'dow', 'sp500', 'kospi', 'code', 'market',
#        'close', 'kospi_rate', 'nasdaq_rate', 'dow_rate', 'sp500_rate',
#        'kosdaq_rate', 'close_rate'],
#       dtype='object')

# %% [markdown]
# ### 주식 지수에 필요한 열만 추출

# %%
index_data = data[['Date', 'code', 'market', 'kospi_rate', 'nasdaq_rate', 'dow_rate', 'sp500_rate', 'kosdaq_rate']]
index_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86950 entries, 0 to 86949
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         86950 non-null  object
#  1   code         86950 non-null  object
#  2   market       86950 non-null  object
#  3   kospi_rate   86950 non-null  float64
#  4   nasdaq_rate  86950 non-null  float64
#  5   dow_rate     86950 non-null  float64
#  6   sp500_rate   86950 non-null  float64
#  7   kosdaq_rate  86950 non-null  float64
# dtypes: float64(5), object(3)
# memory usage: 5.3+ MB

# %%
index_data.head()
# Out:
#          Date    code market  kospi_rate  nasdaq_rate  dow_rate  sp500_rate  \
# 0  2021-01-04  005930  KOSPI    0.000000     0.000000  0.000000    0.000000
# 1  2021-01-05  005930  KOSPI    0.015663     0.009497  0.005549    0.007083
# 2  2021-01-06  005930  KOSPI   -0.007477    -0.006100  0.014405    0.005710
# 3  2021-01-07  005930  KOSPI    0.021383     0.025642  0.006868    0.014847
# 4  2021-01-08  005930  KOSPI    0.039747     0.010293  0.001831    0.005492
#
#    kosdaq_rate
# 0     0.000000
# 1     0.008326
# 2    -0.004433
# 3     0.007612
# 4    -0.001082

# %% [markdown]
# ### train set

# %%
start_date = '2021-10-04'
end_date = '2021-11-04'

# %%
index_train = index_data[(index_data['Date'] >= start_date) & (index_data['Date'] <= end_date)]
index_train = index_train.reset_index(drop=True)
index_train.head()
# Out:
#          Date    code market  kospi_rate  nasdaq_rate  dow_rate  sp500_rate  \
# 0  2021-10-04  005930  KOSPI   -0.009441    -0.021364 -0.009435   -0.012988
# 1  2021-10-05  005930  KOSPI   -0.009531     0.012507  0.009188    0.010524
# 2  2021-10-06  005930  KOSPI   -0.018183     0.004718  0.002972    0.004103
# 3  2021-10-07  005930  KOSPI    0.017588     0.010488  0.009767    0.008298
# 4  2021-10-08  005930  KOSPI   -0.001068    -0.005084 -0.000214   -0.001909
#
#    kosdaq_rate
# 0    -0.014153
# 1    -0.014356
# 2    -0.034552
# 3     0.033685
# 4    -0.000336

# %%
index_train.tail()
# Out:
#             Date    code  market  kospi_rate  nasdaq_rate  dow_rate  \
# 8875  2021-10-29  099320  KOSDAQ   -0.012916     0.003256  0.002511
# 8876  2021-11-01  099320  KOSDAQ    0.002781     0.006291  0.002627
# 8877  2021-11-02  099320  KOSDAQ    0.011598     0.003443  0.003882
# 8878  2021-11-03  099320  KOSDAQ   -0.012537     0.010352  0.002883
# 8879  2021-11-04  099320  KOSDAQ    0.002524     0.008140 -0.000895
#
#       sp500_rate  kosdaq_rate
# 8875    0.001949    -0.007799
# 8876    0.001800     0.006288
# 8877    0.003680     0.010886
# 8878    0.006461    -0.004398
# 8879    0.004182    -0.003552

# %%
index_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8880 entries, 0 to 8879
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         8880 non-null   object
#  1   code         8880 non-null   object
#  2   market       8880 non-null   object
#  3   kospi_rate   8880 non-null   float64
#  4   nasdaq_rate  8880 non-null   float64
#  5   dow_rate     8880 non-null   float64
#  6   sp500_rate   8880 non-null   float64
#  7   kosdaq_rate  8880 non-null   float64
# dtypes: float64(5), object(3)
# memory usage: 555.1+ KB

# %% [markdown]
# ### test set

# %%
index_test = index_data[(index_data['Date'] >= '2021-11-01') & (index_data['Date'] <= '2021-11-05')]
index_test = index_test[['Date', 'code', 'market']]
index_test = index_test.reset_index(drop=True)
index_test.head()
# Out:
#          Date    code market
# 0  2021-11-01  005930  KOSPI
# 1  2021-11-02  005930  KOSPI
# 2  2021-11-03  005930  KOSPI
# 3  2021-11-04  005930  KOSPI
# 4  2021-11-05  005930  KOSPI

# %%
index_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1850 entries, 0 to 1849
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1850 non-null   object
#  1   code    1850 non-null   object
#  2   market  1850 non-null   object
# dtypes: object(3)
# memory usage: 43.5+ KB

# %% [markdown]
# ## 3가지 특성으로 5가지 외부 특성 순서대로 예측하기

# %%
start_date = '2021-10-04'
end_date = '2021-11-04'

features = ['Date', 'code', 'market', 'kospi_rate', 'nasdaq_rate', 'dow_rate', 'sp500_rate', 'kosdaq_rate']
days1 = ['2021-10-04', '2021-10-05', '2021-10-06', '2021-10-07', '2021-10-08']
days2 = ['2021-10-29', '2021-11-01', '2021-11-02', '2021-11-03', '2021-11-04', '2021-11-05']
pred_index_test = pd.DataFrame()
for d in tqdm(range(5)):
    train_start_day = d
    train_end_day = d
    test_day = d+1
    temp_train = index_train[(index_train['Date'] >= days1[train_start_day]) & (index_train['Date'] <= days2[train_end_day])]
    temp_test = index_test[index_test['Date'] == days2[test_day]]
    
    for i in range(5):      
        ex = setup(temp_train, target = features[i+3], ignore_features = features[i+4:], fold=4,
                      fold_shuffle=True, silent=True, use_gpu=True)
        model = create_model('catboost')
        final_model = finalize_model(model)
        pred = predict_model(final_model, temp_test)
        
        temp_test[features[i+3]] = pred['Label']
    
    pred_index_test = pd.concat([pred_index_test, temp_test])
# Out:
# <style  type="text/css" >
# #T_9a9cc_row4_col0,#T_9a9cc_row4_col1,#T_9a9cc_row4_col2,#T_9a9cc_row4_col3,#T_9a9cc_row4_col4,#T_9a9cc_row4_col5{
#             background:  yellow;
#         }</style><table id="T_9a9cc_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9a9cc_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_9a9cc_row0_col0" class="data row0 col0" >0.0000</td>
#                         <td id="T_9a9cc_row0_col1" class="data row0 col1" >0.0000</td>
#                         <td id="T_9a9cc_row0_col2" class="data row0 col2" >0.0000</td>
#                         <td id="T_9a9cc_row0_col3" class="data row0 col3" >1.0000</td>
#                         <td id="T_9a9cc_row0_col4" class="data row0 col4" >0.0000</td>
#                         <td id="T_9a9cc_row0_col5" class="data row0 col5" >0.0001</td>
#             </tr>
#             <tr>
#                         <th id="T_9a9cc_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_9a9cc_row1_col0" class="data row1 col0" >0.0000</td>
#                         <td id="T_9a9cc_row1_col1" class="data row1 col1" >0.0000</td>
#                         <td id="T_9a9cc_row1_col2" class="data row1 col2" >0.0000</td>
#                         <td id="T_9a9cc_row1_col3" class="data row1 col3" >1.0000</td>
#                         <td id="T_9a9cc_row1_col4" class="data row1 col4" >0.0000</td>
#                         <td id="T_9a9cc_row1_col5" class="data row1 col5" >0.0001</td>
#             </tr>
#             <tr>
#                         <th id="T_9a9cc_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_9a9cc_row2_col0" class="data row2 col0" >0.0000</td>
#                         <td id="T_9a9cc_row2_col1" class="data row2 col1" >0.0000</td>
#                         <td id="T_9a9cc_row2_col2" class="data row2 col2" >0.0000</td>
#                         <td id="T_9a9cc_row2_col3" class="data row2 col3" >1.0000</td>
#                         <td id="T_9a9cc_row2_col4" class="data row2 col4" >0.0000</td>
#                         <td id="T_9a9cc_row2_col5" class="data row2 col5" >0.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_9a9cc_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_9a9cc_row3_col0" class="data row3 col0" >0.0000</td>
#                         <td id="T_9a9cc_row3_col1" class="data row3 col1" >0.0000</td>
#                         <td id="T_9a9cc_row3_col2" class="data row3 col2" >0.0000</td>
#                         <td id="T_9a9cc_row3_col3" class="data row3 col3" >1.0000</td>
#                         <td id="T_9a9cc_row3_col4" class="data row3 col4" >0.0000</td>
#                         <td id="T_9a9cc_row3_col5" class="data row3 col5" >0.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_9a9cc_level0_row4" class="row_heading level0 row4" >Mean</th>
#                         <td id="T_9a9cc_row4_col0" class="data row4 col0" >0.0000</td>
#                         <td id="T_9a9cc_row4_col1" class="data row4 col1" >0.0000</td>
#                         <td id="T_9a9cc_row4_col2" class="data row4 col2" >0.0000</td>
#                         <td id="T_9a9cc_row4_col3" class="data row4 col3" >1.0000</td>
#                         <td id="T_9a9cc_row4_col4" class="data row4 col4" >0.0000</td>
#                         <td id="T_9a9cc_row4_col5" class="data row4 col5" >0.0001</td>
#             </tr>
#             <tr>
#                         <th id="T_9a9cc_level0_row5" class="row_heading level0 row5" >SD</th>
#                         <td id="T_9a9cc_row5_col0" class="data row5 col0" >0.0000</td>
#                         <td id="T_9a9cc_row5_col1" class="data row5 col1" >0.0000</td>
#                         <td id="T_9a9cc_row5_col2" class="data row5 col2" >0.0000</td>
#                         <td id="T_9a9cc_row5_col3" class="data row5 col3" >0.0000</td>
#                         <td id="T_9a9cc_row5_col4" class="data row5 col4" >0.0000</td>
#                         <td id="T_9a9cc_row5_col5" class="data row5 col5" >0.0000</td>
#             </tr>
#     </tbody></table>
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [11:51<00:00, 142.31s/it]

# %%
pred_index_test = pred_index_test.reset_index(drop=True)
pred_index_test
# Out:
#             Date    code  market  kospi_rate  nasdaq_rate  dow_rate  \
# 0     2021-11-01  005930   KOSPI   -0.003548     0.008357 -0.001033
# 1     2021-11-01  000660   KOSPI   -0.003549     0.008357 -0.001033
# 2     2021-11-01  035420   KOSPI   -0.003547     0.008357 -0.001033
# 3     2021-11-01  035720   KOSPI   -0.003547     0.008357 -0.001033
# 4     2021-11-01  207940   KOSPI   -0.003547     0.008357 -0.001033
# ...          ...     ...     ...         ...          ...       ...
# 1845  2021-11-05  220630  KOSDAQ   -0.000403    -0.000409  0.000793
# 1846  2021-11-05  064260  KOSDAQ   -0.000399    -0.000409  0.000793
# 1847  2021-11-05  287410  KOSDAQ   -0.000412    -0.000409  0.000795
# 1848  2021-11-05  110790  KOSDAQ   -0.000401    -0.000409  0.000793
# 1849  2021-11-05  099320  KOSDAQ   -0.000400    -0.000409  0.000793
#
#       sp500_rate  kosdaq_rate
# 0       0.003379     0.003352
# 1       0.003379     0.003352
# 2       0.003379     0.003352
# 3       0.003379     0.003352
# 4       0.003379     0.003352
# ...          ...          ...
# 1845    0.000623     0.001221
# 1846    0.000623     0.001221
# 1847    0.000623     0.001221
# 1848    0.000623     0.001221
# 1849    0.000623     0.001221
#
# [1850 rows x 8 columns]

# %%
# pred_index_test.to_csv('prac_4w_pred_1w_index_test_cat.csv', index=False)

# %% [markdown]
# ## 종가예측 위한 훈련, 테스트 셋 준비

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86950 entries, 0 to 86949
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         86950 non-null  object
#  1   kosdaq       86950 non-null  float64
#  2   nasdaq       86950 non-null  float64
#  3   dow          86950 non-null  float64
#  4   sp500        86950 non-null  float64
#  5   kospi        86950 non-null  float64
#  6   code         86950 non-null  object
#  7   market       86950 non-null  object
#  8   close        86950 non-null  float64
#  9   kospi_rate   86950 non-null  float64
#  10  nasdaq_rate  86950 non-null  float64
#  11  dow_rate     86950 non-null  float64
#  12  sp500_rate   86950 non-null  float64
#  13  kosdaq_rate  86950 non-null  float64
#  14  close_rate   86950 non-null  float64
# dtypes: float64(12), object(3)
# memory usage: 10.0+ MB

# %% [markdown]
# ### 훈련 셋 준비

# %%
start_date = '2021-10-04'
end_date = '2021-11-04'

# %%
data.columns
# Out:
# Index(['Date', 'kosdaq', 'nasdaq', 'dow', 'sp500', 'kospi', 'code', 'market',
#        'close', 'kospi_rate', 'nasdaq_rate', 'dow_rate', 'sp500_rate',
#        'kosdaq_rate', 'close_rate'],
#       dtype='object')

# %%
close_train = data[ (data['Date'] >= start_date) & (data['Date'] <= end_date) ]
close_train = close_train[ ['Date', 'code', 'market', 'kospi_rate', 'nasdaq_rate',
 'dow_rate', 'sp500_rate', 'kosdaq_rate', 'close_rate'] ]
close_train = close_train.reset_index(drop=True)
close_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8880 entries, 0 to 8879
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         8880 non-null   object
#  1   code         8880 non-null   object
#  2   market       8880 non-null   object
#  3   kospi_rate   8880 non-null   float64
#  4   nasdaq_rate  8880 non-null   float64
#  5   dow_rate     8880 non-null   float64
#  6   sp500_rate   8880 non-null   float64
#  7   kosdaq_rate  8880 non-null   float64
#  8   close_rate   8880 non-null   float64
# dtypes: float64(6), object(3)
# memory usage: 624.5+ KB

# %%
close_train.head()
# Out:
#          Date    code market  kospi_rate  nasdaq_rate  dow_rate  sp500_rate  \
# 0  2021-10-04  005930  KOSPI   -0.009441    -0.021364 -0.009435   -0.012988
# 1  2021-10-05  005930  KOSPI   -0.009531     0.012507  0.009188    0.010524
# 2  2021-10-06  005930  KOSPI   -0.018183     0.004718  0.002972    0.004103
# 3  2021-10-07  005930  KOSPI    0.017588     0.010488  0.009767    0.008298
# 4  2021-10-08  005930  KOSPI   -0.001068    -0.005084 -0.000214   -0.001909
#
#    kosdaq_rate  close_rate
# 0    -0.014153   -0.006831
# 1    -0.014356   -0.006878
# 2    -0.034552   -0.012465
# 3     0.033685    0.004208
# 4    -0.000336   -0.001397

# %% [markdown]
# ### 테스트 셋 준비

# %%
pred_index_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1850 entries, 0 to 1849
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         1850 non-null   object
#  1   code         1850 non-null   object
#  2   market       1850 non-null   object
#  3   kospi_rate   1850 non-null   float64
#  4   nasdaq_rate  1850 non-null   float64
#  5   dow_rate     1850 non-null   float64
#  6   sp500_rate   1850 non-null   float64
#  7   kosdaq_rate  1850 non-null   float64
# dtypes: float64(5), object(3)
# memory usage: 115.8+ KB

# %%
pred_index_test.head()
# Out:
#          Date    code market  kospi_rate  nasdaq_rate  dow_rate  sp500_rate  \
# 0  2021-11-01  005930  KOSPI   -0.003548     0.008357 -0.001033    0.003379
# 1  2021-11-01  000660  KOSPI   -0.003549     0.008357 -0.001033    0.003379
# 2  2021-11-01  035420  KOSPI   -0.003547     0.008357 -0.001033    0.003379
# 3  2021-11-01  035720  KOSPI   -0.003547     0.008357 -0.001033    0.003379
# 4  2021-11-01  207940  KOSPI   -0.003547     0.008357 -0.001033    0.003379
#
#    kosdaq_rate
# 0     0.003352
# 1     0.003352
# 2     0.003352
# 3     0.003352
# 4     0.003352

# %%
pred_close_test = pred_index_test

# %%
pred_close_test.tail()
# Out:
#             Date    code  market  kospi_rate  nasdaq_rate  dow_rate  \
# 1845  2021-11-05  220630  KOSDAQ   -0.000403    -0.000409  0.000793
# 1846  2021-11-05  064260  KOSDAQ   -0.000399    -0.000409  0.000793
# 1847  2021-11-05  287410  KOSDAQ   -0.000412    -0.000409  0.000795
# 1848  2021-11-05  110790  KOSDAQ   -0.000401    -0.000409  0.000793
# 1849  2021-11-05  099320  KOSDAQ   -0.000400    -0.000409  0.000793
#
#       sp500_rate  kosdaq_rate
# 1845    0.000623     0.001221
# 1846    0.000623     0.001221
# 1847    0.000623     0.001221
# 1848    0.000623     0.001221
# 1849    0.000623     0.001221

# %% [markdown]
# ## 상장 시장 별 종가 비율 예측하기

# %%
market = ['KOSPI', 'KOSDAQ']
days1 = ['2021-10-04', '2021-10-05', '2021-10-06', '2021-10-07', '2021-10-08']
days2 = ['2021-10-29', '2021-11-01', '2021-11-02', '2021-11-03', '2021-11-04', '2021-11-05']


temp_pred_close = pd.DataFrame()

for market in tqdm(market):
    # 상장 시장에 따라 추출
    train = close_train[close_train['market'] == market].reset_index(drop=True)
    test = pred_close_test[pred_close_test['market'] == market].reset_index(drop=True)

    for d in range(5):
        # 훈련, 테스트 날짜 지정
        train_start_day = d
        train_end_day = d
        test_day = d+1

        # 훈련, 테스트 셋 추출
        temp_train = train[ (train['Date'] >= days1[train_start_day]) &
        (train['Date'] <= days2[train_end_day]) ].reset_index(drop=True)
        temp_test = test[test['Date'] == days2[test_day]].reset_index(drop=True)

        # 머신 러닝 훈련
        ex = setup(temp_train, target = 'close_rate', silent=True, fold=4, fold_shuffle=True, use_gpu=True, verbose=False)
        cat = create_model('catboost')
        pred = predict_model(cat, temp_test)
        temp_test['close_rate'] = pred['Label']
        temp_pred_close = pd.concat([temp_pred_close, temp_test])

pred_close_rate = temp_pred_close[['Date', 'code', 'market', 'close_rate']]
# Out:
# <style  type="text/css" >
# #T_4c80a_row4_col0,#T_4c80a_row4_col1,#T_4c80a_row4_col2,#T_4c80a_row4_col3,#T_4c80a_row4_col4,#T_4c80a_row4_col5{
#             background:  yellow;
#         }</style><table id="T_4c80a_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4c80a_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4c80a_row0_col0" class="data row0 col0" >0.0199</td>
#                         <td id="T_4c80a_row0_col1" class="data row0 col1" >0.0009</td>
#                         <td id="T_4c80a_row0_col2" class="data row0 col2" >0.0296</td>
#                         <td id="T_4c80a_row0_col3" class="data row0 col3" >0.0786</td>
#                         <td id="T_4c80a_row0_col4" class="data row0 col4" >0.0245</td>
#                         <td id="T_4c80a_row0_col5" class="data row0 col5" >1.6138</td>
#             </tr>
#             <tr>
#                         <th id="T_4c80a_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_4c80a_row1_col0" class="data row1 col0" >0.0201</td>
#                         <td id="T_4c80a_row1_col1" class="data row1 col1" >0.0009</td>
#                         <td id="T_4c80a_row1_col2" class="data row1 col2" >0.0305</td>
#                         <td id="T_4c80a_row1_col3" class="data row1 col3" >0.0508</td>
#                         <td id="T_4c80a_row1_col4" class="data row1 col4" >0.0249</td>
#                         <td id="T_4c80a_row1_col5" class="data row1 col5" >1.4468</td>
#             </tr>
#             <tr>
#                         <th id="T_4c80a_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_4c80a_row2_col0" class="data row2 col0" >0.0209</td>
#                         <td id="T_4c80a_row2_col1" class="data row2 col1" >0.0011</td>
#                         <td id="T_4c80a_row2_col2" class="data row2 col2" >0.0329</td>
#                         <td id="T_4c80a_row2_col3" class="data row2 col3" >0.0618</td>
#                         <td id="T_4c80a_row2_col4" class="data row2 col4" >0.0272</td>
#                         <td id="T_4c80a_row2_col5" class="data row2 col5" >1.7216</td>
#             </tr>
#             <tr>
#                         <th id="T_4c80a_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_4c80a_row3_col0" class="data row3 col0" >0.0214</td>
#                         <td id="T_4c80a_row3_col1" class="data row3 col1" >0.0010</td>
#                         <td id="T_4c80a_row3_col2" class="data row3 col2" >0.0309</td>
#                         <td id="T_4c80a_row3_col3" class="data row3 col3" >-0.0487</td>
#                         <td id="T_4c80a_row3_col4" class="data row3 col4" >0.0242</td>
#                         <td id="T_4c80a_row3_col5" class="data row3 col5" >1.8184</td>
#             </tr>
#             <tr>
#                         <th id="T_4c80a_level0_row4" class="row_heading level0 row4" >Mean</th>
#                         <td id="T_4c80a_row4_col0" class="data row4 col0" >0.0206</td>
#                         <td id="T_4c80a_row4_col1" class="data row4 col1" >0.0010</td>
#                         <td id="T_4c80a_row4_col2" class="data row4 col2" >0.0310</td>
#                         <td id="T_4c80a_row4_col3" class="data row4 col3" >0.0356</td>
#                         <td id="T_4c80a_row4_col4" class="data row4 col4" >0.0252</td>
#                         <td id="T_4c80a_row4_col5" class="data row4 col5" >1.6501</td>
#             </tr>
#             <tr>
#                         <th id="T_4c80a_level0_row5" class="row_heading level0 row5" >SD</th>
#                         <td id="T_4c80a_row5_col0" class="data row5 col0" >0.0006</td>
#                         <td id="T_4c80a_row5_col1" class="data row5 col1" >0.0001</td>
#                         <td id="T_4c80a_row5_col2" class="data row5 col2" >0.0012</td>
#                         <td id="T_4c80a_row5_col3" class="data row5 col3" >0.0497</td>
#                         <td id="T_4c80a_row5_col4" class="data row5 col4" >0.0012</td>
#                         <td id="T_4c80a_row5_col5" class="data row5 col5" >0.1379</td>
#             </tr>
#     </tbody></table>
# 100%|████████████████████████████████████████████████████████████████████████████████████| 2/2 [01:49<00:00, 54.97s/it]

# %%
pred_close_rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1850 entries, 0 to 184
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        1850 non-null   object
#  1   code        1850 non-null   object
#  2   market      1850 non-null   object
#  3   close_rate  1850 non-null   float64
# dtypes: float64(1), object(3)
# memory usage: 72.3+ KB

# %%
pred_close_rate.head()
# Out:
#          Date    code market  close_rate
# 0  2021-11-01  005930  KOSPI   -0.002903
# 1  2021-11-01  000660  KOSPI    0.001866
# 2  2021-11-01  035420  KOSPI   -0.002790
# 3  2021-11-01  035720  KOSPI   -0.002790
# 4  2021-11-01  207940  KOSPI    0.002129

# %%
pred_close_rate = pred_close_rate.sort_values(['code', 'Date'])
pred_close_rate = pred_close_rate.reset_index(drop=True)
pred_close_rate
# Out:
#             Date    code  market  close_rate
# 0     2021-11-01  000060   KOSPI    0.002328
# 1     2021-11-02  000060   KOSPI   -0.003304
# 2     2021-11-03  000060   KOSPI    0.005864
# 3     2021-11-04  000060   KOSPI    0.023918
# 4     2021-11-05  000060   KOSPI    0.002650
# ...          ...     ...     ...         ...
# 1845  2021-11-01  950130  KOSDAQ   -0.016779
# 1846  2021-11-02  950130  KOSDAQ    0.022060
# 1847  2021-11-03  950130  KOSDAQ    0.006508
# 1848  2021-11-04  950130  KOSDAQ    0.004333
# 1849  2021-11-05  950130  KOSDAQ    0.037639
#
# [1850 rows x 4 columns]

# %% [markdown]
# ## 종가 비율 값 원래 값으로 변환

# %%
# 원 데이터
data.head()
# Out:
#          Date  kosdaq   nasdaq       dow    sp500    kospi    code market  \
# 0  2021-01-04  977.62  12698.4  30223.89  3700.65  2944.45  005930  KOSPI
# 1  2021-01-05  985.76  12819.0  30391.60  3726.86  2990.57  005930  KOSPI
# 2  2021-01-06  981.39  12740.8  30829.40  3748.14  2968.21  005930  KOSPI
# 3  2021-01-07  988.86  13067.5  31041.13  3803.79  3031.68  005930  KOSPI
# 4  2021-01-08  987.79  13202.0  31097.97  3824.68  3152.18  005930  KOSPI
#
#      close  kospi_rate  nasdaq_rate  dow_rate  sp500_rate  kosdaq_rate  \
# 0  83000.0    0.000000     0.000000  0.000000    0.000000     0.000000
# 1  83900.0    0.015663     0.009497  0.005549    0.007083     0.008326
# 2  82200.0   -0.007477    -0.006100  0.014405    0.005710    -0.004433
# 3  82900.0    0.021383     0.025642  0.006868    0.014847     0.007612
# 4  88800.0    0.039747     0.010293  0.001831    0.005492    -0.001082
#
#    close_rate
# 0    0.000000
# 1    0.010843
# 2   -0.020262
# 3    0.008516
# 4    0.071170

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86950 entries, 0 to 86949
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         86950 non-null  object
#  1   kosdaq       86950 non-null  float64
#  2   nasdaq       86950 non-null  float64
#  3   dow          86950 non-null  float64
#  4   sp500        86950 non-null  float64
#  5   kospi        86950 non-null  float64
#  6   code         86950 non-null  object
#  7   market       86950 non-null  object
#  8   close        86950 non-null  float64
#  9   kospi_rate   86950 non-null  float64
#  10  nasdaq_rate  86950 non-null  float64
#  11  dow_rate     86950 non-null  float64
#  12  sp500_rate   86950 non-null  float64
#  13  kosdaq_rate  86950 non-null  float64
#  14  close_rate   86950 non-null  float64
# dtypes: float64(12), object(3)
# memory usage: 10.0+ MB

# %%
mod_data = data[ ['Date','code','market','close'] ]
mod_data
# Out:
#              Date    code  market    close
# 0      2021-01-04  005930   KOSPI  83000.0
# 1      2021-01-05  005930   KOSPI  83900.0
# 2      2021-01-06  005930   KOSPI  82200.0
# 3      2021-01-07  005930   KOSPI  82900.0
# 4      2021-01-08  005930   KOSPI  88800.0
# ...           ...     ...     ...      ...
# 86945  2021-11-22  099320  KOSDAQ  48350.0
# 86946  2021-11-23  099320  KOSDAQ  46900.0
# 86947  2021-11-24  099320  KOSDAQ  47150.0
# 86948  2021-11-25  099320  KOSDAQ  46600.0
# 86949  2021-11-26  099320  KOSDAQ  45350.0
#
# [86950 rows x 4 columns]

# %%
mod_data = mod_data.sort_values(['code', 'Date']).reset_index(drop=True)
mod_data
# Out:
#              Date    code  market    close
# 0      2021-01-04  000060   KOSPI  14250.0
# 1      2021-01-05  000060   KOSPI  14050.0
# 2      2021-01-06  000060   KOSPI  14250.0
# 3      2021-01-07  000060   KOSPI  14700.0
# 4      2021-01-08  000060   KOSPI  14750.0
# ...           ...     ...     ...      ...
# 86945  2021-11-22  950130  KOSDAQ  15950.0
# 86946  2021-11-23  950130  KOSDAQ  15500.0
# 86947  2021-11-24  950130  KOSDAQ  15200.0
# 86948  2021-11-25  950130  KOSDAQ  15300.0
# 86949  2021-11-26  950130  KOSDAQ  16650.0
#
# [86950 rows x 4 columns]

# %%
pred_close_rate['code'].unique()[:5]
# Out:
# array(['000060', '000080', '000100', '000120', '000150'], dtype=object)

# %%
stock_close_list = []
for code in tqdm(pred_close_rate['code'].unique()):
    # 종목 별로 셋 가져오기
    temp_data = mod_data[mod_data['code'] == code].reset_index(drop=True)
    temp_pred = pred_close_rate[pred_close_rate['code'] == code].reset_index(drop=True)

    # 날짜 지정
    present_days = ['2021-11-01', '2021-11-02', '2021-11-03', '2021-11-04', '2021-11-05']
    
    # 당일 종가 = 전날 종가 * (1 + 당일 비율)
    # 2021-11-01일의 예측 종가 = 2021-10-29일의 실제 종가 * (1 + 2021-11-01 예측 비율)
    # 2021-11-02일의 예측 종가 = 2021-11-01일의 예측 종가 * (1 + 2021-11-02 예측 비율)
    
    # 2021-11-01일의 예측 종가 계산
    one_stock_close_list = []
    # 2021-10-29일의 실제 종가
    before_close = float(temp_data[temp_data['Date'] == '2021-10-29']['close'].values)
    # 2021-11-01일의 예측 비율
    present_rate = float(temp_pred[temp_pred['Date'] == present_days[0]]['close_rate'].values)
    close = before_close * (1 + present_rate)
    one_stock_close_list.append(close)
    # 2021-11-02 ~ 05일의 예측 종가 계산
    for i in range(4):
        before_close = one_stock_close_list[i]
        present_rate = float(temp_pred[temp_pred['Date'] == present_days[i+1]]['close_rate'].values)
        close = before_close * (1 + present_rate)
        one_stock_close_list.append(close)
    stock_close_list += one_stock_close_list
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 370/370 [00:03<00:00, 113.07it/s]

# %%
len(stock_close_list)
# Out:
# 1850

# %%
stock_close_list[:5]
# Out:
# [27764.49912982529,
#  27672.773475499987,
#  27835.04682443043,
#  28500.798377089628,
#  28576.322026084064]

# %%
mod_data[ (mod_data['Date']>='2021-11-01') & (mod_data['Date']<='2021-11-05') & (mod_data['code']=='000060') ]
# Out:
#            Date    code market    close
# 215  2021-11-01  000060  KOSPI  27850.0
# 216  2021-11-02  000060  KOSPI  29250.0
# 217  2021-11-03  000060  KOSPI  30250.0
# 218  2021-11-04  000060  KOSPI  29450.0
# 219  2021-11-05  000060  KOSPI  29550.0

# %%
pred_close_rate['close'] = stock_close_list
pred_close_rate
# Out:
#             Date    code  market  close_rate         close
# 0     2021-11-01  000060   KOSPI    0.002328  27764.499130
# 1     2021-11-02  000060   KOSPI   -0.003304  27672.773475
# 2     2021-11-03  000060   KOSPI    0.005864  27835.046824
# 3     2021-11-04  000060   KOSPI    0.023918  28500.798377
# 4     2021-11-05  000060   KOSPI    0.002650  28576.322026
# ...          ...     ...     ...         ...           ...
# 1845  2021-11-01  950130  KOSDAQ   -0.016779  16813.085583
# 1846  2021-11-02  950130  KOSDAQ    0.022060  17183.990468
# 1847  2021-11-03  950130  KOSDAQ    0.006508  17295.820041
# 1848  2021-11-04  950130  KOSDAQ    0.004333  17370.759710
# 1849  2021-11-05  950130  KOSDAQ    0.037639  18024.580671
#
# [1850 rows x 5 columns]

# %%
pred_close_rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1850 entries, 0 to 1849
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        1850 non-null   object
#  1   code        1850 non-null   object
#  2   market      1850 non-null   object
#  3   close_rate  1850 non-null   float64
#  4   close       1850 non-null   float64
# dtypes: float64(2), object(3)
# memory usage: 72.4+ KB

# %% [markdown]
# ### 예측 파일 pivot_table로 변환

# %%
pred_pivot = pred_close_rate.pivot_table(index='Date', columns='code', values='close')
pred_pivot
# Out:
# code              000060        000080        000100         000120  \
# Date
# 2021-11-01  27764.499130  34758.542985  59756.057998  141503.511612
# 2021-11-02  27672.773475  34599.202297  59516.532112  140796.416126
# 2021-11-03  27835.046824  34807.583937  59899.065078  141585.549662
# 2021-11-04  28500.798377  34901.779399  60829.802987  144155.142133
# 2021-11-05  28576.322026  35036.217192  61068.688871  144841.296668
#
# code               000150        000240        000250        000270  \
# Date
# 2021-11-01  102950.989132  16740.452467  47374.400253  85399.739588
# 2021-11-02  102184.715265  16703.991530  47726.745965  85155.310393
# 2021-11-03  101635.379457  16679.461199  48150.661862  85373.731053
# 2021-11-04  103181.013480  16787.221965  48375.355284  85918.692257
# 2021-11-05  104036.863300  16930.149135  48431.323573  86642.152898
#
# code               000660         000670  ...        330860        336260  \
# Date                                      ...
# 2021-11-01  103192.235635  690497.691266  ...  49061.401867  51936.698981
# 2021-11-02  103625.271618  687988.509704  ...  49113.560615  52898.135319
# 2021-11-03  104499.141777  687609.757213  ...  49680.640361  53155.759857
# 2021-11-04  105464.429873  693434.175653  ...  50120.624917  53711.960556
# 2021-11-05  106424.042960  695699.190327  ...  50303.633031  54248.381002
#
# code              336370        347860        348150        348210  \
# Date
# 2021-11-01  85278.081130  36232.424198  25923.409088  52931.497120
# 2021-11-02  85898.990330  36309.739364  25921.623350  52819.417570
# 2021-11-03  87165.515079  37012.262812  26145.015700  53132.302797
# 2021-11-04  88036.147297  37190.078437  25888.024835  52640.624145
# 2021-11-05  88014.891185  38564.568864  26080.445542  52962.513018
#
# code               352820         357780        363280        950130
# Date
# 2021-11-01  339129.540899  259748.733053  26927.608269  16813.085583
# 2021-11-02  341346.307653  260194.239296  26919.029746  17183.990468
# 2021-11-03  340985.058237  260957.606072  26627.320994  17295.820041
# 2021-11-04  345355.618662  259319.691412  26534.926097  17370.759710
# 2021-11-05  341376.958207  259466.599307  26347.997090  18024.580671
#
# [5 rows x 370 columns]

# %%
pred_pivot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 2021-11-01 to 2021-11-05
# Columns: 370 entries, 000060 to 950130
# dtypes: float64(370)
# memory usage: 14.5+ KB

# %%
pred_pivot = pred_pivot.reset_index()
pred_pivot
# Out:
# code        Date        000060        000080        000100         000120  \
# 0     2021-11-01  27764.499130  34758.542985  59756.057998  141503.511612
# 1     2021-11-02  27672.773475  34599.202297  59516.532112  140796.416126
# 2     2021-11-03  27835.046824  34807.583937  59899.065078  141585.549662
# 3     2021-11-04  28500.798377  34901.779399  60829.802987  144155.142133
# 4     2021-11-05  28576.322026  35036.217192  61068.688871  144841.296668
#
# code         000150        000240        000250        000270         000660  \
# 0     102950.989132  16740.452467  47374.400253  85399.739588  103192.235635
# 1     102184.715265  16703.991530  47726.745965  85155.310393  103625.271618
# 2     101635.379457  16679.461199  48150.661862  85373.731053  104499.141777
# 3     103181.013480  16787.221965  48375.355284  85918.692257  105464.429873
# 4     104036.863300  16930.149135  48431.323573  86642.152898  106424.042960
#
# code  ...        330860        336260        336370        347860  \
# 0     ...  49061.401867  51936.698981  85278.081130  36232.424198
# 1     ...  49113.560615  52898.135319  85898.990330  36309.739364
# 2     ...  49680.640361  53155.759857  87165.515079  37012.262812
# 3     ...  50120.624917  53711.960556  88036.147297  37190.078437
# 4     ...  50303.633031  54248.381002  88014.891185  38564.568864
#
# code        348150        348210         352820         357780        363280  \
# 0     25923.409088  52931.497120  339129.540899  259748.733053  26927.608269
# 1     25921.623350  52819.417570  341346.307653  260194.239296  26919.029746
# 2     26145.015700  53132.302797  340985.058237  260957.606072  26627.320994
# 3     25888.024835  52640.624145  345355.618662  259319.691412  26534.926097
# 4     26080.445542  52962.513018  341376.958207  259466.599307  26347.997090
#
# code        950130
# 0     16813.085583
# 1     17183.990468
# 2     17295.820041
# 3     17370.759710
# 4     18024.580671
#
# [5 rows x 371 columns]

# %% [markdown]
# ## 예측 종가 파일로 출력

# %%
pred_pivot.to_csv('prac4w_pred1w_rate_cat2.csv', index=False)
