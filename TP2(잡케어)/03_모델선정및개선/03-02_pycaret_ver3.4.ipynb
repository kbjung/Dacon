# %% [markdown]
# # 라이브러리 로드 및 기본 세팅

# %%
# !pip install catboost

# %%
# !pip install pycaret

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import pandas as pd
from pycaret.classification import *
from tqdm import tqdm

# %% [markdown]
# # 데이콘 점수

# %%
# 자체 점수 : 0.7021
# 제출 점수(제출 날짜) : 0.6872047442(2021-12-31 05:01:57)

# %% [markdown]
# # 설정

# %%
# pycaret : cat
# probability_threshold : 0.3865
# tune : ❌(자체 점수 떨어짐.)
# comb
# 순서형 특성 수치형으로 지정(4개)
# 'person_attribute_a_a', 'person_attribute_b', 'person_prefer_e', 'contents_attribute_e'

# %%
# 제거된 특성(29개)
# 'id',
# 'contents_open_dt',
# 'contents_rn',
# 'person_prefer_f',
# 'person_prefer_g',
# 'h_m_match_yn',
# 'h_s_match_yn',
# 'person_attribute_b',
# 'contents_attribute_k',
# 'contents_attribute_l_n',
# 'contents_attribute_l_s',
# 'contents_attribute_l_m',
# 'contents_attribute_l_l',
# 'person_prefer_d_1_s',
# 'person_prefer_d_1_m',
# 'person_prefer_d_2_n',
# 'person_prefer_d_2_s',
# 'person_prefer_d_2_m',
# 'person_prefer_d_2_l',
# 'person_prefer_d_3_n',
# 'person_prefer_d_3_s',
# 'person_prefer_d_3_m',
# 'person_prefer_d_3_l',
# 'contents_attribute_d_s',
# 'contents_attribute_d_m',
# 'person_prefer_h_2_m',
# 'person_prefer_h_2_l',
# 'person_prefer_h_3_m',
# 'person_prefer_h_3_l'

# %%
# 매칭 속성

# %%
# d_l_match_yn : 'person_prefer_d_1_l', 'contents_attribute_d_l' 매칭 여부
# d_m_match_yn : 'person_prefer_d_1_n', 'contents_attribute_d_n' 매칭 여부'
# d_s_match_yn : 'person_prefer_d_1', 'contents_attribute_d' 매칭 여부
# h_l_match_yn : 'person_prefer_h_1_l', 'contents_attribute_h_l' 매칭 여부
# h_m_match_yn : 'person_prefer_h_1_m', 'contents_attribute_h_m' 매칭 여부
# h_s_match_yn : 'person_prefer_h_1', 'contents_attribute_h' 매칭 여부

# %% [markdown]
# # 데이터 불러오기

# %%
train = pd.read_csv('../data/df_train.csv')
test = pd.read_csv('../data/df_test.csv')
# train = pd.read_csv('/content/drive/MyDrive/GitHub/Dacon/TP2(잡케어)/data/df_train.csv')
# test = pd.read_csv('/content/drive/MyDrive/GitHub/Dacon/TP2(잡케어)/data/df_test.csv')

# %% [markdown]
# # 데이터 확인

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501951 entries, 0 to 501950
# Data columns (total 63 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   id                      501951 non-null  int64
#  1   d_l_match_yn            501951 non-null  bool
#  2   d_m_match_yn            501951 non-null  bool
#  3   d_s_match_yn            501951 non-null  bool
#  4   h_l_match_yn            501951 non-null  bool
#  5   h_m_match_yn            501951 non-null  bool
#  6   h_s_match_yn            501951 non-null  bool
#  7   person_attribute_a      501951 non-null  int64
#  8   person_attribute_a_1    501951 non-null  int64
#  9   person_attribute_b      501951 non-null  int64
#  10  person_prefer_c         501951 non-null  int64
#  11  person_prefer_d_1       501951 non-null  int64
#  12  person_prefer_d_2       501951 non-null  int64
#  13  person_prefer_d_3       501951 non-null  int64
#  14  person_prefer_e         501951 non-null  int64
#  15  person_prefer_f         501951 non-null  int64
#  16  person_prefer_g         501951 non-null  int64
#  17  person_prefer_h_1       501951 non-null  int64
#  18  person_prefer_h_2       501951 non-null  int64
#  19  person_prefer_h_3       501951 non-null  int64
#  20  contents_attribute_i    501951 non-null  int64
#  21  contents_attribute_a    501951 non-null  int64
#  22  contents_attribute_j_1  501951 non-null  int64
#  23  contents_attribute_j    501951 non-null  int64
#  24  contents_attribute_c    501951 non-null  int64
#  25  contents_attribute_k    501951 non-null  int64
#  26  contents_attribute_l    501951 non-null  int64
#  27  contents_attribute_d    501951 non-null  int64
#  28  contents_attribute_m    501951 non-null  int64
#  29  contents_attribute_e    501951 non-null  int64
#  30  contents_attribute_h    501951 non-null  int64
#  31  person_rn               501951 non-null  int64
#  32  contents_rn             501951 non-null  int64
#  33  contents_open_dt        501951 non-null  object
#  34  target                  501951 non-null  int64
#  35  person_prefer_d_1_n     501951 non-null  int64
#  36  person_prefer_d_1_s     501951 non-null  int64
#  37  person_prefer_d_1_m     501951 non-null  int64
#  38  person_prefer_d_1_l     501951 non-null  int64
#  39  person_prefer_d_2_n     501951 non-null  int64
#  40  person_prefer_d_2_s     501951 non-null  int64
#  41  person_prefer_d_2_m     501951 non-null  int64
#  42  person_prefer_d_2_l     501951 non-null  int64
#  43  person_prefer_d_3_n     501951 non-null  int64
#  44  person_prefer_d_3_s     501951 non-null  int64
#  45  person_prefer_d_3_m     501951 non-null  int64
#  46  person_prefer_d_3_l     501951 non-null  int64
#  47  contents_attribute_d_n  501951 non-null  int64
#  48  contents_attribute_d_s  501951 non-null  int64
#  49  contents_attribute_d_m  501951 non-null  int64
#  50  contents_attribute_d_l  501951 non-null  int64
#  51  person_prefer_h_1_m     501951 non-null  int64
#  52  person_prefer_h_1_l     501951 non-null  int64
#  53  person_prefer_h_2_m     501951 non-null  int64
#  54  person_prefer_h_2_l     501951 non-null  int64
#  55  person_prefer_h_3_m     501951 non-null  int64
#  56  person_prefer_h_3_l     501951 non-null  int64
#  57  contents_attribute_h_m  501951 non-null  int64
#  58  contents_attribute_h_l  501951 non-null  int64
#  59  contents_attribute_l_n  501951 non-null  int64
#  60  contents_attribute_l_s  501951 non-null  int64
#  61  contents_attribute_l_m  501951 non-null  int64
#  62  contents_attribute_l_l  501951 non-null  int64
# dtypes: bool(6), int64(56), object(1)
# memory usage: 221.2+ MB

# %%
train.head()
# Out:
#    id  d_l_match_yn  d_m_match_yn  d_s_match_yn  h_l_match_yn  h_m_match_yn  \
# 0   0          True          True          True         False         False
# 1   1         False         False         False          True          True
# 2   2         False         False         False          True         False
# 3   3         False         False         False          True         False
# 4   4          True          True          True         False         False
#
#    h_s_match_yn  person_attribute_a  person_attribute_a_1  person_attribute_b  \
# 0         False                   1                     4                   3
# 1         False                   1                     3                   4
# 2         False                   2                     0                   3
# 3         False                   2                     0                   2
# 4         False                   1                     3                   4
#
#    person_prefer_c  person_prefer_d_1  person_prefer_d_2  person_prefer_d_3  \
# 0                5                275                370                369
# 1                1                114                181                175
# 2                5                464                175                452
# 3                5                703                705                704
# 4                5                275                370                369
#
#    person_prefer_e  person_prefer_f  person_prefer_g  person_prefer_h_1  \
# 0                8                1                1                  4
# 1                4                1                1                131
# 2                3                1                1                 54
# 3                3                1                1                 72
# 4                4                1                1                214
#
#    person_prefer_h_2  person_prefer_h_3  contents_attribute_i  \
# 0                 95                 59                     3
# 1                101                 96                     1
# 2                263                 56                     3
# 3                227                  2                     1
# 4                210                209                     1
#
#    contents_attribute_a  contents_attribute_j_1  contents_attribute_j  \
# 0                     3                      10                     2
# 1                     3                       5                     1
# 2                     1                      10                     2
# 3                     3                       5                     1
# 4                     1                      10                     2
#
#    contents_attribute_c  contents_attribute_k  contents_attribute_l  \
# 0                     1                     2                  1608
# 1                     1                     2                  1608
# 2                     1                     1                  1600
# 3                     1                     2                  1608
# 4                     1                     2                  1608
#
#    contents_attribute_d  contents_attribute_m  contents_attribute_e  \
# 0                   275                     1                     4
# 1                   275                     1                     4
# 2                    94                     1                     4
# 3                   275                     5                     3
# 4                   275                     1                     4
#
#    contents_attribute_h  person_rn  contents_rn     contents_open_dt  target  \
# 0                   139     618822       354805  2020-01-17 12:09:36       1
# 1                   133     571659       346213  2020-06-18 17:48:52       0
# 2                    53     399816       206408  2020-07-08 20:00:10       0
# 3                    74     827967       572323  2020-01-13 18:09:34       0
# 4                    74     831614       573899  2020-03-09 20:39:22       0
#
#    person_prefer_d_1_n  person_prefer_d_1_s  person_prefer_d_1_m  \
# 0                  275                  274                  274
# 1                  114                  109                   56
# 2                  464                  463                  450
# 3                  703                  703                  690
# 4                  275                  274                  274
#
#    person_prefer_d_1_l  person_prefer_d_2_n  person_prefer_d_2_s  \
# 0                  216                  369                  368
# 1                    1                  175                  152
# 2                  377                  175                  152
# 3                  618                  703                  703
# 4                  216                  369                  368
#
#    person_prefer_d_2_m  person_prefer_d_2_l  person_prefer_d_3_n  \
# 0                  297                  216                  369
# 1                   56                    1                  175
# 2                   56                    1                  452
# 3                  690                  618                  703
# 4                  297                  216                  369
#
#    person_prefer_d_3_s  person_prefer_d_3_m  person_prefer_d_3_l  \
# 0                  368                  297                  216
# 1                  152                   56                    1
# 2                  451                  450                  377
# 3                  703                  690                  618
# 4                  368                  297                  216
#
#    contents_attribute_d_n  contents_attribute_d_s  contents_attribute_d_m  \
# 0                     275                     274                     274
# 1                     275                     274                     274
# 2                      92                      91                      56
# 3                     275                     274                     274
# 4                     275                     274                     274
#
#    contents_attribute_d_l  person_prefer_h_1_m  person_prefer_h_1_l  \
# 0                     216                  316                    3
# 1                     216                  417                   94
# 2                       1                  364                   48
# 3                     216                  379                   71
# 4                     216                  483                  208
#
#    person_prefer_h_2_m  person_prefer_h_2_l  person_prefer_h_3_m  \
# 0                  398                   94                  368
# 1                  400                   94                  399
# 2                  528                  250                  366
# 3                  495                  226                  315
# 4                  481                  208                  480
#
#    person_prefer_h_3_l  contents_attribute_h_m  contents_attribute_h_l  \
# 0                   58                     422                      94
# 1                   94                     417                      94
# 2                   48                     363                      48
# 3                    1                     381                      71
# 4                  208                     381                      71
#
#    contents_attribute_l_n  contents_attribute_l_s  contents_attribute_l_m  \
# 0                    1607                    1606                    1605
# 1                    1607                    1606                    1605
# 2                    1599                    1595                    1572
# 3                    1607                    1606                    1605
# 4                    1607                    1606                    1605
#
#    contents_attribute_l_l
# 0                    2016
# 1                    2016
# 2                    2016
# 3                    2016
# 4                    2016

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46404 entries, 0 to 46403
# Data columns (total 62 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      46404 non-null  int64
#  1   d_l_match_yn            46404 non-null  bool
#  2   d_m_match_yn            46404 non-null  bool
#  3   d_s_match_yn            46404 non-null  bool
#  4   h_l_match_yn            46404 non-null  bool
#  5   h_m_match_yn            46404 non-null  bool
#  6   h_s_match_yn            46404 non-null  bool
#  7   person_attribute_a      46404 non-null  int64
#  8   person_attribute_a_1    46404 non-null  int64
#  9   person_attribute_b      46404 non-null  int64
#  10  person_prefer_c         46404 non-null  int64
#  11  person_prefer_d_1       46404 non-null  int64
#  12  person_prefer_d_2       46404 non-null  int64
#  13  person_prefer_d_3       46404 non-null  int64
#  14  person_prefer_e         46404 non-null  int64
#  15  person_prefer_f         46404 non-null  int64
#  16  person_prefer_g         46404 non-null  int64
#  17  person_prefer_h_1       46404 non-null  int64
#  18  person_prefer_h_2       46404 non-null  int64
#  19  person_prefer_h_3       46404 non-null  int64
#  20  contents_attribute_i    46404 non-null  int64
#  21  contents_attribute_a    46404 non-null  int64
#  22  contents_attribute_j_1  46404 non-null  int64
#  23  contents_attribute_j    46404 non-null  int64
#  24  contents_attribute_c    46404 non-null  int64
#  25  contents_attribute_k    46404 non-null  int64
#  26  contents_attribute_l    46404 non-null  int64
#  27  contents_attribute_d    46404 non-null  int64
#  28  contents_attribute_m    46404 non-null  int64
#  29  contents_attribute_e    46404 non-null  int64
#  30  contents_attribute_h    46404 non-null  int64
#  31  person_rn               46404 non-null  int64
#  32  contents_rn             46404 non-null  int64
#  33  contents_open_dt        46404 non-null  object
#  34  person_prefer_d_1_n     46404 non-null  int64
#  35  person_prefer_d_1_s     46404 non-null  int64
#  36  person_prefer_d_1_m     46404 non-null  int64
#  37  person_prefer_d_1_l     46404 non-null  int64
#  38  person_prefer_d_2_n     46404 non-null  int64
#  39  person_prefer_d_2_s     46404 non-null  int64
#  40  person_prefer_d_2_m     46404 non-null  int64
#  41  person_prefer_d_2_l     46404 non-null  int64
#  42  person_prefer_d_3_n     46404 non-null  int64
#  43  person_prefer_d_3_s     46404 non-null  int64
#  44  person_prefer_d_3_m     46404 non-null  int64
#  45  person_prefer_d_3_l     46404 non-null  int64
#  46  contents_attribute_d_n  46404 non-null  int64
#  47  contents_attribute_d_s  46404 non-null  int64
#  48  contents_attribute_d_m  46404 non-null  int64
#  49  contents_attribute_d_l  46404 non-null  int64
#  50  person_prefer_h_1_m     46404 non-null  int64
#  51  person_prefer_h_1_l     46404 non-null  int64
#  52  person_prefer_h_2_m     46404 non-null  int64
#  53  person_prefer_h_2_l     46404 non-null  int64
#  54  person_prefer_h_3_m     46404 non-null  int64
#  55  person_prefer_h_3_l     46404 non-null  int64
#  56  contents_attribute_h_m  46404 non-null  int64
#  57  contents_attribute_h_l  46404 non-null  int64
#  58  contents_attribute_l_n  46404 non-null  int64
#  59  contents_attribute_l_s  46404 non-null  int64
#  60  contents_attribute_l_m  46404 non-null  int64
#  61  contents_attribute_l_l  46404 non-null  int64
# dtypes: bool(6), int64(55), object(1)
# memory usage: 20.1+ MB

# %%
test.head()
# Out:
#    id  d_l_match_yn  d_m_match_yn  d_s_match_yn  h_l_match_yn  h_m_match_yn  \
# 0   0          True         False         False          True          True
# 1   1         False         False         False          True         False
# 2   2          True         False         False          True          True
# 3   3          True         False         False          True          True
# 4   4          True         False         False          True         False
#
#    h_s_match_yn  person_attribute_a  person_attribute_a_1  person_attribute_b  \
# 0          True                   1                     1                   2
# 1         False                   2                     0                   2
# 2          True                   2                     3                   2
# 3          True                   1                     2                   2
# 4         False                   1                     6                   4
#
#    person_prefer_c  person_prefer_d_1  person_prefer_d_2  person_prefer_d_3  \
# 0                1                857                851               1227
# 1                2                683               1086                662
# 2                1                514                790               1233
# 3                5                114                181                175
# 4                5               1082               1078               1056
#
#    person_prefer_e  person_prefer_f  person_prefer_g  person_prefer_h_1  \
# 0                4                1                1                263
# 1                2                1                1                258
# 2                0                1                1                177
# 3                4                1                1                177
# 4                5                1                1                178
#
#    person_prefer_h_2  person_prefer_h_3  contents_attribute_i  \
# 0                 56                 49                     1
# 1                263                 49                     1
# 2                170                171                     3
# 3                170                171                     3
# 4                177                  4                     3
#
#    contents_attribute_a  contents_attribute_j_1  contents_attribute_j  \
# 0                     3                      10                     2
# 1                     3                       5                     1
# 2                     3                       3                     1
# 3                     3                       5                     1
# 4                     1                       5                     1
#
#    contents_attribute_c  contents_attribute_k  contents_attribute_l  \
# 0                     1                     2                  1147
# 1                     1                     2                  1611
# 2                     1                     2                  1817
# 3                     1                     2                   101
# 4                     1                     1                   985
#
#    contents_attribute_d  contents_attribute_m  contents_attribute_e  \
# 0                   839                     1                     5
# 1                   278                     1                     4
# 2                   490                     3                     4
# 3                   150                     5                     3
# 4                  1097                     1                     4
#
#    contents_attribute_h  person_rn  contents_rn     contents_open_dt  \
# 0                   263     393790       236865  2020-12-01 02:24:18
# 1                   263     394058       236572  2020-12-17 05:42:53
# 2                   177    1002061       704612  2020-12-10 23:33:41
# 3                   177    1000813       704652  2020-12-03 19:44:55
# 4                   177     111146       704413  2020-12-11 21:24:34
#
#    person_prefer_d_1_n  person_prefer_d_1_s  person_prefer_d_1_m  \
# 0                  854                  853                  824
# 1                  683                  677                  659
# 2                  514                  509                  482
# 3                  114                  109                   56
# 4                 1078                 1078                 1053
#
#    person_prefer_d_1_l  person_prefer_d_2_n  person_prefer_d_2_s  \
# 0                  744                  847                  847
# 1                  618                 1086                 1086
# 2                  482                  784                  783
# 3                    1                  175                  152
# 4                  926                 1078                 1078
#
#    person_prefer_d_2_m  person_prefer_d_2_l  person_prefer_d_3_n  \
# 0                  824                  744                 1227
# 1                 1053                  926                  662
# 2                  745                  744                 1227
# 3                   56                    1                  175
# 4                 1053                  926                 1056
#
#    person_prefer_d_3_s  person_prefer_d_3_m  person_prefer_d_3_l  \
# 0                 1227                 1227                  926
# 1                  660                  659                  618
# 2                 1227                 1227                  926
# 3                  152                   56                    1
# 4                 1054                 1053                  926
#
#    contents_attribute_d_n  contents_attribute_d_s  contents_attribute_d_m  \
# 0                     836                     831                     824
# 1                     276                     274                     274
# 2                     490                     490                     482
# 3                     145                     123                      56
# 4                    1097                    1094                    1093
#
#    contents_attribute_d_l  person_prefer_h_1_m  person_prefer_h_1_l  \
# 0                     744                  528                  250
# 1                     216                  523                  250
# 2                     482                  453                  169
# 3                       1                  453                  169
# 4                     926                  454                  169
#
#    person_prefer_h_2_m  person_prefer_h_2_l  person_prefer_h_3_m  \
# 0                  366                   48                  359
# 1                  528                  250                  359
# 2                  451                  169                  452
# 3                  451                  169                  452
# 4                  453                  169                  316
#
#    person_prefer_h_3_l  contents_attribute_h_m  contents_attribute_h_l  \
# 0                   48                     528                     250
# 1                   48                     528                     250
# 2                  169                     453                     169
# 3                  169                     453                     169
# 4                    3                     453                     169
#
#    contents_attribute_l_n  contents_attribute_l_s  contents_attribute_l_m  \
# 0                    1146                    1128                    1021
# 1                    1610                    1606                    1605
# 2                    1812                    1811                    1810
# 3                     101                     100                      99
# 4                     984                     980                     954
#
#    contents_attribute_l_l
# 0                    2010
# 1                    2016
# 2                    2020
# 3                    2006
# 4                    2009

# %% [markdown]
# # 필요 데이터 추출

# %%
# test_col = ['d_l_match_yn', 'd_m_match_yn', 'd_s_match_yn', 'h_l_match_yn',
#  'person_attribute_a', 'person_attribute_a_1', 'person_attribute_b', 'person_prefer_c',
#  'person_prefer_d_1', 'person_prefer_d_2', 'person_prefer_d_3',
#  'person_prefer_e',
#  'person_prefer_h_1', 'person_prefer_h_2', 'person_prefer_h_3', 
#  'contents_attribute_i', 'contents_attribute_a',
#  'contents_attribute_j', 'contents_attribute_j_1', 'contents_attribute_c',
#  'contents_attribute_l', 'contents_attribute_d',
#  'contents_attribute_m', 'contents_attribute_e',
#  'contents_attribute_h',
#  'person_rn']
# target = ['target']
# train_col = test_col + target
# len(train_col), len(test_col)

# %%
# train = train[train_col]
# test = test[test_col]

# %% [markdown]
# ## 훈련에 의미가 적은 열 제거

# %%
# 제거된 특성(29개)
# 'id',
# 'contents_open_dt',
# 'contents_rn',
# 'person_prefer_f',
# 'person_prefer_g',
# 'h_m_match_yn',
# 'h_s_match_yn',
# 'person_attribute_b',
# 'contents_attribute_k',
# 'contents_attribute_l_n',
# 'contents_attribute_l_s',
# 'contents_attribute_l_m',
# 'contents_attribute_l_l',
# 'person_prefer_d_1_s',
# 'person_prefer_d_1_m',
# 'person_prefer_d_2_n',
# 'person_prefer_d_2_s',
# 'person_prefer_d_2_m',
# 'person_prefer_d_2_l',
# 'person_prefer_d_3_n',
# 'person_prefer_d_3_s',
# 'person_prefer_d_3_m',
# 'person_prefer_d_3_l',
# 'contents_attribute_d_s',
# 'contents_attribute_d_m',
# 'person_prefer_h_2_m',
# 'person_prefer_h_2_l',
# 'person_prefer_h_3_m',
# 'person_prefer_h_3_l'

# %%
# 삭제할 특성
pop_col = ['id',
'contents_open_dt',
'contents_rn',
'person_prefer_f',
'person_prefer_g',
'h_m_match_yn',
'h_s_match_yn',
'person_attribute_b',
'contents_attribute_k',
'contents_attribute_l_n',
'contents_attribute_l_s',
'contents_attribute_l_m',
'contents_attribute_l_l',
'person_prefer_d_1_s',
'person_prefer_d_1_m',
'person_prefer_d_2_n',
'person_prefer_d_2_s',
'person_prefer_d_2_m',
'person_prefer_d_2_l',
'person_prefer_d_3_n',
'person_prefer_d_3_s',
'person_prefer_d_3_m',
'person_prefer_d_3_l',
'contents_attribute_d_s',
'contents_attribute_d_m',
'person_prefer_h_2_m',
'person_prefer_h_2_l',
'person_prefer_h_3_m',
'person_prefer_h_3_l']
len(pop_col)
# Out:
# 29

# %%
train = train.drop(pop_col, axis=1) 
test = test.drop(pop_col, axis=1)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501951 entries, 0 to 501950
# Data columns (total 34 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   d_l_match_yn            501951 non-null  bool
#  1   d_m_match_yn            501951 non-null  bool
#  2   d_s_match_yn            501951 non-null  bool
#  3   h_l_match_yn            501951 non-null  bool
#  4   person_attribute_a      501951 non-null  int64
#  5   person_attribute_a_1    501951 non-null  int64
#  6   person_prefer_c         501951 non-null  int64
#  7   person_prefer_d_1       501951 non-null  int64
#  8   person_prefer_d_2       501951 non-null  int64
#  9   person_prefer_d_3       501951 non-null  int64
#  10  person_prefer_e         501951 non-null  int64
#  11  person_prefer_h_1       501951 non-null  int64
#  12  person_prefer_h_2       501951 non-null  int64
#  13  person_prefer_h_3       501951 non-null  int64
#  14  contents_attribute_i    501951 non-null  int64
#  15  contents_attribute_a    501951 non-null  int64
#  16  contents_attribute_j_1  501951 non-null  int64
#  17  contents_attribute_j    501951 non-null  int64
#  18  contents_attribute_c    501951 non-null  int64
#  19  contents_attribute_l    501951 non-null  int64
#  20  contents_attribute_d    501951 non-null  int64
#  21  contents_attribute_m    501951 non-null  int64
#  22  contents_attribute_e    501951 non-null  int64
#  23  contents_attribute_h    501951 non-null  int64
#  24  person_rn               501951 non-null  int64
#  25  target                  501951 non-null  int64
#  26  person_prefer_d_1_n     501951 non-null  int64
#  27  person_prefer_d_1_l     501951 non-null  int64
#  28  contents_attribute_d_n  501951 non-null  int64
#  29  contents_attribute_d_l  501951 non-null  int64
#  30  person_prefer_h_1_m     501951 non-null  int64
#  31  person_prefer_h_1_l     501951 non-null  int64
#  32  contents_attribute_h_m  501951 non-null  int64
#  33  contents_attribute_h_l  501951 non-null  int64
# dtypes: bool(4), int64(30)
# memory usage: 116.8 MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46404 entries, 0 to 46403
# Data columns (total 33 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   d_l_match_yn            46404 non-null  bool
#  1   d_m_match_yn            46404 non-null  bool
#  2   d_s_match_yn            46404 non-null  bool
#  3   h_l_match_yn            46404 non-null  bool
#  4   person_attribute_a      46404 non-null  int64
#  5   person_attribute_a_1    46404 non-null  int64
#  6   person_prefer_c         46404 non-null  int64
#  7   person_prefer_d_1       46404 non-null  int64
#  8   person_prefer_d_2       46404 non-null  int64
#  9   person_prefer_d_3       46404 non-null  int64
#  10  person_prefer_e         46404 non-null  int64
#  11  person_prefer_h_1       46404 non-null  int64
#  12  person_prefer_h_2       46404 non-null  int64
#  13  person_prefer_h_3       46404 non-null  int64
#  14  contents_attribute_i    46404 non-null  int64
#  15  contents_attribute_a    46404 non-null  int64
#  16  contents_attribute_j_1  46404 non-null  int64
#  17  contents_attribute_j    46404 non-null  int64
#  18  contents_attribute_c    46404 non-null  int64
#  19  contents_attribute_l    46404 non-null  int64
#  20  contents_attribute_d    46404 non-null  int64
#  21  contents_attribute_m    46404 non-null  int64
#  22  contents_attribute_e    46404 non-null  int64
#  23  contents_attribute_h    46404 non-null  int64
#  24  person_rn               46404 non-null  int64
#  25  person_prefer_d_1_n     46404 non-null  int64
#  26  person_prefer_d_1_l     46404 non-null  int64
#  27  contents_attribute_d_n  46404 non-null  int64
#  28  contents_attribute_d_l  46404 non-null  int64
#  29  person_prefer_h_1_m     46404 non-null  int64
#  30  person_prefer_h_1_l     46404 non-null  int64
#  31  contents_attribute_h_m  46404 non-null  int64
#  32  contents_attribute_h_l  46404 non-null  int64
# dtypes: bool(4), int64(29)
# memory usage: 10.4 MB

# %% [markdown]
# ## 카테고리형 특성 원핫인코딩시 컬럼 명 겹치는 문제 해결위해 특성명 변경

# %%
# 카테고리형 특성 원핫인코딩시 컬럼 명 겹치는 문제 해결위해 특성명 변경
train = train.rename(columns={'person_attribute_a_1':'person_attribute_a_a'})
train.head()
# Out:
#    d_l_match_yn  d_m_match_yn  d_s_match_yn  h_l_match_yn  person_attribute_a  \
# 0          True          True          True         False                   1
# 1         False         False         False          True                   1
# 2         False         False         False          True                   2
# 3         False         False         False          True                   2
# 4          True          True          True         False                   1
#
#    person_attribute_a_a  person_prefer_c  person_prefer_d_1  \
# 0                     4                5                275
# 1                     3                1                114
# 2                     0                5                464
# 3                     0                5                703
# 4                     3                5                275
#
#    person_prefer_d_2  person_prefer_d_3  person_prefer_e  person_prefer_h_1  \
# 0                370                369                8                  4
# 1                181                175                4                131
# 2                175                452                3                 54
# 3                705                704                3                 72
# 4                370                369                4                214
#
#    person_prefer_h_2  person_prefer_h_3  contents_attribute_i  \
# 0                 95                 59                     3
# 1                101                 96                     1
# 2                263                 56                     3
# 3                227                  2                     1
# 4                210                209                     1
#
#    contents_attribute_a  contents_attribute_j_1  contents_attribute_j  \
# 0                     3                      10                     2
# 1                     3                       5                     1
# 2                     1                      10                     2
# 3                     3                       5                     1
# 4                     1                      10                     2
#
#    contents_attribute_c  contents_attribute_l  contents_attribute_d  \
# 0                     1                  1608                   275
# 1                     1                  1608                   275
# 2                     1                  1600                    94
# 3                     1                  1608                   275
# 4                     1                  1608                   275
#
#    contents_attribute_m  contents_attribute_e  contents_attribute_h  \
# 0                     1                     4                   139
# 1                     1                     4                   133
# 2                     1                     4                    53
# 3                     5                     3                    74
# 4                     1                     4                    74
#
#    person_rn  target  person_prefer_d_1_n  person_prefer_d_1_l  \
# 0     618822       1                  275                  216
# 1     571659       0                  114                    1
# 2     399816       0                  464                  377
# 3     827967       0                  703                  618
# 4     831614       0                  275                  216
#
#    contents_attribute_d_n  contents_attribute_d_l  person_prefer_h_1_m  \
# 0                     275                     216                  316
# 1                     275                     216                  417
# 2                      92                       1                  364
# 3                     275                     216                  379
# 4                     275                     216                  483
#
#    person_prefer_h_1_l  contents_attribute_h_m  contents_attribute_h_l
# 0                    3                     422                      94
# 1                   94                     417                      94
# 2                   48                     363                      48
# 3                   71                     381                      71
# 4                  208                     381                      71

# %%
# 카테고리형 특성 원핫인코딩시 컬럼 명 겹치는 문제 해결위해 특성명 변경
test = test.rename(columns={'person_attribute_a_1':'person_attribute_a_a'})
test.head()
# Out:
#    d_l_match_yn  d_m_match_yn  d_s_match_yn  h_l_match_yn  person_attribute_a  \
# 0          True         False         False          True                   1
# 1         False         False         False          True                   2
# 2          True         False         False          True                   2
# 3          True         False         False          True                   1
# 4          True         False         False          True                   1
#
#    person_attribute_a_a  person_prefer_c  person_prefer_d_1  \
# 0                     1                1                857
# 1                     0                2                683
# 2                     3                1                514
# 3                     2                5                114
# 4                     6                5               1082
#
#    person_prefer_d_2  person_prefer_d_3  person_prefer_e  person_prefer_h_1  \
# 0                851               1227                4                263
# 1               1086                662                2                258
# 2                790               1233                0                177
# 3                181                175                4                177
# 4               1078               1056                5                178
#
#    person_prefer_h_2  person_prefer_h_3  contents_attribute_i  \
# 0                 56                 49                     1
# 1                263                 49                     1
# 2                170                171                     3
# 3                170                171                     3
# 4                177                  4                     3
#
#    contents_attribute_a  contents_attribute_j_1  contents_attribute_j  \
# 0                     3                      10                     2
# 1                     3                       5                     1
# 2                     3                       3                     1
# 3                     3                       5                     1
# 4                     1                       5                     1
#
#    contents_attribute_c  contents_attribute_l  contents_attribute_d  \
# 0                     1                  1147                   839
# 1                     1                  1611                   278
# 2                     1                  1817                   490
# 3                     1                   101                   150
# 4                     1                   985                  1097
#
#    contents_attribute_m  contents_attribute_e  contents_attribute_h  \
# 0                     1                     5                   263
# 1                     1                     4                   263
# 2                     3                     4                   177
# 3                     5                     3                   177
# 4                     1                     4                   177
#
#    person_rn  person_prefer_d_1_n  person_prefer_d_1_l  \
# 0     393790                  854                  744
# 1     394058                  683                  618
# 2    1002061                  514                  482
# 3    1000813                  114                    1
# 4     111146                 1078                  926
#
#    contents_attribute_d_n  contents_attribute_d_l  person_prefer_h_1_m  \
# 0                     836                     744                  528
# 1                     276                     216                  523
# 2                     490                     482                  453
# 3                     145                       1                  453
# 4                    1097                     926                  454
#
#    person_prefer_h_1_l  contents_attribute_h_m  contents_attribute_h_l
# 0                  250                     528                     250
# 1                  250                     528                     250
# 2                  169                     453                     169
# 3                  169                     453                     169
# 4                  169                     453                     169

# %% [markdown]
# ## 카테고리형 특성으로 지정할 특성

# %%
# 원본 데이터에서 순서형 특성
# 'person_attribute_a_a', 'person_attribute_b', 'person_prefer_e', 'contents_attribute_e'

# %%
# 순서형 특성 수치형으로 지정 : ⭕
# 'person_attribute_a_a', 'person_prefer_e', 'contents_attribute_e'

# %%
cat_cols = ['person_attribute_a_a', 'person_prefer_e', 'contents_attribute_e']

# %% [markdown]
# ## bin_numeric_features

# %%
# bin_numeric_features
  # 미리 정의된 bin을 사용하여 연속된 값을 범주형 값으로 변환하는 방법
  # 연속된 값의 고유값이 너무 많거나 예상 범위를 벗어난 극단값이 거의 없는 경우에 효과적

# %%
# 고유값 개수가 100개 이상인 특성
# person_prefer_d_1 : 1093
# person_prefer_d_2 : 1081
# person_prefer_d_3 : 1043
# person_prefer_h_1 : 279
# person_prefer_h_2 : 279
# person_prefer_h_3 : 279
# contents_attribute_l : 1752
# contents_attribute_d : 1065
# contents_attribute_h : 250
# person_prefer_d_1_n : 433
# person_prefer_d_1_s : 137
# person_prefer_d_2_n : 435
# person_prefer_d_2_s : 137
# person_prefer_d_3_n : 420
# person_prefer_d_3_s : 136
# contents_attribute_d_n : 431
# contents_attribute_d_s : 137
# person_prefer_h_1_m : 246
# person_prefer_h_2_m : 246
# person_prefer_h_3_m : 246
# contents_attribute_h_m : 228
# contents_attribute_l_n : 736
# contents_attribute_l_s : 305

# %%
# bin_numeric_features 적용할 특성
# 'person_prefer_d_1', 'person_prefer_d_2', 'person_prefer_d_3', 
# 'person_prefer_h_1', 'person_prefer_h_2', 'person_prefer_h_3',
# 'contents_attribute_l', 'contents_attribute_d', 'contents_attribute_h'
# 'person_prefer_d_1_n', 'person_prefer_d_1_s', 
# 'person_prefer_d_2_n', 'person_prefer_d_2_s',
# 'person_prefer_d_3_n', 'person_prefer_d_3_s',
# 'contents_attribute_d_n', 'contents_attribute_d_s',
# 'person_prefer_h_1_m', 'person_prefer_h_2_m', 'person_prefer_h_3_m',
# 'contents_attribute_h_m', 'contents_attribute_l_n', 'contents_attribute_l_s'

# %%
bin_cols = ['person_prefer_d_1', 'person_prefer_d_2', 'person_prefer_d_3', 
            'person_prefer_h_1', 'person_prefer_h_2', 'person_prefer_h_3',
            'contents_attribute_l', 'contents_attribute_d', 'contents_attribute_h',
            'person_prefer_d_1_n', 'person_prefer_d_1_s', 
            'person_prefer_d_2_n', 'person_prefer_d_2_s',
            'person_prefer_d_3_n', 'person_prefer_d_3_s',
            'contents_attribute_d_n', 'contents_attribute_d_s', 
            'person_prefer_h_1_m', 'person_prefer_h_2_m', 'person_prefer_h_3_m',
            'contents_attribute_h_m', 'contents_attribute_l_n', 'contents_attribute_l_s']

# %% [markdown]
# # 모델 훈련/예측

# %%
ex = setup(train, target='target', n_jobs=-1, 
           session_id=0, verbose=False, silent=True, 
           fold=5, fold_shuffle=True, combine_rare_levels=True,
           numeric_features = cat_cols
           )
# 43s

# %% [markdown]
# ## 모델 비교

# %%
compare_models(sort='F1')
# 53m 24s
# Out:
# <style  type="text/css" >
#     #T_92f79_ th {
#           text-align: left;
#     }#T_92f79_row0_col0,#T_92f79_row0_col3,#T_92f79_row1_col0,#T_92f79_row1_col1,#T_92f79_row1_col2,#T_92f79_row1_col3,#T_92f79_row1_col4,#T_92f79_row1_col5,#T_92f79_row1_col6,#T_92f79_row1_col7,#T_92f79_row2_col0,#T_92f79_row2_col1,#T_92f79_row2_col2,#T_92f79_row2_col3,#T_92f79_row2_col4,#T_92f79_row2_col5,#T_92f79_row2_col6,#T_92f79_row2_col7,#T_92f79_row3_col0,#T_92f79_row3_col1,#T_92f79_row3_col2,#T_92f79_row3_col3,#T_92f79_row3_col4,#T_92f79_row3_col5,#T_92f79_row3_col6,#T_92f79_row3_col7,#T_92f79_row4_col0,#T_92f79_row4_col1,#T_92f79_row4_col2,#T_92f79_row4_col3,#T_92f79_row4_col4,#T_92f79_row4_col5,#T_92f79_row4_col6,#T_92f79_row4_col7,#T_92f79_row5_col0,#T_92f79_row5_col1,#T_92f79_row5_col2,#T_92f79_row5_col3,#T_92f79_row5_col4,#T_92f79_row5_col5,#T_92f79_row5_col6,#T_92f79_row5_col7,#T_92f79_row6_col0,#T_92f79_row6_col1,#T_92f79_row6_col2,#T_92f79_row6_col3,#T_92f79_row6_col4,#T_92f79_row6_col5,#T_92f79_row6_col6,#T_92f79_row6_col7,#T_92f79_row7_col0,#T_92f79_row7_col1,#T_92f79_row7_col2,#T_92f79_row7_col4,#T_92f79_row7_col5,#T_92f79_row7_col6,#T_92f79_row7_col7,#T_92f79_row8_col0,#T_92f79_row8_col1,#T_92f79_row8_col2,#T_92f79_row8_col3,#T_92f79_row8_col4,#T_92f79_row8_col5,#T_92f79_row8_col6,#T_92f79_row8_col7,#T_92f79_row9_col0,#T_92f79_row9_col1,#T_92f79_row9_col2,#T_92f79_row9_col3,#T_92f79_row9_col4,#T_92f79_row9_col5,#T_92f79_row9_col6,#T_92f79_row9_col7,#T_92f79_row10_col0,#T_92f79_row10_col1,#T_92f79_row10_col2,#T_92f79_row10_col3,#T_92f79_row10_col4,#T_92f79_row10_col5,#T_92f79_row10_col6,#T_92f79_row10_col7,#T_92f79_row11_col0,#T_92f79_row11_col1,#T_92f79_row11_col2,#T_92f79_row11_col3,#T_92f79_row11_col4,#T_92f79_row11_col5,#T_92f79_row11_col6,#T_92f79_row11_col7,#T_92f79_row12_col0,#T_92f79_row12_col1,#T_92f79_row12_col2,#T_92f79_row12_col3,#T_92f79_row12_col4,#T_92f79_row12_col5,#T_92f79_row12_col6,#T_92f79_row12_col7,#T_92f79_row13_col0,#T_92f79_row13_col1,#T_92f79_row13_col2,#T_92f79_row13_col3,#T_92f79_row13_col4,#T_92f79_row13_col5,#T_92f79_row13_col6,#T_92f79_row13_col7{
#             text-align:  left;
#             text-align:  left;
#         }#T_92f79_row0_col1,#T_92f79_row0_col2,#T_92f79_row0_col4,#T_92f79_row0_col5,#T_92f79_row0_col6,#T_92f79_row0_col7,#T_92f79_row7_col3{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_92f79_row0_col8,#T_92f79_row1_col8,#T_92f79_row2_col8,#T_92f79_row3_col8,#T_92f79_row4_col8,#T_92f79_row5_col8,#T_92f79_row6_col8,#T_92f79_row7_col8,#T_92f79_row8_col8,#T_92f79_row9_col8,#T_92f79_row10_col8,#T_92f79_row11_col8,#T_92f79_row12_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_92f79_row13_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_92f79_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_92f79_level0_row0" class="row_heading level0 row0" >catboost</th>
#                         <td id="T_92f79_row0_col0" class="data row0 col0" >CatBoost Classifier</td>
#                         <td id="T_92f79_row0_col1" class="data row0 col1" >0.6233</td>
#                         <td id="T_92f79_row0_col2" class="data row0 col2" >0.6715</td>
#                         <td id="T_92f79_row0_col3" class="data row0 col3" >0.6736</td>
#                         <td id="T_92f79_row0_col4" class="data row0 col4" >0.6117</td>
#                         <td id="T_92f79_row0_col5" class="data row0 col5" >0.6412</td>
#                         <td id="T_92f79_row0_col6" class="data row0 col6" >0.2466</td>
#                         <td id="T_92f79_row0_col7" class="data row0 col7" >0.2479</td>
#                         <td id="T_92f79_row0_col8" class="data row0 col8" >64.9300</td>
#             </tr>
#             <tr>
#                         <th id="T_92f79_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#                         <td id="T_92f79_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#                         <td id="T_92f79_row1_col1" class="data row1 col1" >0.6131</td>
#                         <td id="T_92f79_row1_col2" class="data row1 col2" >0.6587</td>
#                         <td id="T_92f79_row1_col3" class="data row1 col3" >0.6721</td>
#                         <td id="T_92f79_row1_col4" class="data row1 col4" >0.6009</td>
#                         <td id="T_92f79_row1_col5" class="data row1 col5" >0.6345</td>
#                         <td id="T_92f79_row1_col6" class="data row1 col6" >0.2262</td>
#                         <td id="T_92f79_row1_col7" class="data row1 col7" >0.2278</td>
#                         <td id="T_92f79_row1_col8" class="data row1 col8" >5.3060</td>
#             </tr>
#             <tr>
#                         <th id="T_92f79_level0_row2" class="row_heading level0 row2" >rf</th>
#                         <td id="T_92f79_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#                         <td id="T_92f79_row2_col1" class="data row2 col1" >0.6118</td>
#                         <td id="T_92f79_row2_col2" class="data row2 col2" >0.6571</td>
#                         <td id="T_92f79_row2_col3" class="data row2 col3" >0.6220</td>
#                         <td id="T_92f79_row2_col4" class="data row2 col4" >0.6093</td>
#                         <td id="T_92f79_row2_col5" class="data row2 col5" >0.6155</td>
#                         <td id="T_92f79_row2_col6" class="data row2 col6" >0.2236</td>
#                         <td id="T_92f79_row2_col7" class="data row2 col7" >0.2237</td>
#                         <td id="T_92f79_row2_col8" class="data row2 col8" >65.2280</td>
#             </tr>
#             <tr>
#                         <th id="T_92f79_level0_row3" class="row_heading level0 row3" >gbc</th>
#                         <td id="T_92f79_row3_col0" class="data row3 col0" >Gradient Boosting Classifier</td>
#                         <td id="T_92f79_row3_col1" class="data row3 col1" >0.5995</td>
#                         <td id="T_92f79_row3_col2" class="data row3 col2" >0.6409</td>
#                         <td id="T_92f79_row3_col3" class="data row3 col3" >0.6356</td>
#                         <td id="T_92f79_row3_col4" class="data row3 col4" >0.5925</td>
#                         <td id="T_92f79_row3_col5" class="data row3 col5" >0.6133</td>
#                         <td id="T_92f79_row3_col6" class="data row3 col6" >0.1990</td>
#                         <td id="T_92f79_row3_col7" class="data row3 col7" >0.1996</td>
#                         <td id="T_92f79_row3_col8" class="data row3 col8" >114.4220</td>
#             </tr>
#             <tr>
#                         <th id="T_92f79_level0_row4" class="row_heading level0 row4" >ridge</th>
#                         <td id="T_92f79_row4_col0" class="data row4 col0" >Ridge Classifier</td>
#                         <td id="T_92f79_row4_col1" class="data row4 col1" >0.5914</td>
#                         <td id="T_92f79_row4_col2" class="data row4 col2" >0.0000</td>
#                         <td id="T_92f79_row4_col3" class="data row4 col3" >0.6262</td>
#                         <td id="T_92f79_row4_col4" class="data row4 col4" >0.5852</td>
#                         <td id="T_92f79_row4_col5" class="data row4 col5" >0.6050</td>
#                         <td id="T_92f79_row4_

# %%
# 모델 생성
model = create_model('catboost')
# 7m 6s
# Out:
# <style  type="text/css" >
# #T_cfeb3_row5_col0,#T_cfeb3_row5_col1,#T_cfeb3_row5_col2,#T_cfeb3_row5_col3,#T_cfeb3_row5_col4,#T_cfeb3_row5_col5,#T_cfeb3_row5_col6{
#             background:  yellow;
#         }</style><table id="T_cfeb3_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cfeb3_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_cfeb3_row0_col0" class="data row0 col0" >0.6213</td>
#                         <td id="T_cfeb3_row0_col1" class="data row0 col1" >0.6702</td>
#                         <td id="T_cfeb3_row0_col2" class="data row0 col2" >0.6719</td>
#                         <td id="T_cfeb3_row0_col3" class="data row0 col3" >0.6099</td>
#                         <td id="T_cfeb3_row0_col4" class="data row0 col4" >0.6394</td>
#                         <td id="T_cfeb3_row0_col5" class="data row0 col5" >0.2427</td>
#                         <td id="T_cfeb3_row0_col6" class="data row0 col6" >0.2440</td>
#             </tr>
#             <tr>
#                         <th id="T_cfeb3_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_cfeb3_row1_col0" class="data row1 col0" >0.6225</td>
#                         <td id="T_cfeb3_row1_col1" class="data row1 col1" >0.6705</td>
#                         <td id="T_cfeb3_row1_col2" class="data row1 col2" >0.6724</td>
#                         <td id="T_cfeb3_row1_col3" class="data row1 col3" >0.6111</td>
#                         <td id="T_cfeb3_row1_col4" class="data row1 col4" >0.6403</td>
#                         <td id="T_cfeb3_row1_col5" class="data row1 col5" >0.2451</td>
#                         <td id="T_cfeb3_row1_col6" class="data row1 col6" >0.2464</td>
#             </tr>
#             <tr>
#                         <th id="T_cfeb3_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_cfeb3_row2_col0" class="data row2 col0" >0.6251</td>
#                         <td id="T_cfeb3_row2_col1" class="data row2 col1" >0.6741</td>
#                         <td id="T_cfeb3_row2_col2" class="data row2 col2" >0.6740</td>
#                         <td id="T_cfeb3_row2_col3" class="data row2 col3" >0.6137</td>
#                         <td id="T_cfeb3_row2_col4" class="data row2 col4" >0.6424</td>
#                         <td id="T_cfeb3_row2_col5" class="data row2 col5" >0.2503</td>
#                         <td id="T_cfeb3_row2_col6" class="data row2 col6" >0.2515</td>
#             </tr>
#             <tr>
#                         <th id="T_cfeb3_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_cfeb3_row3_col0" class="data row3 col0" >0.6239</td>
#                         <td id="T_cfeb3_row3_col1" class="data row3 col1" >0.6719</td>
#                         <td id="T_cfeb3_row3_col2" class="data row3 col2" >0.6752</td>
#                         <td id="T_cfeb3_row3_col3" class="data row3 col3" >0.6121</td>
#                         <td id="T_cfeb3_row3_col4" class="data row3 col4" >0.6421</td>
#                         <td id="T_cfeb3_row3_col5" class="data row3 col5" >0.2479</td>
#                         <td id="T_cfeb3_row3_col6" class="data row3 col6" >0.2492</td>
#             </tr>
#             <tr>
#                         <th id="T_cfeb3_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_cfeb3_row4_col0" class="data row4 col0" >0.6234</td>
#                         <td id="T_cfeb3_row4_col1" class="data row4 col1" >0.6705</td>
#                         <td id="T_cfeb3_row4_col2" class="data row4 col2" >0.6747</td>
#                         <td id="T_cfeb3_row4_col3" class="data row4 col3" >0.6116</td>
#                         <td id="T_cfeb3_row4_col4" class="data row4 col4" >0.6416</td>
#                         <td id="T_cfeb3_row4_col5" class="data row4 col5" >0.2469</td>
#                         <td id="T_cfeb3_row4_col6" class="data row4 col6" >0.2482</td>
#             </tr>
#             <tr>
#                         <th id="T_cfeb3_level0_row5" class="row_heading level0 row5" >Mean</th>
#                         <td id="T_cfeb3_row5_col0" class="data row5 col0" >0.6233</td>
#                         <td id="T_cfeb3_row5_col1" class="data row5 col1" >0.6715</td>
#                         <td id="T_cfeb3_row5_col2" class="data row5 col2" >0.6736</td>
#                         <td id="T_cfeb3_row5_col3" class="data row5 col3" >0.6117</td>
#                         <td id="T_cfeb3_row5_col4" class="data row5 col4" >0.6412</td>
#                         <td id="T_cfeb3_row5_col5" class="data row5 col5" >0.2466</td>
#                         <td id="T_cfeb3_row5_col6" class="data row5 col6" >0.2479</td>
#             </tr>
#             <tr>
#                         <th id="T_cfeb3_level0_row6" class="row_heading level0 row6" >SD</th>
#                         <td id="T_cfeb3_row6_col0" class="data row6 col0" >0.0013</td>
#                         <td id="T_cfeb3_row6_col1" class="data row6 col1" >0.0015</td>
#                         <td id="T_cfeb3_row6_col2" class="data row6 col2" >0.0013</td>
#                         <td id="T_cfeb3_row6_col3" class="data row6 col3" >0.0012</td>
#                         <td id="T_cfeb3_row6_col4" class="data row6 col4" >0.0011</td>
#                         <td id="T_cfeb3_row6_col5" class="data row6 col5" >0.0026</td>
#                         <td id="T_cfeb3_row6_col6" class="data row6 col6" >0.0026</td>
#             </tr>
#     </tbody></table>

# %%
plot_model(model, plot='confusion_matrix')

# %%
# optimize threshold for trained model
optimize_threshold(model, false_negative=-1500, false_positive=-900)
# 40s
# Out:
# Optimized Probability Threshold: 0.3865 | Optimized Cost Function: -59037900
# 0.3865

# %% [markdown]
# ## train 예측, F1 자체평가

# %%
from pycaret.utils import check_metric

# %%
th = 0.3865
train_pred = predict_model(model, train, probability_threshold=th)
check_metric(train['target'], train_pred['Label'], metric = 'F1')
# fn, fp = -1500, -900 / threshold, f1 score =  0.3865, 0.7021
# 44s
# Out:
# 0.7021

# %% [markdown]
# ## test 예측

# %%
# 예측
pred = predict_model(model, test, probability_threshold=th)

# %%
pred.iloc[:,-2:].head()
# Out:
#    Label   Score
# 0      1  0.5072
# 1      1  0.4931
# 2      1  0.4104
# 3      1  0.4486
# 4      1  0.5432

# %%
pred['Label']
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 46399    1
# 46400    1
# 46401    1
# 46402    1
# 46403    1
# Name: Label, Length: 46404, dtype: int32

# %%
pred['Label'].value_counts()
# Out:
# 1    36344
# 0    10060
# Name: Label, dtype: int64

# %% [markdown]
# # 제출파일 불러오기

# %%
sub = pd.read_csv('../data/sample_submission.csv')
# sub = pd.read_csv('/content/drive/MyDrive/GitHub/Dacon/TP2(잡케어)/data/sample_submission.csv')
sub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46404 entries, 0 to 46403
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      46404 non-null  int64
#  1   target  46404 non-null  int64
# dtypes: int64(2)
# memory usage: 725.2 KB

# %%
sub.head()
# Out:
#    id  target
# 0   0       0
# 1   1       0
# 2   2       0
# 3   3       0
# 4   4       0

# %% [markdown]
# # 제출파일 생성

# %%
sub['target'] = pred['Label']
sub.to_csv('sub_ver3.4.csv', index=False)
# sub.to_csv('/content/drive/MyDrive/GitHub/Dacon/TP2(잡케어)/03_모델선정및개선/sub_ver3.4.csv', index=False)

# %%
sub.head()
# Out:
#    id  target
# 0   0       1
# 1   1       1
# 2   2       1
# 3   3       1
# 4   4       1

# %% [markdown]
# # 코드 마지막
