# %%
import pandas as pd
from pycaret.classification import *
from tqdm import tqdm

# %% [markdown]
# # 데이콘 점수

# %%
# 제출 점수(제출 날짜) : 0.6447103781(2021-12-19 01:56:31)

# %% [markdown]
# # 설정

# %%
# id, contents_open_dt 제거 : ⭕
# 모든 값이 1인 person_prefer_f, person_prefer_g 열 제거 : ⭕
# person_rn, contents_rn 제거 : ⭕
# 중복 샘플 제거 : ❌

# %%
# pycaret, nb
# combine
# 순서형 특성 수치형으로 지정 : ⭕
    # 'person_attribute_a_a', 'person_attribute_b', 'person_prefer_e', 'contents_attribute_e'

# %% [markdown]
# # 데이터 불러오기

# %%
train = pd.read_csv('../data/train.csv')
test = pd.read_csv('../data/test.csv')

# %% [markdown]
# # 데이터 확인

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501951 entries, 0 to 501950
# Data columns (total 35 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   id                      501951 non-null  int64
#  1   d_l_match_yn            501951 non-null  bool
#  2   d_m_match_yn            501951 non-null  bool
#  3   d_s_match_yn            501951 non-null  bool
#  4   h_l_match_yn            501951 non-null  bool
#  5   h_m_match_yn            501951 non-null  bool
#  6   h_s_match_yn            501951 non-null  bool
#  7   person_attribute_a      501951 non-null  int64
#  8   person_attribute_a_1    501951 non-null  int64
#  9   person_attribute_b      501951 non-null  int64
#  10  person_prefer_c         501951 non-null  int64
#  11  person_prefer_d_1       501951 non-null  int64
#  12  person_prefer_d_2       501951 non-null  int64
#  13  person_prefer_d_3       501951 non-null  int64
#  14  person_prefer_e         501951 non-null  int64
#  15  person_prefer_f         501951 non-null  int64
#  16  person_prefer_g         501951 non-null  int64
#  17  person_prefer_h_1       501951 non-null  int64
#  18  person_prefer_h_2       501951 non-null  int64
#  19  person_prefer_h_3       501951 non-null  int64
#  20  contents_attribute_i    501951 non-null  int64
#  21  contents_attribute_a    501951 non-null  int64
#  22  contents_attribute_j_1  501951 non-null  int64
#  23  contents_attribute_j    501951 non-null  int64
#  24  contents_attribute_c    501951 non-null  int64
#  25  contents_attribute_k    501951 non-null  int64
#  26  contents_attribute_l    501951 non-null  int64
#  27  contents_attribute_d    501951 non-null  int64
#  28  contents_attribute_m    501951 non-null  int64
#  29  contents_attribute_e    501951 non-null  int64
#  30  contents_attribute_h    501951 non-null  int64
#  31  person_rn               501951 non-null  int64
#  32  contents_rn             501951 non-null  int64
#  33  contents_open_dt        501951 non-null  object
#  34  target                  501951 non-null  int64
# dtypes: bool(6), int64(28), object(1)
# memory usage: 113.9+ MB

# %%
train.head()
# Out:
#    id  d_l_match_yn  d_m_match_yn  d_s_match_yn  h_l_match_yn  h_m_match_yn  \
# 0   0          True          True          True         False         False
# 1   1         False         False         False          True          True
# 2   2         False         False         False          True         False
# 3   3         False         False         False          True         False
# 4   4          True          True          True         False         False
#
#    h_s_match_yn  person_attribute_a  person_attribute_a_1  person_attribute_b  \
# 0         False                   1                     4                   3
# 1         False                   1                     3                   4
# 2         False                   2                     0                   3
# 3         False                   2                     0                   2
# 4         False                   1                     3                   4
#
#    person_prefer_c  person_prefer_d_1  person_prefer_d_2  person_prefer_d_3  \
# 0                5                275                370                369
# 1                1                114                181                175
# 2                5                464                175                452
# 3                5                703                705                704
# 4                5                275                370                369
#
#    person_prefer_e  person_prefer_f  person_prefer_g  person_prefer_h_1  \
# 0                8                1                1                  4
# 1                4                1                1                131
# 2                3                1                1                 54
# 3                3                1                1                 72
# 4                4                1                1                214
#
#    person_prefer_h_2  person_prefer_h_3  contents_attribute_i  \
# 0                 95                 59                     3
# 1                101                 96                     1
# 2                263                 56                     3
# 3                227                  2                     1
# 4                210                209                     1
#
#    contents_attribute_a  contents_attribute_j_1  contents_attribute_j  \
# 0                     3                      10                     2
# 1                     3                       5                     1
# 2                     1                      10                     2
# 3                     3                       5                     1
# 4                     1                      10                     2
#
#    contents_attribute_c  contents_attribute_k  contents_attribute_l  \
# 0                     1                     2                  1608
# 1                     1                     2                  1608
# 2                     1                     1                  1600
# 3                     1                     2                  1608
# 4                     1                     2                  1608
#
#    contents_attribute_d  contents_attribute_m  contents_attribute_e  \
# 0                   275                     1                     4
# 1                   275                     1                     4
# 2                    94                     1                     4
# 3                   275                     5                     3
# 4                   275                     1                     4
#
#    contents_attribute_h  person_rn  contents_rn     contents_open_dt  target
# 0                   139     618822       354805  2020-01-17 12:09:36       1
# 1                   133     571659       346213  2020-06-18 17:48:52       0
# 2                    53     399816       206408  2020-07-08 20:00:10       0
# 3                    74     827967       572323  2020-01-13 18:09:34       0
# 4                    74     831614       573899  2020-03-09 20:39:22       0

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46404 entries, 0 to 46403
# Data columns (total 34 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      46404 non-null  int64
#  1   d_l_match_yn            46404 non-null  bool
#  2   d_m_match_yn            46404 non-null  bool
#  3   d_s_match_yn            46404 non-null  bool
#  4   h_l_match_yn            46404 non-null  bool
#  5   h_m_match_yn            46404 non-null  bool
#  6   h_s_match_yn            46404 non-null  bool
#  7   person_attribute_a      46404 non-null  int64
#  8   person_attribute_a_1    46404 non-null  int64
#  9   person_attribute_b      46404 non-null  int64
#  10  person_prefer_c         46404 non-null  int64
#  11  person_prefer_d_1       46404 non-null  int64
#  12  person_prefer_d_2       46404 non-null  int64
#  13  person_prefer_d_3       46404 non-null  int64
#  14  person_prefer_e         46404 non-null  int64
#  15  person_prefer_f         46404 non-null  int64
#  16  person_prefer_g         46404 non-null  int64
#  17  person_prefer_h_1       46404 non-null  int64
#  18  person_prefer_h_2       46404 non-null  int64
#  19  person_prefer_h_3       46404 non-null  int64
#  20  contents_attribute_i    46404 non-null  int64
#  21  contents_attribute_a    46404 non-null  int64
#  22  contents_attribute_j_1  46404 non-null  int64
#  23  contents_attribute_j    46404 non-null  int64
#  24  contents_attribute_c    46404 non-null  int64
#  25  contents_attribute_k    46404 non-null  int64
#  26  contents_attribute_l    46404 non-null  int64
#  27  contents_attribute_d    46404 non-null  int64
#  28  contents_attribute_m    46404 non-null  int64
#  29  contents_attribute_e    46404 non-null  int64
#  30  contents_attribute_h    46404 non-null  int64
#  31  person_rn               46404 non-null  int64
#  32  contents_rn             46404 non-null  int64
#  33  contents_open_dt        46404 non-null  object
# dtypes: bool(6), int64(27), object(1)
# memory usage: 10.2+ MB

# %%
test.head()
# Out:
#    id  d_l_match_yn  d_m_match_yn  d_s_match_yn  h_l_match_yn  h_m_match_yn  \
# 0   0          True         False         False          True          True
# 1   1         False         False         False          True         False
# 2   2          True         False         False          True          True
# 3   3          True         False         False          True          True
# 4   4          True         False         False          True         False
#
#    h_s_match_yn  person_attribute_a  person_attribute_a_1  person_attribute_b  \
# 0          True                   1                     1                   2
# 1         False                   2                     0                   2
# 2          True                   2                     3                   2
# 3          True                   1                     2                   2
# 4         False                   1                     6                   4
#
#    person_prefer_c  person_prefer_d_1  person_prefer_d_2  person_prefer_d_3  \
# 0                1                857                851               1227
# 1                2                683               1086                662
# 2                1                514                790               1233
# 3                5                114                181                175
# 4                5               1082               1078               1056
#
#    person_prefer_e  person_prefer_f  person_prefer_g  person_prefer_h_1  \
# 0                4                1                1                263
# 1                2                1                1                258
# 2                0                1                1                177
# 3                4                1                1                177
# 4                5                1                1                178
#
#    person_prefer_h_2  person_prefer_h_3  contents_attribute_i  \
# 0                 56                 49                     1
# 1                263                 49                     1
# 2                170                171                     3
# 3                170                171                     3
# 4                177                  4                     3
#
#    contents_attribute_a  contents_attribute_j_1  contents_attribute_j  \
# 0                     3                      10                     2
# 1                     3                       5                     1
# 2                     3                       3                     1
# 3                     3                       5                     1
# 4                     1                       5                     1
#
#    contents_attribute_c  contents_attribute_k  contents_attribute_l  \
# 0                     1                     2                  1147
# 1                     1                     2                  1611
# 2                     1                     2                  1817
# 3                     1                     2                   101
# 4                     1                     1                   985
#
#    contents_attribute_d  contents_attribute_m  contents_attribute_e  \
# 0                   839                     1                     5
# 1                   278                     1                     4
# 2                   490                     3                     4
# 3                   150                     5                     3
# 4                  1097                     1                     4
#
#    contents_attribute_h  person_rn  contents_rn     contents_open_dt
# 0                   263     393790       236865  2020-12-01 02:24:18
# 1                   263     394058       236572  2020-12-17 05:42:53
# 2                   177    1002061       704612  2020-12-10 23:33:41
# 3                   177    1000813       704652  2020-12-03 19:44:55
# 4                   177     111146       704413  2020-12-11 21:24:34

# %% [markdown]
# # 필요 데이터 추출

# %%
# person_rn :  사용자번호
# contents_rn :  컨텐츠번호
# contents_open_dt :  컨텐츠 열람 일시

# %% [markdown]
# ## 훈련에 의미가 적은 열 제거

# %%
# id, contents_open_dt 제거 : ⭕
# 모든 값이 1인 'person_prefer_f', 'person_prefer_g' 열 제거 : ⭕
# 'person_rn', 'contents_rn' 제거 : ⭕
# 중복 샘플 제거 : ❌

# %%
# train = train.drop(['id', 'contents_open_dt', 'person_prefer_f'], axis=1)
# test = test.drop(['id', 'contents_open_dt', 'person_prefer_f'], axis=1)

# %%
train = train.drop(['id', 'contents_open_dt', 'person_prefer_f', 'person_prefer_g', 'person_rn', 'contents_rn'], axis=1)
test = test.drop(['id', 'contents_open_dt', 'person_prefer_f', 'person_prefer_g', 'person_rn', 'contents_rn'], axis=1)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501951 entries, 0 to 501950
# Data columns (total 29 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   d_l_match_yn            501951 non-null  bool
#  1   d_m_match_yn            501951 non-null  bool
#  2   d_s_match_yn            501951 non-null  bool
#  3   h_l_match_yn            501951 non-null  bool
#  4   h_m_match_yn            501951 non-null  bool
#  5   h_s_match_yn            501951 non-null  bool
#  6   person_attribute_a      501951 non-null  int64
#  7   person_attribute_a_1    501951 non-null  int64
#  8   person_attribute_b      501951 non-null  int64
#  9   person_prefer_c         501951 non-null  int64
#  10  person_prefer_d_1       501951 non-null  int64
#  11  person_prefer_d_2       501951 non-null  int64
#  12  person_prefer_d_3       501951 non-null  int64
#  13  person_prefer_e         501951 non-null  int64
#  14  person_prefer_h_1       501951 non-null  int64
#  15  person_prefer_h_2       501951 non-null  int64
#  16  person_prefer_h_3       501951 non-null  int64
#  17  contents_attribute_i    501951 non-null  int64
#  18  contents_attribute_a    501951 non-null  int64
#  19  contents_attribute_j_1  501951 non-null  int64
#  20  contents_attribute_j    501951 non-null  int64
#  21  contents_attribute_c    501951 non-null  int64
#  22  contents_attribute_k    501951 non-null  int64
#  23  contents_attribute_l    501951 non-null  int64
#  24  contents_attribute_d    501951 non-null  int64
#  25  contents_attribute_m    501951 non-null  int64
#  26  contents_attribute_e    501951 non-null  int64
#  27  contents_attribute_h    501951 non-null  int64
#  28  target                  501951 non-null  int64
# dtypes: bool(6), int64(23)
# memory usage: 91.0 MB

# %% [markdown]
# ## 카테고리형 특성 원핫인코딩시 컬럼 명 겹치는 문제 해결위해 특성명 변경

# %%
# 카테고리형 특성 원핫인코딩시 컬럼 명 겹치는 문제 해결위해 특성명 변경
train = train.rename(columns={'person_attribute_a_1':'person_attribute_a_a'})
train.head()
# Out:
#    d_l_match_yn  d_m_match_yn  d_s_match_yn  h_l_match_yn  h_m_match_yn  \
# 0          True          True          True         False         False
# 1         False         False         False          True          True
# 2         False         False         False          True         False
# 3         False         False         False          True         False
# 4          True          True          True         False         False
#
#    h_s_match_yn  person_attribute_a  person_attribute_a_a  person_attribute_b  \
# 0         False                   1                     4                   3
# 1         False                   1                     3                   4
# 2         False                   2                     0                   3
# 3         False                   2                     0                   2
# 4         False                   1                     3                   4
#
#    person_prefer_c  person_prefer_d_1  person_prefer_d_2  person_prefer_d_3  \
# 0                5                275                370                369
# 1                1                114                181                175
# 2                5                464                175                452
# 3                5                703                705                704
# 4                5                275                370                369
#
#    person_prefer_e  person_prefer_h_1  person_prefer_h_2  person_prefer_h_3  \
# 0                8                  4                 95                 59
# 1                4                131                101                 96
# 2                3                 54                263                 56
# 3                3                 72                227                  2
# 4                4                214                210                209
#
#    contents_attribute_i  contents_attribute_a  contents_attribute_j_1  \
# 0                     3                     3                      10
# 1                     1                     3                       5
# 2                     3                     1                      10
# 3                     1                     3                       5
# 4                     1                     1                      10
#
#    contents_attribute_j  contents_attribute_c  contents_attribute_k  \
# 0                     2                     1                     2
# 1                     1                     1                     2
# 2                     2                     1                     1
# 3                     1                     1                     2
# 4                     2                     1                     2
#
#    contents_attribute_l  contents_attribute_d  contents_attribute_m  \
# 0                  1608                   275                     1
# 1                  1608                   275                     1
# 2                  1600                    94                     1
# 3                  1608                   275                     5
# 4                  1608                   275                     1
#
#    contents_attribute_e  contents_attribute_h  target
# 0                     4                   139       1
# 1                     4                   133       0
# 2                     4                    53       0
# 3                     3                    74       0
# 4                     4                    74       0

# %%
# 카테고리형 특성 원핫인코딩시 컬럼 명 겹치는 문제 해결위해 특성명 변경
test = test.rename(columns={'person_attribute_a_1':'person_attribute_a_a'})
test.head()
# Out:
#    d_l_match_yn  d_m_match_yn  d_s_match_yn  h_l_match_yn  h_m_match_yn  \
# 0          True         False         False          True          True
# 1         False         False         False          True         False
# 2          True         False         False          True          True
# 3          True         False         False          True          True
# 4          True         False         False          True         False
#
#    h_s_match_yn  person_attribute_a  person_attribute_a_a  person_attribute_b  \
# 0          True                   1                     1                   2
# 1         False                   2                     0                   2
# 2          True                   2                     3                   2
# 3          True                   1                     2                   2
# 4         False                   1                     6                   4
#
#    person_prefer_c  person_prefer_d_1  person_prefer_d_2  person_prefer_d_3  \
# 0                1                857                851               1227
# 1                2                683               1086                662
# 2                1                514                790               1233
# 3                5                114                181                175
# 4                5               1082               1078               1056
#
#    person_prefer_e  person_prefer_h_1  person_prefer_h_2  person_prefer_h_3  \
# 0                4                263                 56                 49
# 1                2                258                263                 49
# 2                0                177                170                171
# 3                4                177                170                171
# 4                5                178                177                  4
#
#    contents_attribute_i  contents_attribute_a  contents_attribute_j_1  \
# 0                     1                     3                      10
# 1                     1                     3                       5
# 2                     3                     3                       3
# 3                     3                     3                       5
# 4                     3                     1                       5
#
#    contents_attribute_j  contents_attribute_c  contents_attribute_k  \
# 0                     2                     1                     2
# 1                     1                     1                     2
# 2                     1                     1                     2
# 3                     1                     1                     2
# 4                     1                     1                     1
#
#    contents_attribute_l  contents_attribute_d  contents_attribute_m  \
# 0                  1147                   839                     1
# 1                  1611                   278                     1
# 2                  1817                   490                     3
# 3                   101                   150                     5
# 4                   985                  1097                     1
#
#    contents_attribute_e  contents_attribute_h
# 0                     5                   263
# 1                     4                   263
# 2                     4                   177
# 3                     3                   177
# 4                     4                   177

# %% [markdown]
# # 모델 학습/예측

# %%
# 순서형 특성 수치형으로 지정 : ⭕
# 'person_attribute_a_a', 'person_attribute_b', 'person_prefer_e', 'contents_attribute_e'

# %%
ex = setup(train, target='target', n_jobs=3, session_id=0, verbose=False, silent=True, 
 fold=5, fold_shuffle=True, combine_rare_levels=True,
 numeric_features=['person_attribute_a_a', 'person_attribute_b', 'person_prefer_e', 'contents_attribute_e'])

# %%
compare_models(sort='F1')
# 32m 56s
# Out:
# <style  type="text/css" >
#     #T_9a909_ th {
#           text-align: left;
#     }#T_9a909_row0_col0,#T_9a909_row0_col1,#T_9a909_row0_col2,#T_9a909_row0_col4,#T_9a909_row0_col6,#T_9a909_row0_col7,#T_9a909_row1_col0,#T_9a909_row1_col3,#T_9a909_row1_col5,#T_9a909_row2_col0,#T_9a909_row2_col1,#T_9a909_row2_col2,#T_9a909_row2_col3,#T_9a909_row2_col4,#T_9a909_row2_col5,#T_9a909_row2_col6,#T_9a909_row2_col7,#T_9a909_row3_col0,#T_9a909_row3_col1,#T_9a909_row3_col2,#T_9a909_row3_col3,#T_9a909_row3_col4,#T_9a909_row3_col5,#T_9a909_row3_col6,#T_9a909_row3_col7,#T_9a909_row4_col0,#T_9a909_row4_col1,#T_9a909_row4_col2,#T_9a909_row4_col3,#T_9a909_row4_col4,#T_9a909_row4_col5,#T_9a909_row4_col6,#T_9a909_row4_col7,#T_9a909_row5_col0,#T_9a909_row5_col1,#T_9a909_row5_col2,#T_9a909_row5_col3,#T_9a909_row5_col4,#T_9a909_row5_col5,#T_9a909_row5_col6,#T_9a909_row5_col7,#T_9a909_row6_col0,#T_9a909_row6_col1,#T_9a909_row6_col2,#T_9a909_row6_col3,#T_9a909_row6_col4,#T_9a909_row6_col5,#T_9a909_row6_col6,#T_9a909_row6_col7,#T_9a909_row7_col0,#T_9a909_row7_col1,#T_9a909_row7_col2,#T_9a909_row7_col3,#T_9a909_row7_col4,#T_9a909_row7_col5,#T_9a909_row7_col6,#T_9a909_row7_col7,#T_9a909_row8_col0,#T_9a909_row8_col1,#T_9a909_row8_col2,#T_9a909_row8_col3,#T_9a909_row8_col4,#T_9a909_row8_col5,#T_9a909_row8_col6,#T_9a909_row8_col7,#T_9a909_row9_col0,#T_9a909_row9_col1,#T_9a909_row9_col2,#T_9a909_row9_col3,#T_9a909_row9_col4,#T_9a909_row9_col5,#T_9a909_row9_col6,#T_9a909_row9_col7,#T_9a909_row10_col0,#T_9a909_row10_col1,#T_9a909_row10_col2,#T_9a909_row10_col3,#T_9a909_row10_col4,#T_9a909_row10_col5,#T_9a909_row10_col6,#T_9a909_row10_col7,#T_9a909_row11_col0,#T_9a909_row11_col1,#T_9a909_row11_col2,#T_9a909_row11_col3,#T_9a909_row11_col4,#T_9a909_row11_col5,#T_9a909_row11_col6,#T_9a909_row11_col7,#T_9a909_row12_col0,#T_9a909_row12_col1,#T_9a909_row12_col2,#T_9a909_row12_col3,#T_9a909_row12_col4,#T_9a909_row12_col5,#T_9a909_row12_col6,#T_9a909_row12_col7,#T_9a909_row13_col0,#T_9a909_row13_col1,#T_9a909_row13_col2,#T_9a909_row13_col3,#T_9a909_row13_col4,#T_9a909_row13_col5,#T_9a909_row13_col6,#T_9a909_row13_col7,#T_9a909_row14_col0,#T_9a909_row14_col1,#T_9a909_row14_col2,#T_9a909_row14_col3,#T_9a909_row14_col4,#T_9a909_row14_col5,#T_9a909_row14_col6,#T_9a909_row14_col7{
#             text-align:  left;
#             text-align:  left;
#         }#T_9a909_row0_col3,#T_9a909_row0_col5,#T_9a909_row1_col1,#T_9a909_row1_col2,#T_9a909_row1_col4,#T_9a909_row1_col6,#T_9a909_row1_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_9a909_row0_col8,#T_9a909_row1_col8,#T_9a909_row2_col8,#T_9a909_row3_col8,#T_9a909_row4_col8,#T_9a909_row5_col8,#T_9a909_row6_col8,#T_9a909_row7_col8,#T_9a909_row8_col8,#T_9a909_row9_col8,#T_9a909_row10_col8,#T_9a909_row11_col8,#T_9a909_row12_col8,#T_9a909_row13_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_9a909_row14_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_9a909_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9a909_level0_row0" class="row_heading level0 row0" >nb</th>
#                         <td id="T_9a909_row0_col0" class="data row0 col0" >Naive Bayes</td>
#                         <td id="T_9a909_row0_col1" class="data row0 col1" >0.5429</td>
#                         <td id="T_9a909_row0_col2" class="data row0 col2" >0.5938</td>
#                         <td id="T_9a909_row0_col3" class="data row0 col3" >0.8477</td>
#                         <td id="T_9a909_row0_col4" class="data row0 col4" >0.5265</td>
#                         <td id="T_9a909_row0_col5" class="data row0 col5" >0.6495</td>
#                         <td id="T_9a909_row0_col6" class="data row0 col6" >0.0863</td>
#                         <td id="T_9a909_row0_col7" class="data row0 col7" >0.1089</td>
#                         <td id="T_9a909_row0_col8" class="data row0 col8" >0.5280</td>
#             </tr>
#             <tr>
#                         <th id="T_9a909_level0_row1" class="row_heading level0 row1" >catboost</th>
#                         <td id="T_9a909_row1_col0" class="data row1 col0" >CatBoost Classifier</td>
#                         <td id="T_9a909_row1_col1" class="data row1 col1" >0.6238</td>
#                         <td id="T_9a909_row1_col2" class="data row1 col2" >0.6730</td>
#                         <td id="T_9a909_row1_col3" class="data row1 col3" >0.6727</td>
#                         <td id="T_9a909_row1_col4" class="data row1 col4" >0.6124</td>
#                         <td id="T_9a909_row1_col5" class="data row1 col5" >0.6412</td>
#                         <td id="T_9a909_row1_col6" class="data row1 col6" >0.2476</td>
#                         <td id="T_9a909_row1_col7" class="data row1 col7" >0.2488</td>
#                         <td id="T_9a909_row1_col8" class="data row1 col8" >59.2100</td>
#             </tr>
#             <tr>
#                         <th id="T_9a909_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#                         <td id="T_9a909_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#                         <td id="T_9a909_row2_col1" class="data row2 col1" >0.6133</td>
#                         <td id="T_9a909_row2_col2" class="data row2 col2" >0.6604</td>
#                         <td id="T_9a909_row2_col3" class="data row2 col3" >0.6697</td>
#                         <td id="T_9a909_row2_col4" class="data row2 col4" >0.6015</td>
#                         <td id="T_9a909_row2_col5" class="data row2 col5" >0.6338</td>
#                         <td id="T_9a909_row2_col6" class="data row2 col6" >0.2267</td>
#                         <td id="T_9a909_row2_col7" class="data row2 col7" >0.2282</td>
#                         <td id="T_9a909_row2_col8" class="data row2 col8" >5.9540</td>
#             </tr>
#             <tr>
#                         <th id="T_9a909_level0_row3" class="row_heading level0 row3" >gbc</th>
#                         <td id="T_9a909_row3_col0" class="data row3 col0" >Gradient Boosting Classifier</td>
#                         <td id="T_9a909_row3_col1" class="data row3 col1" >0.6008</td>
#                         <td id="T_9a909_row3_col2" class="data row3 col2" >0.6427</td>
#                         <td id="T_9a909_row3_col3" class="data row3 col3" >0.6397</td>
#                         <td id="T_9a909_row3_col4" class="data row3 col4" >0.5932</td>
#                         <td id="T_9a909_row3_col5" class="data row3 col5" >0.6156</td>
#                         <td id="T_9a909_row3_col6" class="data row3 col6" >0.2016</td>
#                         <td id="T_9a909_row3_col7" class="data row3 col7" >0.2022</td>
#                         <td id="T_9a909_row3_col8" class="data row3 col8" >76.3040</td>
#             </tr>
#             <tr>
#                         <th id="T_9a909_level0_row4" class="row_heading level0 row4" >rf</th>
#                         <td id="T_9a909_row4_col0" class="data row4 col0" >Random Forest Classifier</td>
#                         <td id="T_9a909_row4_col1" class="data row4 col1" >0.6120</td>
#                         <td id="T_9a909_row4_col2" class="data row4 col2" >0.6582</td>
#                         <td id="T_9a909_row4_col3" class="data row4 col3" >0.6207</td>
#                         <td id="T_9a909_row4_col4
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
model = create_model('nb')
# Out:
# <style  type="text/css" >
# #T_d85e9_row5_col0,#T_d85e9_row5_col1,#T_d85e9_row5_col2,#T_d85e9_row5_col3,#T_d85e9_row5_col4,#T_d85e9_row5_col5,#T_d85e9_row5_col6{
#             background:  yellow;
#         }</style><table id="T_d85e9_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d85e9_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d85e9_row0_col0" class="data row0 col0" >0.5403</td>
#                         <td id="T_d85e9_row0_col1" class="data row0 col1" >0.5923</td>
#                         <td id="T_d85e9_row0_col2" class="data row0 col2" >0.8416</td>
#                         <td id="T_d85e9_row0_col3" class="data row0 col3" >0.5249</td>
#                         <td id="T_d85e9_row0_col4" class="data row0 col4" >0.6466</td>
#                         <td id="T_d85e9_row0_col5" class="data row0 col5" >0.0810</td>
#                         <td id="T_d85e9_row0_col6" class="data row0 col6" >0.1015</td>
#             </tr>
#             <tr>
#                         <th id="T_d85e9_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_d85e9_row1_col0" class="data row1 col0" >0.5425</td>
#                         <td id="T_d85e9_row1_col1" class="data row1 col1" >0.5913</td>
#                         <td id="T_d85e9_row1_col2" class="data row1 col2" >0.8431</td>
#                         <td id="T_d85e9_row1_col3" class="data row1 col3" >0.5263</td>
#                         <td id="T_d85e9_row1_col4" class="data row1 col4" >0.6481</td>
#                         <td id="T_d85e9_row1_col5" class="data row1 col5" >0.0854</td>
#                         <td id="T_d85e9_row1_col6" class="data row1 col6" >0.1068</td>
#             </tr>
#             <tr>
#                         <th id="T_d85e9_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_d85e9_row2_col0" class="data row2 col0" >0.5440</td>
#                         <td id="T_d85e9_row2_col1" class="data row2 col1" >0.5944</td>
#                         <td id="T_d85e9_row2_col2" class="data row2 col2" >0.8512</td>
#                         <td id="T_d85e9_row2_col3" class="data row2 col3" >0.5270</td>
#                         <td id="T_d85e9_row2_col4" class="data row2 col4" >0.6510</td>
#                         <td id="T_d85e9_row2_col5" class="data row2 col5" >0.0884</td>
#                         <td id="T_d85e9_row2_col6" class="data row2 col6" >0.1120</td>
#             </tr>
#             <tr>
#                         <th id="T_d85e9_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_d85e9_row3_col0" class="data row3 col0" >0.5460</td>
#                         <td id="T_d85e9_row3_col1" class="data row3 col1" >0.5968</td>
#                         <td id="T_d85e9_row3_col2" class="data row3 col2" >0.8549</td>
#                         <td id="T_d85e9_row3_col3" class="data row3 col3" >0.5282</td>
#                         <td id="T_d85e9_row3_col4" class="data row3 col4" >0.6530</td>
#                         <td id="T_d85e9_row3_col5" class="data row3 col5" >0.0924</td>
#                         <td id="T_d85e9_row3_col6" class="data row3 col6" >0.1175</td>
#             </tr>
#             <tr>
#                         <th id="T_d85e9_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_d85e9_row4_col0" class="data row4 col0" >0.5419</td>
#                         <td id="T_d85e9_row4_col1" class="data row4 col1" >0.5941</td>
#                         <td id="T_d85e9_row4_col2" class="data row4 col2" >0.8474</td>
#                         <td id="T_d85e9_row4_col3" class="data row4 col3" >0.5258</td>
#                         <td id="T_d85e9_row4_col4" class="data row4 col4" >0.6489</td>
#                         <td id="T_d85e9_row4_col5" class="data row4 col5" >0.0842</td>
#                         <td id="T_d85e9_row4_col6" class="data row4 col6" >0.1064</td>
#             </tr>
#             <tr>
#                         <th id="T_d85e9_level0_row5" class="row_heading level0 row5" >Mean</th>
#                         <td id="T_d85e9_row5_col0" class="data row5 col0" >0.5429</td>
#                         <td id="T_d85e9_row5_col1" class="data row5 col1" >0.5938</td>
#                         <td id="T_d85e9_row5_col2" class="data row5 col2" >0.8477</td>
#                         <td id="T_d85e9_row5_col3" class="data row5 col3" >0.5265</td>
#                         <td id="T_d85e9_row5_col4" class="data row5 col4" >0.6495</td>
#                         <td id="T_d85e9_row5_col5" class="data row5 col5" >0.0863</td>
#                         <td id="T_d85e9_row5_col6" class="data row5 col6" >0.1089</td>
#             </tr>
#             <tr>
#                         <th id="T_d85e9_level0_row6" class="row_heading level0 row6" >SD</th>
#                         <td id="T_d85e9_row6_col0" class="data row6 col0" >0.0019</td>
#                         <td id="T_d85e9_row6_col1" class="data row6 col1" >0.0019</td>
#                         <td id="T_d85e9_row6_col2" class="data row6 col2" >0.0050</td>
#                         <td id="T_d85e9_row6_col3" class="data row6 col3" >0.0011</td>
#                         <td id="T_d85e9_row6_col4" class="data row6 col4" >0.0023</td>
#                         <td id="T_d85e9_row6_col5" class="data row6 col5" >0.0039</td>
#                         <td id="T_d85e9_row6_col6" class="data row6 col6" >0.0055</td>
#             </tr>
#     </tbody></table>

# %%
pred = predict_model(model, test)

# %%
pred.head()
# Out:
#    d_l_match_yn  d_m_match_yn  d_s_match_yn  h_l_match_yn  h_m_match_yn  \
# 0          True         False         False          True          True
# 1         False         False         False          True         False
# 2          True         False         False          True          True
# 3          True         False         False          True          True
# 4          True         False         False          True         False
#
#    h_s_match_yn  person_attribute_a  person_attribute_a_a  person_attribute_b  \
# 0          True                   1                     1                   2
# 1         False                   2                     0                   2
# 2          True                   2                     3                   2
# 3          True                   1                     2                   2
# 4         False                   1                     6                   4
#
#    person_prefer_c  ...  contents_attribute_j  contents_attribute_c  \
# 0                1  ...                     2                     1
# 1                2  ...                     1                     1
# 2                1  ...                     1                     1
# 3                5  ...                     1                     1
# 4                5  ...                     1                     1
#
#    contents_attribute_k  contents_attribute_l  contents_attribute_d  \
# 0                     2                  1147                   839
# 1                     2                  1611                   278
# 2                     2                  1817                   490
# 3                     2                   101                   150
# 4                     1                   985                  1097
#
#    contents_attribute_m  contents_attribute_e  contents_attribute_h  Label  \
# 0                     1                     5                   263      1
# 1                     1                     4                   263      0
# 2                     3                     4                   177      0
# 3                     5                     3                   177      1
# 4                     1                     4                   177      0
#
#     Score
# 0  0.6575
# 1  0.5821
# 2  0.9961
# 3  0.9346
# 4  0.7754
#
# [5 rows x 30 columns]

# %%
pred.iloc[:,-2:].head()
# Out:
#    Label   Score
# 0      1  0.6575
# 1      0  0.5821
# 2      0  0.9961
# 3      1  0.9346
# 4      0  0.7754

# %%
pred['Label'].value_counts()
# Out:
# 1    36211
# 0    10193
# Name: Label, dtype: int64

# %% [markdown]
# # 제출파일 생성

# %%
submission = pd.read_csv('../data/sample_submission.csv')
submission['target'] = pred['Label']

submission.to_csv('sub_ver1.2.csv', index=False)

# %% [markdown]
# # 모델 분석 그래프

# %%
plot_model(model)
